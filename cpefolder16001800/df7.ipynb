# %%
import requests
from datetime import datetime
import pandas as pd

# %%
df=pd.read_csv('df9.csv') #change

# %%
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1600  #CHANGE
    target_upper = 1800 #CHANGE

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 30 <= days_taken <= 55: #CHANGE
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
# Out:
# abhaumik24 did not cross the rating margin within the specified range.
# keep1earning did not cross the rating margin within the specified range.
# namelessly did not cross the rating margin within the specified range.
# nyaaaayn did not cross the rating margin within the specified range.
# partTimeIntern did not cross the rating margin within the specified range.
# rudicundo did not cross the rating margin within the specified range.
# zhaopipichishi did not cross the rating margin within the specified range.
# C8H15NO2 did not cross the rating margin within the specified range.
# FLAME. did not cross the rating margin within the specified range.
# HMZHMZHMZ did not cross the rating margin within the specified range.
# Hamine did not cross the rating margin within the specified range.
# Khalwsh did not cross the rating margin within the specified range.
# Metallic did not cross the rating margin within the specified range.
# Thinkbuge did not cross the rating margin within the specified range.
# ajayreddy12123 did not cross the rating margin within the specified range.
# bawiFox did not cross the rating margin within the specified range.
# Failed to fetch rating history for cp_boy. Status code: 503
# fryingduc did not cross the rating margin within the specified range.
# idat_50me did not cross the rating margin within the specified range.
# iliaaaaa did not cross the rating margin within the specified range.
# libolin1 did not cross the rating margin within the specified range.
# piyush_raz did not cross the rating margin within the specified range.
# Failed to fetch rating history for xalwa. Status code: 503
# 911Boom did not cross the rating margin within the specified range.
# Anlybt did not cross the rating margin within the specified range.
# Blastoise42 did not cross the rating margin within the specified range.
# Blueawa did not cross the rating margin within the specified range.
# Failed to fetch rating history for EyadBT. Status code: 503
# Failed to fetch rating history for Headshooot. Status code: 503
# MadRat_2 did not cross the rating margin within the specified range.
# Maginy_ZYX did not cross the rating margin within the specified range.
# Failed to fetch rating history for r_chesnokov. Status code: 503
# tamminaina_y did not cross the rating margin within the specified range.
# Failed to fetch rating history for yaloh. Status code: 503
# Failed to fetch rating history for 77x17. Status code: 503
# IS_Rushdi did not cross the rating margin within the specified range.
# Failed to fetch rating history for JellyFishy. Status code: 503
# MiniMboker did not cross the rating margin within the specified range.
# TanJI did not cross the rating margin within the specified range.
# aonbel did not cross the rating margin within the specified range.
# Failed to fetch rating history for jlallas384. Status code: 503
# nisargagrawal75 did not cross the rating margin within the specified range.
# Cryogenic2302 did not cross the rating margin within the specified range.
# RatingIsJustANumber did not cross the rating margin within the specified range.
# depresed_k1d did not cross the rating margin within the specified range.
# juzixiong did not cross the rating margin within the specified range.
# kb_00 did not cross the rating margin within the specified range.
# Failed to fetch rating history for keduolimm. Status code: 503
# likhnic did not cross the rating margin within the specified range.
# Failed to fetch rating history for madhav_23. Status code: 503
# Failed to fetch rating history for tobitob. Status code: 503
# weawemam did not cross the rating margin within the specified range.
# A5IR did not cross the rating margin within the specified range.
# Trumling did not cross the rating margin within the specified range.
# Failed to fetch rating history for icewarrior52. Status code: 503
# Abhi8803 did not cross the rating margin within the specified range.
# Aukotiq did not cross the rating margin within the specified range.
# ChinatsuKano did not cross the rating margin within the specified range.
# Failed to fetch rating history for Iskander2287. Status code: 503
# Omiya_Shinobu did not cross the rating margin within the specified range.
# Failed to fetch rating history for Taha. Status code: 503
# angleface_DAC did not cross the rating margin within the specified range.
# Failed to fetch rating history for cqbzzhy. Status code: 503
# thirdcook did not cross the rating margin within the specified range.
# wordy did not cross the rating margin within the specified range.
# 112661 did not cross the rating margin within the specified range.
# 2986858916 did not cross the rating margin within the specified range.
# Failed to fetch rating history for A_Peasant. Status code: 503
# Abo_Samrah did not cross the rating margin within the specified range.
# Cryptic_42 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Desh01. Status code: 503
# FritzGeiger did not cross the rating margin within the specified range.
# Lockeder did not cross the rating margin within the specified range.
# Failed to fetch rating history for Muhammad.SARAM. Status code: 503
# kotyakotb did not cross the rating margin within the specified range.
# Failed to fetch rating history for lunaticAJ. Status code: 503
# Failed to fetch rating history for rkb_rd. Status code: 503
# sharmalokesh did not cross the rating margin within the specified range.
# vahmad did not cross the rating margin within the specified range.
# Failed to fetch rating history for zhtzshhh666. Status code: 503
# Kurukururin did not cross the rating margin within the specified range.
# Sreedhar3210 did not cross the rating margin within the specified range.
# ZoeL-Jul10 did not cross the rating margin within the specified range.
# Failed to fetch rating history for __FRIDAY__. Status code: 503
# amit_pandit_15 did not cross the rating margin within the specified range.
# helloZ did not cross the rating margin within the specified range.
# Failed to fetch rating history for rsegvic. Status code: 503
# stevenhoang did not cross the rating margin within the specified range.
# EdGrass did not cross the rating margin within the specified range.
# Failed to fetch rating history for NintyMinLost. Status code: 503
# bochkov did not cross the rating margin within the specified range.
# dj4zo6u.6 did not cross the rating margin within the specified range.
# Failed to fetch rating history for futuo. Status code: 503
# kinglykang did not cross the rating margin within the specified range.
# subrat0018 did not cross the rating margin within the specified range.
# tanvir03 did not cross the rating margin within the specified range.
# yzkkai did not cross the rating margin within the specified range.
# Failed to fetch rating history for Arpia. Status code: 503
# ShadowRainger did not cross the rating margin within the specified range.
# Failed to fetch rating history for prem__. Status code: 503
# pretodf did not cross the rating margin within the specified range.
# Failed to fetch rating history for 1xrz1. Status code: 503
# 7oSkaaa did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ansh777. Status code: 503
# GANGSTER did not cross the rating margin within the specified range.
# Failed to fetch rating history for Taki_Tachibana. Status code: 503
# Tzzzzz did not cross the rating margin within the specified range.
# YuXiao did not cross the rating margin within the specified range.
# emoreira did not cross the rating margin within the specified range.
# fyh20 did not cross the rating margin within the specified range.
# Failed to fetch rating history for i.Pear. Status code: 503
# muxiuyulin did not cross the rating margin within the specified range.
# mzmz001 did not cross the rating margin within the specified range.
# Chienthancp did not cross the rating margin within the specified range.
# Failed to fetch rating history for DerrickLo. Status code: 503
# Zoro238 did not cross the rating margin within the specified range.
# larsr did not cross the rating margin within the specified range.
# little_dog did not cross the rating margin within the specified range.
# Failed to fetch rating history for maxK99. Status code: 503
# ulorew did not cross the rating margin within the specified range.
# Failed to fetch rating history for woaihutao. Status code: 503
# Dhanushk23 did not cross the rating margin within the specified range.
# Failed to fetch rating history for EthanZYF. Status code: 503
# FuelTheBurn did not cross the rating margin within the specified range.
# Failed to fetch rating history for Musab1Blaser. Status code: 503
# NewTraveller did not cross the rating margin within the specified range.
# RGB_YYYYY did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ricardo03. Status code: 503
# SunlightZero did not cross the rating margin within the specified range.
# aron3678 did not cross the rating margin within the specified range.
# Failed to fetch rating history for btac. Status code: 503
# ilyaytrewq did not cross the rating margin within the specified range.
# Failed to fetch rating history for m.ashoori. Status code: 503
# ninjamayank did not cross the rating margin within the specified range.
# os-moussao did not cross the rating margin within the specified range.
# Failed to fetch rating history for panhuachao. Status code: 503
# zhi_fan did not cross the rating margin within the specified range.
# 930851771G did not cross the rating margin within the specified range.
# Failed to fetch rating history for I_LOVE_RNG. Status code: 503
# Kun10 did not cross the rating margin within the specified range.
# Moonandlight did not cross the rating margin within the specified range.
# Failed to fetch rating history for _Pahal_Aman. Status code: 503
# happify03 did not cross the rating margin within the specified range.
# llzzxx712 did not cross the rating margin within the specified range.
# Failed to fetch rating history for stash. Status code: 503
# surung9898 did not cross the rating margin within the specified range.
# zzq_666 did not cross the rating margin within the specified range.
# 27_Numara did not cross the rating margin within the specified range.
# Failed to fetch rating history for 66H6. Status code: 503
# QH.hqh did not cross the rating margin within the specified range.
# aditya.pca.25 did not cross the rating margin within the specified range.
# littlegirl112 did not cross the rating margin within the specified range.
# orange_juice_1024 did not cross the rating margin within the specified range.
# paketik_chaya did not cross the rating margin within the specified range.
# world_of_only_victors did not cross the rating margin within the specified range.
# yeaDonaby did not cross the rating margin within the specified range.
# zabrouter did not cross the rating margin within the specified range.
# A1m233 did not cross the rating margin within the specified range.
# AnosVoldigoad did not cross the rating margin within the specified range.
# AutumnMist did not cross the rating margin within the specified range.
# Failed to fetch rating history for Fremder. Status code: 503
# Little_Xi did not cross the rating margin within the specified range.
# Failed to fetch rating history for TLE_Automaton. Status code: 503
# avatsavirsa did not cross the rating margin within the specified range.
# Failed to fetch rating history for baibaiouo. Status code: 503
# buffering did not cross the rating margin within the specified range.
# emad234 did not cross the rating margin within the specified range.
# llking did not cross the rating margin within the specified range.
# shiqiaqiaya did not cross the rating margin within the specified range.
# whutzym did not cross the rating margin within the specified range.
# Failed to fetch rating history for HarmlessLittleMlem. Status code: 503
# Failed to fetch rating history for harryzhengipsum. Status code: 503
# hydra_cody did not cross the rating margin within the specified range.
# Failed to fetch rating history for kosakkun. Status code: 503
# pandeyGRocks did not cross the rating margin within the specified range.
# sieunhan283 did not cross the rating margin within the specified range.
# Nagae_Iku did not cross the rating margin within the specified range.
# OLGA233 did not cross the rating margin within the specified range.
# Failed to fetch rating history for ShirosakiMieru. Status code: 503
# huyaowen did not cross the rating margin within the specified range.
# Spidy01 did not cross the rating margin within the specified range.
# Yuuukkk did not cross the rating margin within the specified range.
# _WannaLoveyou did not cross the rating margin within the specified range.
# Failed to fetch rating history for litachloveyou. Status code: 503
# BroHit did not cross the rating margin within the specified range.
# Failed to fetch rating history for Citrus_Sinensis. Status code: 503
# Karrrrrr did not cross the rating margin within the specified range.
# NaCly-fish did not cross the rating margin within the specified range.
# Failed to fetch rating history for radi__07. Status code: 503
# shdut0901 did not cross the rating margin within the specified range.
# tft_grandmaster did not cross the rating margin within the specified range.
# Atuer did not cross the rating margin within the specified range.
# BabyPopcorn did not cross the rating margin within the specified range.
# Oinng did not cross the rating margin within the specified range.
# OmarTammam did not cross the rating margin within the specified range.
# Failed to fetch rating history for TRMN. Status code: 503
# Troubadour_Ggmz did not cross the rating margin within the specified range.
# baizongyu314 did not cross the rating margin within the specified range.
# Failed to fetch rating history for goelsagar. Status code: 503
# igeee did not cross the rating margin within the specified range.
# Failed to fetch rating history for jiangnaihui. Status code: 503
# jypiter did not cross the rating margin within the specified range.
# kyoukohori did not cross the rating margin within the specified range.
# mewnya did not cross the rating margin within the specified range.
# Failed to fetch rating history for peshkoff. Status code: 503
# AndreNascimento did not cross the rating margin within the specified range.
# Hero777 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Infinity_206. Status code: 503
# Juanm1 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Katakuri57. Status code: 503
# PedroGallo did not cross the rating margin within the specified range.
# Red_House did not cross the rating margin within the specified range.
# SpeedDemon did not cross the rating margin within the specified range.
# Unrated_LGM did not cross the rating margin within the specified range.
# Failed to fetch rating history for Zadbebroni. Status code: 503
# eq24 did not cross the rating margin within the specified range.
# Failed to fetch rating history for its_pranjal_83. Status code: 503
# kalDima did not cross the rating margin within the specified range.
# kk_d did not cross the rating margin within the specified range.
# trh0630 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Chairman_Meow. Status code: 503
# Greedious did not cross the rating margin within the specified range.
# Michailus did not cross the rating margin within the specified range.
# Remineva did not cross the rating margin within the specified range.
# Failed to fetch rating history for bhukyatharun216. Status code: 503
# jingxi did not cross the rating margin within the specified range.
# margo820 did not cross the rating margin within the specified range.
# Failed to fetch rating history for shengda. Status code: 503
# Arpitkr did not cross the rating margin within the specified range.
# Elgoker did not cross the rating margin within the specified range.
# Ssaranshh13 did not cross the rating margin within the specified range.
# Failed to fetch rating history for eddyboy. Status code: 503
# Failed to fetch rating history for introspecct. Status code: 503
# mohen did not cross the rating margin within the specified range.
# Failed to fetch rating history for t.a7a.ya_masr. Status code: 503
# 1e-9 did not cross the rating margin within the specified range.
# Failed to fetch rating history for AW_Flister. Status code: 503
# Achaoooo did not cross the rating margin within the specified range.
# G_Ayan7 did not cross the rating margin within the specified range.
# Handler90 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Hanx16. Status code: 503
# ShyGuy did not cross the rating margin within the specified range.
# Skay did not cross the rating margin within the specified range.
# anthonyaaab123 did not cross the rating margin within the specified range.
# bkdn23.hide__ did not cross the rating margin within the specified range.
# deuteridayo did not cross the rating margin within the specified range.
# dogoeswoof did not cross the rating margin within the specified range.
# Failed to fetch rating history for fullmetal. Status code: 503
# iling_ did not cross the rating margin within the specified range.
# Failed to fetch rating history for janrandom. Status code: 503
# lionel.m did not cross the rating margin within the specified range.
# wjxAKIOI did not cross the rating margin within the specified range.
# Failed to fetch rating history for yuvraj_k. Status code: 503
# zhligzweru did not cross the rating margin within the specified range.
# Alve_50 did not cross the rating margin within the specified range.
# MaiAditya did not cross the rating margin within the specified range.
# gipnag did not cross the rating margin within the specified range.
# Failed to fetch rating history for haengsyo. Status code: 503
# hpractic did not cross the rating margin within the specified range.
# Failed to fetch rating history for sharmaharsh2609. Status code: 503
# Coder14_a523 did not cross the rating margin within the specified range.
# DM2002 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ismail_Alrifai. Status code: 503
# SAEED. did not cross the rating margin within the specified range.
# The-N-word did not cross the rating margin within the specified range.
# Failed to fetch rating history for Zhengliangfei. Status code: 503
# _xiaohao did not cross the rating margin within the specified range.
# c_plus_plus did not cross the rating margin within the specified range.
# cuenta_secundaria did not cross the rating margin within the specified range.
# Failed to fetch rating history for lishan4688. Status code: 503
# lizhous did not cross the rating margin within the specified range.
# sanamdeepsinghbhatia did not cross the rating margin within the specified range.
# Failed to fetch rating history for ttt1anyu. Status code: 503
# Lirich did not cross the rating margin within the specified range.
# Failed to fetch rating history for MunirKP. Status code: 503
# PeruvianCartel did not cross the rating margin within the specified range.
# Pro_Noob_25 did not cross the rating margin within the specified range.
# Shri_874 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Taibo. Status code: 503
# haciii did not cross the rating margin within the specified range.
# Failed to fetch rating history for ko_RT_nya. Status code: 503
# liuyaningqwq did not cross the rating margin within the specified range.
# pienotpi did not cross the rating margin within the specified range.
# sheldonn did not cross the rating margin within the specified range.
# Failed to fetch rating history for soham_c04. Status code: 503
# AlexRex0 did not cross the rating margin within the specified range.
# SUII did not cross the rating margin within the specified range.
# Shubham-V did not cross the rating margin within the specified range.
# Failed to fetch rating history for _Aghost. Status code: 503
# giaminh2211 did not cross the rating margin within the specified range.
# t00100t did not cross the rating margin within the specified range.
# Koiios did not cross the rating margin within the specified range.
# Nedal did not cross the rating margin within the specified range.
# Failed to fetch rating history for _bqn. Status code: 503
# _gyrFalcon_ did not cross the rating margin within the specified range.
# greensignal did not cross the rating margin within the specified range.
# Failed to fetch rating history for 34z12000. Status code: 503
# AyuAnchor did not cross the rating margin within the specified range.
# Gabituss did not cross the rating margin within the specified range.
# Kawchar85 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Striker009. Status code: 503
# dolphin2025 did not cross the rating margin within the specified range.
# Failed to fetch rating history for dreamjoker. Status code: 503
# dshfjka did not cross the rating margin within the specified range.
# ghosh__ did not cross the rating margin within the specified range.
# Failed to fetch rating history for hacker.NO.1. Status code: 503
# kysibongdem did not cross the rating margin within the specified range.
# mark did not cross the rating margin within the specified range.
# Failed to fetch rating history for oogerbooger. Status code: 503
# sariel_mao did not cross the rating margin within the specified range.
# Failed to fetch rating history for yanb0. Status code: 503
# DADA_JI did not cross the rating margin within the specified range.
# IgorA did not cross the rating margin within the specified range.
# Failed to fetch rating history for Not_A_Fumo. Status code: 503
# ajmeraraghav99 did not cross the rating margin within the specified range.
# arthur_9548 did not cross the rating margin within the specified range.
# caos_enjoyer did not cross the rating margin within the specified range.
# cypher_king did not cross the rating margin within the specified range.
# dongggle did not cross the rating margin within the specified range.
# hnust_lijiahui did not cross the rating margin within the specified range.
# manavisrani2002 did not cross the rating margin within the specified range.
# Failed to fetch rating history for my_father. Status code: 503
# Failed to fetch rating history for spectrra. Status code: 503
# Art.twink did not cross the rating margin within the specified range.
# FilatovYura did not cross the rating margin within the specified range.
# azert9526 did not cross the rating margin within the specified range.
# Failed to fetch rating history for jz796. Status code: 503
# luckyblock233 did not cross the rating margin within the specified range.
# Alexey_Parsh did not cross the rating margin within the specified range.
# AverageBasilEnjoyer did not cross the rating margin within the specified range.
# Naim_Elias did not cross the rating margin within the specified range.
# Failed to fetch rating history for SuperSat0001. Status code: 503
# Xorx7 did not cross the rating margin within the specified range.
# code_hardik did not cross the rating margin within the specified range.
# Failed to fetch rating history for nirav114. Status code: 503
# njupt_zy did not cross the rating margin within the specified range.
# pu29 did not cross the rating margin within the specified range.
# Benzenes did not cross the rating margin within the specified range.
# GxDf77777 did not cross the rating margin within the specified range.
# gagan_6730 did not cross the rating margin within the specified range.
# Failed to fetch rating history for hahaha1234. Status code: 503
# hipereg did not cross the rating margin within the specified range.
# khanhtai did not cross the rating margin within the specified range.
# pipiaker did not cross the rating margin within the specified range.
# Failed to fetch rating history for turgon314. Status code: 503
# tx344 did not cross the rating margin within the specified range.
# yolx did not cross the rating margin within the specified range.
# -WIDA- did not cross the rating margin within the specified range.
# Harsh-Bardolia did not cross the rating margin within the specified range.
# SmartMonky did not cross the rating margin within the specified range.
# Vanjanja did not cross the rating margin within the specified range.
# Failed to fetch rating history for andreumat. Status code: 503
# hnust_lizhongyu did not cross the rating margin within the specified range.
# Failed to fetch rating history for j30. Status code: 503
# jabbour.ralph did not cross the rating margin within the specified range.
# Failed to fetch rating history for kaislash.. Status code: 503
# ngmtuan did not cross the rating margin within the specified range.
# Failed to fetch rating history for shstyle. Status code: 503
# void_3 did not cross the rating margin within the specified range.
# Failed to fetch rating history for EchoInvisible. Status code: 503
# ErikJ did not cross the rating margin within the specified range.
# I_CE_IOI did not cross the rating margin within the specified range.
# MinhCrafter3009 did not cross the rating margin within the specified range.
# NishantS did not cross the rating margin within the specified range.
# Failed to fetch rating history for YamOCHca. Status code: 503
# aayushdhankecha did not cross the rating margin within the specified range.
# cyc_43346 did not cross the rating margin within the specified range.
# lubei600 did not cross the rating margin within the specified range.
# Failed to fetch rating history for neugis. Status code: 503
# the_detective did not cross the rating margin within the specified range.
# tojra did not cross the rating margin within the specified range.
# Apiram did not cross the rating margin within the specified range.
# Failed to fetch rating history for Gegege337. Status code: 503
# MrOtter did not cross the rating margin within the specified range.
# _Sayantan did not cross the rating margin within the specified range.
# Failed to fetch rating history for _Solyman. Status code: 503
#                     Handle  Max Rating Result
# 0                Stuxnet.z        2002     No
# 1               abhaumik24        1785    N/A
# 2             keep1earning        1718    N/A
# 3               namelessly        1718    N/A
# 4                 nyaaaayn        1718    N/A
# ..                     ...         ...    ...
# 495                 LLZZKK        1882     No
# 496                MrOtter        1725    N/A
# 497  PUSSY_LICKING_LOLI_69        1878     No
# 498              _Sayantan        1770    N/A
# 499               _Solyman        1686    N/A
#
# [500 rows x 3 columns]

# %%
df.head()
# Out:
#          Handle  Max Rating Result
# 0     Stuxnet.z        2002     No
# 1    abhaumik24        1785    N/A
# 2  keep1earning        1718    N/A
# 3    namelessly        1718    N/A
# 4      nyaaaayn        1718    N/A

# %%
df.to_csv('outdf9.csv', index=False) #change

# %%
#

# %%
file_names = ['outdf{}.csv'.format(i) for i in range(1, 9)] #change

dataframes = []

for file_name in file_names:
    df = pd.read_csv(file_name)
    dataframes.append(df)

merged_data = pd.concat(dataframes, ignore_index=True)

merged_data.to_csv('merged_output.csv', index=False)

print("Merged CSV file saved as 'merged_output.csv'")
# Out:
# Merged CSV file saved as 'merged_output.csv'
