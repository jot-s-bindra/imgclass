# %%
#DONT RUN
import requests
import csv

def get_codeforces_problems(min_difficulty, max_difficulty, count=100):
    base_url = "https://codeforces.com/api/problemset.problems"
    problems = []

    for i in range(0, count, 100): 
        params = {
            "tags": "implementation",  
            "minRating": min_difficulty,
            "maxRating": max_difficulty,
            "from": i,
            "count": 100,
        }

        response = requests.get(base_url, params=params)
        data = response.json()

        if "result" in data and "problems" in data["result"]:
            problems.extend(data["result"]["problems"])

    return problems

def save_problems_to_csv(problems, filename):
    with open(filename, 'w', newline='') as csv_file:
        fieldnames = ['Problem', 'Contest', 'Index', 'Tags']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        
        for problem in problems:
            writer.writerow({
                'Problem': problem['name'],
                'Contest': problem['contestId'],
                'Index': problem['index'],
                'Tags': ', '.join(problem.get('tags', []))
            })

if __name__ == "__main__":
    min_difficulty = 1700 #CHANGE
    max_difficulty = 1900 #CHANGE
    count = 1000  
    filename = "codeforces_problems.csv"
    
    problems = get_codeforces_problems(min_difficulty, max_difficulty, count)
    
    if problems:
        for problem in problems:
            print(f"Problem: {problem['name']}")
            print(f"Contest: {problem['contestId']}")
            print(f"Index: {problem['index']}")
            print(f"Tags: {', '.join(problem.get('tags', []))}")
            print("\n")
        
        save_problems_to_csv(problems, filename)
        print(f"Problems saved to {filename}")
    else:
        print("Failed to retrieve problems from Codeforces API.")

# %%
import requests
import json
import csv

url = "https://codeforces.com/api/problemset.problems"
response = requests.get(url)
data = response.json()

if data["status"] == "OK":
    problems = data["result"]["problems"]
    matching_problems = []

    for problem in problems:
        Problem = problem["name"]
        Contest = problem["contestId"]
        Index = problem["index"]
        
        Tags = ", ".join(problem["tags"])
        rating = problem.get("rating", 0)

        if 1700 <= rating <= 1900:
            matching_problems.append([Problem, Contest, Index, Tags])

    with open("codeforces_problems2.csv", mode="w", newline="") as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow(["Problem", "Contest", "Index", "Tags"])
        writer.writerows(matching_problems)
else:
    print("API request failed with the following comment:", data["comment"])

# %%
import requests
import csv

def get_codeforces_problems(min_difficulty, max_difficulty):
    base_url = "https://codeforces.com/api/problemset.problems"

    params = {
        "tags": "implementation",  
        "minRating": min_difficulty,
        "maxRating": max_difficulty,
    }

    response = requests.get(base_url, params=params)
    data = response.json()

    if "result" in data and "problems" in data["result"]:
        problems = data["result"]["problems"]
        return problems
    else:
        return None

def save_problems_to_csv(problems, filename):
    with open(filename, 'w', newline='') as csv_file:
        fieldnames = ['Problem', 'Contest', 'Index', 'Tags']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        
        for problem in problems:
            writer.writerow({
                'Problem': problem['name'],
                'Contest': problem['contestId'],
                'Index': problem['index'],
                'Tags': ', '.join(problem.get('tags', []))
            })

if __name__ == "__main__":
    min_difficulty = 1700 #CHANGE
    max_difficulty = 1900 #CHANGE
    filename = "codeforces_problems2.csv"
    
    problems = get_codeforces_problems(min_difficulty, max_difficulty)
    
    if problems:      
        for problem in problems:
            print(f"Problem: {problem['name']}")
            print(f"Contest: {problem['contestId']}")
            print(f"Index: {problem['index']}")
            print(f"Tags: {', '.join(problem.get('tags', []))}")
            print("\n")
        
        save_problems_to_csv(problems, filename)
        print(f"Problems saved to {filename}")
    else:
        print("Failed to retrieve problems from Codeforces API.")
# Out:
# Problem: Qingshan Loves Strings
# Contest: 1890
# Index: B
# Tags: implementation
#
#
# Problem: Game of Stacks
# Contest: 1889
# Index: D
# Tags: dfs and similar, graphs, implementation, trees
#
#
# Problem: Doremy's Drying Plan (Easy Version)
# Contest: 1889
# Index: C1
# Tags: brute force, data structures, dp, greedy, implementation, sortings
#
#
# Problem: Decreasing String
# Contest: 1886
# Index: C
# Tags: implementation, strings
#
#
# Problem: Hard Design
# Contest: 1884
# Index: E
# Tags: greedy, implementation, math
#
#
# Problem: Perfect Square
# Contest: 1881
# Index: C
# Tags: brute force, implementation
#
#
# Problem: Interactive Game with Coloring
# Contest: 1879
# Index: E
# Tags: brute force, constructive algorithms, dfs and similar, graphs, implementation, interactive, trees
#
#
# Problem: wxhtzdy ORO Tree
# Contest: 1878
# Index: G
# Tags: binary search, bitmasks, brute force, data structures, dfs and similar, implementation, trees
#
#
# Problem: Jellyfish and Game
# Contest: 1874
# Index: A
# Tags: brute force, games, greedy, implementation
#
#
# Problem: 1D Eraser
# Contest: 1873
# Index: D
# Tags: greedy, implementation, two pointers
#
#
# Problem: Target Practice
# Contest: 1873
# Index: C
# Tags: implementation, math
#
#
# Problem: Short Sort
# Contest: 1873
# Index: A
# Tags: brute force, implementation
#
#
# Problem: Selling a Menagerie
# Contest: 1872
# Index: F
# Tags: dfs and similar, dsu, graphs, implementation, math
#
#
# Problem: The Corridor or There and Back Again
# Contest: 1872
# Index: B
# Tags: greedy, implementation
#
#
# Problem: Prefix Purchase
# Contest: 1870
# Index: D
# Tags: greedy, implementation, sortings
#
#
# Problem: Colorful Table
# Contest: 1870
# Index: C
# Tags: binary search, data structures, dp, implementation, math, two pointers
#
#
# Problem: LIS?
# Contest: 1868
# Index: F
# Tags: data structures, greedy, implementation
#
#
# Problem: Flower-like Pseudotree
# Contest: 1868
# Index: D
# Tags: constructive algorithms, graphs, greedy, implementation, trees
#
#
# Problem: Travel Plan
# Contest: 1868
# Index: C
# Tags: combinatorics, dp, implementation, math, trees
#
#
# Problem: Candy Party (Hard Version)
# Contest: 1868
# Index: B2
# Tags: bitmasks, constructive algorithms, dp, greedy, implementation, math
#
#
# Problem: Candy Party (Easy Version)
# Contest: 1868
# Index: B1
# Tags: bitmasks, constructive algorithms, graphs, greedy, implementation, math
#
#
# Problem: Fill in the Matrix
# Contest: 1868
# Index: A
# Tags: constructive algorithms, implementation
#
#
# Problem: Cyclic Operations
# Contest: 1867
# Index: D
# Tags: brute force, constructive algorithms, dfs and similar, graphs, greedy, implementation
#
#
# Problem: Keen Tree Calculation
# Contest: 1866
# Index: K
# Tags: binary search, data structures, dp, geometry, graphs, implementation, trees
#
#
# Problem: Magic Square
# Contest: 1864
# Index: G
# Tags: combinatorics, constructive algorithms, implementation
#
#
# Problem: Exotic Queries
# Contest: 1864
# Index: F
# Tags: data structures, implementation, sortings
#
#
# Problem: Increasing and Decreasing
# Contest: 1864
# Index: A
# Tags: constructive algorithms, greedy, implementation, math
#
#
# Problem: MEX Repetition
# Contest: 1863
# Index: C
# Tags: implementation, math
#
#
# Problem: Channel
# Contest: 1863
# Index: A
# Tags: greedy, implementation
#
#
# Problem: Flower City Fence
# Contest: 1862
# Index: C
# Tags: binary search, data structures, implementation, sortings
#
#
# Problem: Gift Carpet
# Contest: 1862
# Index: A
# Tags: dp, greedy, implementation, strings
#
#
# Problem: Non-Intersecting Subpermutations
# Contest: 1861
# Index: E
# Tags: combinatorics, dp, implementation, math
#
#
# Problem: Queries for the Array
# Contest: 1861
# Index: C
# Tags: data structures, dfs and similar, implementation, strings, trees
#
#
# Problem: Evaluate RBS
# Contest: 1860
# Index: F
# Tags: data structures, geometry, implementation, math, sortings
#
#
# Problem: Maximum Rounding
# Contest: 1857
# Index: B
# Tags: greedy, implementation, math
#
#
# Problem: PermuTree (hard version)
# Contest: 1856
# Index: E2
# Tags: bitmasks, dfs and similar, dp, fft, greedy, implementation, math, trees
#
#
# Problem: Good Arrays
# Contest: 1856
# Index: B
# Tags: implementation, math
#
#
# Problem: Tales of a Sort
# Contest: 1856
# Index: A
# Tags: implementation
#
#
# Problem: Vlad and the Mountains
# Contest: 1851
# Index: G
# Tags: binary search, data structures, dsu, graphs, implementation, sortings, trees, two pointers
#
#
# Problem: Prefix Permutation Sums
# Contest: 1851
# Index: D
# Tags: implementation, math
#
#
# Problem: The Third Letter
# Contest: 1850
# Index: H
# Tags: dfs and similar, dsu, graphs, greedy, implementation
#
#
# Problem: The Morning Star
# Contest: 1850
# Index: G
# Tags: combinatorics, data structures, geometry, implementation, math, sortings
#
#
# Problem: We Were Both Children
# Contest: 1850
# Index: F
# Tags: brute force, implementation, math, number theory
#
#
# Problem: Cardboard for Pictures
# Contest: 1850
# Index: E
# Tags: binary search, geometry, implementation, math
#
#
# Problem: Balanced Round
# Contest: 1850
# Index: D
# Tags: brute force, greedy, implementation, sortings
#
#
# Problem: Word on the Paper
# Contest: 1850
# Index: C
# Tags: implementation, strings
#
#
# Problem: Ten Words of Wisdom
# Contest: 1850
# Index: B
# Tags: implementation, sortings
#
#
# Problem: To My Critics
# Contest: 1850
# Index: A
# Tags: implementation, sortings
#
#
# Problem: Morning Sandwich
# Contest: 1849
# Index: A
# Tags: implementation, math
#
#
# Problem: Vika and Stone Skipping
# Contest: 1848
# Index: E
# Tags: brute force, implementation, math, number theory
#
#
# Problem: Vika and the Bridge
# Contest: 1848
# Index: B
# Tags: binary search, data structures, greedy, implementation, math, sortings
#
#
# Problem: Triangle Platinum?
# Contest: 1847
# Index: E
# Tags: brute force, combinatorics, implementation, interactive, math, probabilities
#
#
# Problem: Professor Higashikata
# Contest: 1847
# Index: D
# Tags: data structures, dsu, greedy, implementation, strings
#
#
# Problem: Rudolph and Mimic
# Contest: 1846
# Index: F
# Tags: constructive algorithms, implementation, interactive
#
#
# Problem: Rudolf and Snowflakes (hard version)
# Contest: 1846
# Index: E2
# Tags: binary search, brute force, implementation, math
#
#
# Problem: Rudolf and Snowflakes (simple version)
# Contest: 1846
# Index: E1
# Tags: brute force, implementation, math
#
#
# Problem: Rudolph and Tic-Tac-Toe
# Contest: 1846
# Index: B
# Tags: brute force, implementation, strings
#
#
# Problem: Rudolph and Cut the Rope
# Contest: 1846
# Index: A
# Tags: implementation, math
#
#
# Problem: Boxes and Balls
# Contest: 1845
# Index: E
# Tags: dp, implementation, math
#
#
# Problem: Come Together
# Contest: 1845
# Index: B
# Tags: geometry, implementation, math
#
#
# Problem: Forbidden Integer
# Contest: 1845
# Index: A
# Tags: constructive algorithms, implementation, math, number theory
#
#
# Problem: Tree Weights
# Contest: 1844
# Index: G
# Tags: bitmasks, constructive algorithms, data structures, dfs and similar, implementation, math, matrices, number theory, trees
#
#
# Problem: Particles
# Contest: 1844
# Index: C
# Tags: dp, greedy, implementation, math
#
#
# Problem: Keep it Beautiful
# Contest: 1841
# Index: B
# Tags: implementation
#
#
# Problem: Character Blocking
# Contest: 1840
# Index: E
# Tags: data structures, hashing, implementation
#
#
# Problem: Cipher Shifer
# Contest: 1840
# Index: A
# Tags: implementation, strings, two pointers
#
#
# Problem: The Good Array
# Contest: 1839
# Index: A
# Tags: greedy, implementation, math
#
#
# Problem: Editorial for Two
# Contest: 1837
# Index: F
# Tags: binary search, data structures, greedy, implementation
#
#
# Problem: Destroyer
# Contest: 1836
# Index: A
# Tags: implementation, sortings
#
#
# Problem: Good Graph
# Contest: 1835
# Index: F
# Tags: bitmasks, dfs and similar, graph matchings, graphs, implementation
#
#
# Problem: k-th equality
# Contest: 1835
# Index: A
# Tags: brute force, implementation, math
#
#
# Problem: MEX of LCM
# Contest: 1834
# Index: E
# Tags: binary search, data structures, implementation, math, number theory
#
#
# Problem: Survey in Class
# Contest: 1834
# Index: D
# Tags: brute force, data structures, greedy, implementation, sortings
#
#
# Problem: Ksyusha and Chinchilla
# Contest: 1833
# Index: G
# Tags: constructive algorithms, dfs and similar, dp, dsu, greedy, implementation, trees
#
#
# Problem: Ira and Flamenco
# Contest: 1833
# Index: F
# Tags: combinatorics, constructive algorithms, data structures, implementation, math, sortings, two pointers
#
#
# Problem: Musical Puzzle
# Contest: 1833
# Index: A
# Tags: implementation, strings
#
#
# Problem: Red-Blue Operations (Hard Version)
# Contest: 1832
# Index: D2
# Tags: binary search, constructive algorithms, greedy, implementation, math
#
#
# Problem: Red-Blue Operations (Easy Version)
# Contest: 1832
# Index: D1
# Tags: binary search, greedy, implementation, math
#
#
# Problem: Contrast Value
# Contest: 1832
# Index: C
# Tags: greedy, implementation
#
#
# Problem: Hits Different
# Contest: 1829
# Index: G
# Tags: data structures, dp, implementation, math
#
#
# Problem: The Lakes
# Contest: 1829
# Index: E
# Tags: dfs and similar, dsu, graphs, implementation
#
#
# Problem: Gold Rush
# Contest: 1829
# Index: D
# Tags: brute force, dfs and similar, dp, implementation
#
#
# Problem: Mr. Perfectly Fine
# Contest: 1829
# Index: C
# Tags: bitmasks, greedy, implementation
#
#
# Problem: Blank Space
# Contest: 1829
# Index: B
# Tags: implementation
#
#
# Problem: Love Story
# Contest: 1829
# Index: A
# Tags: implementation, strings
#
#
# Problem: Walk the Runway
# Contest: 1826
# Index: E
# Tags: bitmasks, brute force, data structures, dp, graphs, implementation, sortings
#
#
# Problem: Trust Nobody
# Contest: 1826
# Index: A
# Tags: brute force, greedy, implementation, sortings
#
#
# Problem: LuoTianyi and the Show
# Contest: 1824
# Index: A
# Tags: greedy, implementation
#
#
# Problem: TubeTube Feed
# Contest: 1822
# Index: A
# Tags: brute force, implementation
#
#
# Problem: Tear It Apart
# Contest: 1821
# Index: C
# Tags: brute force, implementation, math, strings
#
#
# Problem: Yura's New Name
# Contest: 1820
# Index: A
# Tags: implementation, strings
#
#
# Problem: The Fox and the Complete Tree Traversal
# Contest: 1819
# Index: C
# Tags: constructive algorithms, dp, implementation, math, trees
#
#
# Problem: The Butcher
# Contest: 1819
# Index: B
# Tags: geometry, greedy, implementation, sortings, two pointers
#
#
# Problem: Politics
# Contest: 1818
# Index: A
# Tags: greedy, implementation
#
#
# Problem: Toy Machine
# Contest: 1817
# Index: D
# Tags: constructive algorithms, games, implementation
#
#
# Problem: Sum Graph
# Contest: 1815
# Index: B
# Tags: brute force, constructive algorithms, graphs, implementation, interactive, shortest paths, trees
#
#
# Problem: Coins
# Contest: 1814
# Index: A
# Tags: implementation, math
#
#
# Problem: Colour Vision
# Contest: 1812
# Index: G
# Tags: *special, implementation
#
#
# Problem: Was it Rated?
# Contest: 1812
# Index: B
# Tags: *special, *special, *special, brute force, implementation
#
#
# Problem: Is It Flower?
# Contest: 1811
# Index: F
# Tags: dfs and similar, graphs, implementation
#
#
# Problem: Umka and a Long Flight
# Contest: 1811
# Index: D
# Tags: constructive algorithms, implementation, math
#
#
# Problem: Conveyor Belts
# Contest: 1811
# Index: B
# Tags: implementation, math
#
#
# Problem: Traveling in Berland
# Contest: 1809
# Index: F
# Tags: binary search, data structures, graphs, greedy, implementation
#
#
# Problem: Two Tanks
# Contest: 1809
# Index: E
# Tags: binary search, dp, implementation, math
#
#
# Problem: Garland
# Contest: 1809
# Index: A
# Tags: implementation
#
#
# Problem: Unlucky Numbers
# Contest: 1808
# Index: C
# Tags: brute force, dp, greedy, implementation
#
#
# Problem: Lucky Numbers
# Contest: 1808
# Index: A
# Tags: brute force, implementation
#
#
# Problem: Subsequence Addition (Hard Version)
# Contest: 1807
# Index: G2
# Tags: bitmasks, dp, greedy, implementation, sortings
#
#
# Problem: Subsequence Addition (Easy Version)
# Contest: 1807
# Index: G1
# Tags: brute force, data structures, dp, greedy, implementation, sortings
#
#
# Problem: Bouncy Ball
# Contest: 1807
# Index: F
# Tags: brute force, dfs and similar, implementation
#
#
# Problem: Interview
# Contest: 1807
# Index: E
# Tags: binary search, implementation, interactive
#
#
# Problem: Odd Queries
# Contest: 1807
# Index: D
# Tags: data structures, implementation
#
#
# Problem: Find and Replace
# Contest: 1807
# Index: C
# Tags: greedy, implementation, strings
#
#
# Problem: Plus or Minus
# Contest: 1807
# Index: A
# Tags: implementation
#
#
# Problem: Survival of the Weakest (easy version)
# Contest: 1805
# Index: F1
# Tags: binary search, brute force, implementation, math, sortings
#
#
# Problem: Flow Control
# Contest: 1804
# Index: G
# Tags: data structures, dsu, implementation
#
#
# Problem: Accommodation
# Contest: 1804
# Index: D
# Tags: brute force, dp, greedy, implementation
#
#
# Problem: Vaccination
# Contest: 1804
# Index: B
# Tags: greedy, implementation
#
#
# Problem: Settlement of Guinea Pigs
# Contest: 1802
# Index: B
# Tags: greedy, implementation, math
#
#
# Problem: Likes
# Contest: 1802
# Index: A
# Tags: greedy, implementation
#
#
# Problem: Symmetree
# Contest: 1800
# Index: G
# Tags: dfs and similar, hashing, implementation, trees
#
#
# Problem: Is It a Cat?
# Contest: 1800
# Index: A
# Tags: implementation, strings
#
#
# Problem: City Union
# Contest: 1799
# Index: E
# Tags: constructive algorithms, dfs and similar, dsu, geometry, greedy, implementation, math
#
#
# Problem: Recent Actions
# Contest: 1799
# Index: A
# Tags: data structures, greedy, implementation, math
#
#
# Problem: Three Sevens
# Contest: 1798
# Index: B
# Tags: brute force, data structures, greedy, implementation
#
#
# Problem: Showstopper
# Contest: 1798
# Index: A
# Tags: greedy, implementation, sortings
#
#
# Problem: Li Hua and Tree
# Contest: 1797
# Index: D
# Tags: brute force, data structures, dfs and similar, dp, implementation, trees
#
#
# Problem: Li Hua and Maze
# Contest: 1797
# Index: A
# Tags: constructive algorithms, flows, graphs, greedy, implementation
#
#
# Problem: Asterisk-Minor Template
# Contest: 1796
# Index: B
# Tags: implementation, strings
#
#
# Problem: Typical Interview Problem
# Contest: 1796
# Index: A
# Tags: brute force, implementation, strings
#
#
# Problem: Tea Tasting
# Contest: 1795
# Index: C
# Tags: binary search, data structures, implementation
#
#
# Problem: Two Towers
# Contest: 1795
# Index: A
# Tags: brute force, implementation, strings
#
#
# Problem: Labeling the Tree with Distances
# Contest: 1794
# Index: E
# Tags: data structures, dp, greedy, hashing, implementation, trees
#
#
# Problem: Rebrending
# Contest: 1793
# Index: F
# Tags: brute force, data structures, divide and conquer, implementation
#
#
# Problem: Moscow Gorillas
# Contest: 1793
# Index: D
# Tags: binary search, dp, greedy, implementation, math, two pointers
#
#
# Problem: Prepend and Append
# Contest: 1791
# Index: C
# Tags: implementation, two pointers
#
#
# Problem: Following Directions
# Contest: 1791
# Index: B
# Tags: geometry, implementation
#
#
# Problem: Codeforces Checking
# Contest: 1791
# Index: A
# Tags: implementation, strings
#
#
# Problem: Premutation
# Contest: 1790
# Index: C
# Tags: brute force, implementation, math
#
#
# Problem: Polycarp and the Day of Pi
# Contest: 1790
# Index: A
# Tags: implementation, math, strings
#
#
# Problem: Serval and Brain Power
# Contest: 1789
# Index: F
# Tags: bitmasks, brute force, dp, greedy, implementation, strings
#
#
# Problem: Serval and Music Game
# Contest: 1789
# Index: E
# Tags: brute force, dp, implementation, math, number theory
#
#
# Problem: Serval and Shift-Shift-Shift
# Contest: 1789
# Index: D
# Tags: bitmasks, brute force, constructive algorithms, implementation
#
#
# Problem: Serval and Toxel's Arrays
# Contest: 1789
# Index: C
# Tags: combinatorics, dp, implementation, math
#
#
# Problem: Serval and Inversion Magic
# Contest: 1789
# Index: B
# Tags: brute force, implementation, strings, two pointers
#
#
# Problem: XOR, Tree, and Queries
# Contest: 1788
# Index: F
# Tags: bitmasks, constructive algorithms, dfs and similar, dsu, graphs, greedy, implementation, trees
#
#
# Problem: Sum of Two Numbers
# Contest: 1788
# Index: B
# Tags: constructive algorithms, greedy, implementation, math, probabilities
#
#
# Problem: One and Two
# Contest: 1788
# Index: A
# Tags: brute force, implementation, math
#
#
# Problem: Inverse Transformation
# Contest: 1787
# Index: F
# Tags: constructive algorithms, implementation, math
#
#
# Problem: Game on Axis
# Contest: 1787
# Index: D
# Tags: combinatorics, dfs and similar, dsu, graphs, implementation
#
#
# Problem: Alternating Deck (hard version)
# Contest: 1786
# Index: A2
# Tags: implementation
#
#
# Problem: Non-alternating Deck (easy version)
# Contest: 1786
# Index: A1
# Tags: implementation
#
#
# Problem: Weighed Tree Radius
# Contest: 1783
# Index: G
# Tags: data structures, divide and conquer, implementation, trees
#
#
# Problem: Different Arrays
# Contest: 1783
# Index: D
# Tags: brute force, dp, implementation
#
#
# Problem: Rectangle Shrinking
# Contest: 1781
# Index: E
# Tags: binary search, brute force, data structures, greedy, implementation, two pointers
#
#
# Problem: Equal Frequencies
# Contest: 1781
# Index: C
# Tags: brute force, constructive algorithms, greedy, implementation, sortings, strings
#
#
# Problem: Flip Flop Sum
# Contest: 1778
# Index: A
# Tags: greedy, implementation
#
#
# Problem: The Human Equation
# Contest: 1775
# Index: E
# Tags: greedy, implementation
#
#
# Problem: Gardener and the Capybaras (easy version)
# Contest: 1775
# Index: A1
# Tags: brute force, constructive algorithms, implementation
#
#
# Problem: Magician and Pigs (Hard Version)
# Contest: 1774
# Index: F2
# Tags: binary search, brute force, data structures, implementation
#
#
# Problem: Magician and Pigs (Easy Version)
# Contest: 1774
# Index: F1
# Tags: brute force, data structures, implementation
#
#
# Problem: Same Count One
# Contest: 1774
# Index: D
# Tags: brute force, constructive algorithms, greedy, implementation, two pointers
#
#
# Problem: Interactive Factorial Guessing
# Contest: 1773
# Index: I
# Tags: brute force, games, implementation, interactive
#
#
# Problem: BinCoin
# Contest: 1773
# Index: B
# Tags: binary search, divide and conquer, hashing, implementation, probabilities, trees
#
#
# Problem: Gaining Rating
# Contest: 1772
# Index: G
# Tags: binary search, greedy, implementation, math, sortings, two pointers
#
#
# Problem: Copy of a Copy of a Copy
# Contest: 1772
# Index: F
# Tags: constructive algorithms, dfs and similar, graphs, implementation, sortings
#
#
# Problem: Matrix Rotation
# Contest: 1772
# Index: B
# Tags: brute force, implementation
#
#
# Problem: A+B?
# Contest: 1772
# Index: A
# Tags: implementation
#
#
# Problem: Hossam and a Letter
# Contest: 1771
# Index: E
# Tags: brute force, dp, implementation, two pointers
#
#
# Problem: Koxia and Game
# Contest: 1770
# Index: D
# Tags: constructive algorithms, data structures, dfs and similar, dsu, flows, games, graph matchings, graphs, implementation
#
#
# Problem: Копирование файлов I
# Contest: 1769
# Index: B1
# Tags: *special, brute force, implementation, math
#
#
# Problem: Elemental Decompress
# Contest: 1768
# Index: C
# Tags: constructive algorithms, greedy, implementation, sortings
#
#
# Problem: Cut the Triangle
# Contest: 1767
# Index: A
# Tags: implementation
#
#
# Problem: Hamiltonian Wall
# Contest: 1766
# Index: C
# Tags: dp, implementation
#
#
# Problem: Notepad#
# Contest: 1766
# Index: B
# Tags: implementation
#
#
# Problem: Extremely Round
# Contest: 1766
# Index: A
# Tags: brute force, implementation
#
#
# Problem: Project Manager
# Contest: 1765
# Index: L
# Tags: brute force, data structures, implementation
#
#
# Problem: Infinite Chess
# Contest: 1765
# Index: I
# Tags: implementation, shortest paths
#
#
# Problem: Hospital Queue
# Contest: 1765
# Index: H
# Tags: binary search, graphs, greedy, implementation
#
#
# Problem: Valid Bitonic Permutations
# Contest: 1763
# Index: D
# Tags: combinatorics, dp, implementation, math, number theory
#
#
# Problem: Incinerate
# Contest: 1763
# Index: B
# Tags: binary search, brute force, data structures, implementation, math, sortings
#
#
# Problem: Make Array Good
# Contest: 1762
# Index: B
# Tags: constructive algorithms, implementation, number theory, sortings
#
#
# Problem: Elimination of a Ring
# Contest: 1761
# Index: B
# Tags: constructive algorithms, greedy, implementation
#
#
# Problem: Challenging Valleys
# Contest: 1760
# Index: D
# Tags: implementation, two pointers
#
#
# Problem: Advantage
# Contest: 1760
# Index: C
# Tags: data structures, implementation, sortings
#
#
# Problem: Atilla's Favorite Problem
# Contest: 1760
# Index: B
# Tags: greedy, implementation, strings
#
#
# Problem: Medium Number
# Contest: 1760
# Index: A
# Tags: implementation, sortings
#
#
# Problem: Yes-Yes?
# Contest: 1759
# Index: A
# Tags: implementation, strings
#
#
# Problem: Complementary XOR
# Contest: 1750
# Index: C
# Tags: constructive algorithms, implementation
#
#
# Problem: Maximum Substring
# Contest: 1750
# Index: B
# Tags: brute force, greedy, implementation
#
#
# Problem: Indirect Sort
# Contest: 1750
# Index: A
# Tags: constructive algorithms, implementation, math
#
#
# Problem: Number Game
# Contest: 1749
# Index: C
# Tags: binary search, data structures, games, greedy, implementation
#
#
# Problem: Cowardly Rooks
# Contest: 1749
# Index: A
# Tags: greedy, implementation
#
#
# Problem: Zero-Sum Prefixes
# Contest: 1748
# Index: C
# Tags: brute force, data structures, dp, greedy, implementation
#
#
# Problem: Diverse Substrings
# Contest: 1748
# Index: B
# Tags: brute force, implementation, strings
#
#
# Problem: Olympiad Training
# Contest: 1746
# Index: G
# Tags: binary search, data structures, dp, flows, geometry, implementation, sortings
#
#
# Problem: Permutation Operations
# Contest: 1746
# Index: C
# Tags: constructive algorithms, greedy, implementation, math
#
#
# Problem: Traffic Light
# Contest: 1744
# Index: C
# Tags: binary search, implementation, two pointers
#
#
# Problem: Even-Odd Increments
# Contest: 1744
# Index: B
# Tags: implementation, math
#
#
# Problem: Number Replacement
# Contest: 1744
# Index: A
# Tags: greedy, implementation
#
#
# Problem: Password
# Contest: 1743
# Index: A
# Tags: brute force, combinatorics, implementation, math
#
#
# Problem: Stripes
# Contest: 1742
# Index: C
# Tags: implementation
#
#
# Problem: Increasing
# Contest: 1742
# Index: B
# Tags: greedy, implementation, sortings
#
#
# Problem: Sum
# Contest: 1742
# Index: A
# Tags: implementation
#
#
# Problem: Compare T-Shirt Sizes
# Contest: 1741
# Index: A
# Tags: implementation, implementation, strings
#
#
# Problem: Immobile Knight
# Contest: 1739
# Index: A
# Tags: implementation
#
#
# Problem: Glory Addicts
# Contest: 1738
# Index: A
# Tags: greedy, implementation, sortings
#
#
# Problem: Ela and the Wiring Wizard
# Contest: 1737
# Index: D
# Tags: brute force, dp, graphs, greedy, implementation, shortest paths
#
#
# Problem: Ela and Crickets
# Contest: 1737
# Index: C
# Tags: constructive algorithms, games, implementation, math
#
#
# Problem: Ela's Fitness and the Luxury Number
# Contest: 1737
# Index: B
# Tags: binary search, implementation, math
#
#
# Problem: Ela Sorting Books
# Contest: 1737
# Index: A
# Tags: greedy, implementation, strings
#
#
# Problem: Equal Binary Subsequences
# Contest: 1736
# Index: D
# Tags: constructive algorithms, geometry, greedy, implementation, strings
#
#
# Problem: Phase Shift
# Contest: 1735
# Index: C
# Tags: dfs and similar, dsu, graphs, greedy, implementation, strings
#
#
# Problem: Balance (Easy version)
# Contest: 1732
# Index: D1
# Tags: brute force, data structures, implementation, number theory
#
#
# Problem: Sheikh (Hard Version)
# Contest: 1732
# Index: C2
# Tags: binary search, bitmasks, brute force, greedy, implementation, two pointers
#
#
# Problem: Ugu
# Contest: 1732
# Index: B
# Tags: brute force, dp, greedy, implementation
#
#
# Problem: Bestie
# Contest: 1732
# Index: A
# Tags: brute force, combinatorics, constructive algorithms, implementation, math, number theory
#
#
# Problem: Meeting on the Line
# Contest: 1730
# Index: B
# Tags: binary search, geometry, greedy, implementation, math, ternary search
#
#
# Problem: Colored Balls: Revisited
# Contest: 1728
# Index: A
# Tags: brute force, greedy, implementation, sortings
#
#
# Problem: Mainak and the Bleeding Polygon
# Contest: 1726
# Index: H
# Tags: binary search, geometry, implementation, math
#
#
# Problem: L-shapes
# Contest: 1722
# Index: F
# Tags: dfs and similar, implementation
#
#
# Problem: Counting Rectangles
# Contest: 1722
# Index: E
# Tags: brute force, data structures, dp, implementation
#
#
# Problem: Word Game
# Contest: 1722
# Index: C
# Tags: data structures, implementation
#
#
# Problem: Colourblindness
# Contest: 1722
# Index: B
# Tags: implementation
#
#
# Problem: Spell Check
# Contest: 1722
# Index: A
# Tags: implementation
#
#
# Problem: Deadly Laser
# Contest: 1721
# Index: B
# Tags: implementation
#
#
# Problem: Image
# Contest: 1721
# Index: A
# Tags: greedy, implementation
#
#
# Problem: Misha and Paintings
# Contest: 1720
# Index: E
# Tags: constructive algorithms, data structures, greedy, implementation, math
#
#
# Problem: Corners
# Contest: 1720
# Index: C
# Tags: greedy, implementation
#
#
# Problem: Fighting Tournament
# Contest: 1719
# Index: C
# Tags: binary search, data structures, implementation, two pointers
#
#
# Problem: Impressionism
# Contest: 1718
# Index: E
# Tags: constructive algorithms, graphs, implementation, math
#
#
# Problem: Fibonacci Strings
# Contest: 1718
# Index: B
# Tags: greedy, implementation, math, number theory
#
#
# Problem: Madoka and The First Session
# Contest: 1717
# Index: F
# Tags: constructive algorithms, flows, graph matchings, graphs, implementation
#
#
# Problem: Madoka and Underground Competitions
# Contest: 1717
# Index: B
# Tags: constructive algorithms, implementation
#
#
# Problem: Robot in a Hallway
# Contest: 1716
# Index: C
# Tags: data structures, dp, greedy, implementation, ternary search
#
#
# Problem: Monoblock
# Contest: 1715
# Index: C
# Tags: combinatorics, data structures, implementation, math
#
#
# Problem: Build a Tree and That Is It
# Contest: 1714
# Index: F
# Tags: constructive algorithms, implementation, trees
#
#
# Problem: Remove Prefix
# Contest: 1714
# Index: B
# Tags: data structures, greedy, implementation
#
#
# Problem: Everyone Loves to Sleep
# Contest: 1714
# Index: A
# Tags: implementation, math
#
#
# Problem: Traveling Salesman Problem
# Contest: 1713
# Index: A
# Tags: geometry, greedy, implementation
#
#
# Problem: Wonderful Permutation
# Contest: 1712
# Index: A
# Tags: greedy, implementation
#
#
# Problem: Rain
# Contest: 1710
# Index: B
# Tags: binary search, brute force, data structures, geometry, greedy, implementation, math
#
#
# Problem: Recover an RBS
# Contest: 1709
# Index: C
# Tags: constructive algorithms, greedy, implementation, strings
#
#
# Problem: Also Try Minecraft
# Contest: 1709
# Index: B
# Tags: data structures, dp, implementation
#
#
# Problem: Three Doors
# Contest: 1709
# Index: A
# Tags: brute force, greedy, implementation, math
#
#
# Problem: Difference Array
# Contest: 1707
# Index: B
# Tags: brute force, data structures, implementation, sortings
#
#
# Problem: Doremy's IQ
# Contest: 1707
# Index: A
# Tags: binary search, constructive algorithms, greedy, implementation
#
#
# Problem: Qpwoeirut And The City
# Contest: 1706
# Index: C
# Tags: dp, flows, greedy, implementation
#
#
# Problem: Mark and His Unfinished Essay
# Contest: 1705
# Index: C
# Tags: brute force, implementation
#
#
# Problem: Mark the Dust Sweeper
# Contest: 1705
# Index: B
# Tags: constructive algorithms, greedy, implementation
#
#
# Problem: Count Seconds
# Contest: 1704
# Index: E
# Tags: brute force, constructive algorithms, dp, graphs, implementation, math
#
#
# Problem: Magical Array
# Contest: 1704
# Index: D
# Tags: constructive algorithms, hashing, implementation, math
#
#
# Problem: Virus
# Contest: 1704
# Index: C
# Tags: greedy, implementation, sortings
#
#
# Problem: Luke is a Foodie
# Contest: 1704
# Index: B
# Tags: brute force, greedy, implementation
#
#
# Problem: Mirror Grid
# Contest: 1703
# Index: E
# Tags: implementation
#
#
# Problem: Cypher
# Contest: 1703
# Index: C
# Tags: brute force, implementation, strings
#
#
# Problem: ICPC Balloons
# Contest: 1703
# Index: B
# Tags: data structures, implementation
#
#
# Problem: YES or YES?
# Contest: 1703
# Index: A
# Tags: brute force, implementation, strings
#
#
# Problem: Points
# Contest: 1701
# Index: F
# Tags: combinatorics, data structures, implementation, math, matrices
#
#
# Problem: Schedule Management
# Contest: 1701
# Index: C
# Tags: binary search, greedy, implementation, two pointers
#
#
# Problem: Grass Field
# Contest: 1701
# Index: A
# Tags: implementation
#
#
# Problem: Palindromic Numbers
# Contest: 1700
# Index: B
# Tags: constructive algorithms, implementation, math
#
#
# Problem: Equal Reversal
# Contest: 1698
# Index: F
# Tags: constructive algorithms, graphs, implementation, math
#
#
# Problem: Rising Sand
# Contest: 1698
# Index: B
# Tags: constructive algorithms, greedy, implementation
#
#
# Problem: Too Many Constraints
# Contest: 1697
# Index: F
# Tags: 2-sat, constructive algorithms, graphs, implementation
#
#
# Problem: Coloring
# Contest: 1697
# Index: E
# Tags: brute force, combinatorics, constructive algorithms, dp, geometry, graphs, greedy, implementation, math
#
#
# Problem: awoo's Favorite Problem
# Contest: 1697
# Index: C
# Tags: binary search, constructive algorithms, data structures, greedy, implementation, strings, two pointers
#
#
# Problem: Parkway Walk
# Contest: 1697
# Index: A
# Tags: greedy, implementation
#
#
# Problem: Maximum Product?
# Contest: 1696
# Index: H
# Tags: brute force, combinatorics, dp, greedy, implementation, math, two pointers
#
#
# Problem: Fishingprince Plays With Array
# Contest: 1696
# Index: C
# Tags: constructive algorithms, greedy, implementation, math
#
#
# Problem: Creep
# Contest: 1694
# Index: A
# Tags: greedy, implementation
#
#
# Problem: Binary Deque
# Contest: 1692
# Index: E
# Tags: binary search, implementation, two pointers
#
#
# Problem: The Clock
# Contest: 1692
# Index: D
# Tags: brute force, implementation
#
#
# Problem: Where's the Bishop?
# Contest: 1692
# Index: C
# Tags: implementation
#
#
# Problem: Marathon
# Contest: 1692
# Index: A
# Tags: implementation
#
#
# Problem: Max GEQ Sum
# Contest: 1691
# Index: D
# Tags: binary search, constructive algorithms, data structures, divide and conquer, implementation, two pointers
#
#
# Problem: Shoe Shuffling
# Contest: 1691
# Index: B
# Tags: constructive algorithms, greedy, implementation, two pointers
#
#
# Problem: Black and White Stripe
# Contest: 1690
# Index: D
# Tags: implementation, two pointers
#
#
# Problem: Restoring the Duration of Tasks
# Contest: 1690
# Index: C
# Tags: data structures, greedy, implementation
#
#
# Problem: Array Decrements
# Contest: 1690
# Index: B
# Tags: greedy, implementation
#
#
# Problem: Lex String
# Contest: 1689
# Index: A
# Tags: brute force, greedy, implementation, sortings, two pointers
#
#
# Problem: Cute number
# Contest: 1687
# Index: D
# Tags: binary search, brute force, data structures, dsu, implementation, math
#
#
# Problem: Linguistics
# Contest: 1685
# Index: B
# Tags: greedy, implementation, sortings, strings
#
#
# Problem: Column Swapping
# Contest: 1684
# Index: C
# Tags: brute force, constructive algorithms, greedy, implementation, sortings
#
#
# Problem: Circular Spanning Tree
# Contest: 1682
# Index: D
# Tags: constructive algorithms, implementation, trees
#
#
# Problem: LIS or Reverse LIS?
# Contest: 1682
# Index: C
# Tags: constructive algorithms, greedy, implementation, math
#
#
# Problem: Double Sort
# Contest: 1681
# Index: C
# Tags: implementation, sortings
#
#
# Problem: Card Trick
# Contest: 1681
# Index: B
# Tags: implementation, math
#
#
# Problem: Robots
# Contest: 1680
# Index: B
# Tags: implementation
#
#
# Problem: Rooks Defenders
# Contest: 1679
# Index: C
# Tags: data structures, implementation
#
#
# Problem: Stone Age Problem
# Contest: 1679
# Index: B
# Tags: data structures, implementation
#
#
# Problem: Tokitsukaze and Good 01-String (hard version)
# Contest: 1678
# Index: B2
# Tags: dp, greedy, implementation
#
#
# Problem: Tokitsukaze and Good 01-String (easy version)
# Contest: 1678
# Index: B1
# Tags: implementation
#
#
# Problem: Tokitsukaze and All Zero Sequence
# Contest: 1678
# Index: A
# Tags: implementation
#
#
# Problem: Tokitsukaze and Meeting
# Contest: 1677
# Index: B
# Tags: data structures, implementation, math
#
#
# Problem: Longest Strike
# Contest: 1676
# Index: F
# Tags: data structures, greedy, implementation, sortings, two pointers
#
#
# Problem: X-Sum
# Contest: 1676
# Index: D
# Tags: brute force, greedy, implementation
#
#
# Problem: Most Similar Words
# Contest: 1676
# Index: C
# Tags: brute force, greedy, implementation, implementation, math, strings
#
#
# Problem: Lucky?
# Contest: 1676
# Index: A
# Tags: implementation
#
#
# Problem: Vertical Paths
# Contest: 1675
# Index: D
# Tags: graphs, implementation, trees
#
#
# Problem: Detective Task
# Contest: 1675
# Index: C
# Tags: implementation
#
#
# Problem: Make It Increasing
# Contest: 1675
# Index: B
# Tags: greedy, implementation
#
#
# Problem: Desktop Rearrangement
# Contest: 1674
# Index: F
# Tags: data structures, greedy, implementation
#
#
# Problem: A-B-C Sort
# Contest: 1674
# Index: D
# Tags: constructive algorithms, implementation, sortings
#
#
# Problem: Infinite Replacement
# Contest: 1674
# Index: C
# Tags: combinatorics, implementation, strings
#
#
# Problem: Cyclic Rotation
# Contest: 1672
# Index: D
# Tags: constructive algorithms, greedy, implementation, two pointers
#
#
# Problem: Unequal Array
# Contest: 1672
# Index: C
# Tags: constructive algorithms, greedy, implementation
#
#
# Problem: I love AAAB
# Contest: 1672
# Index: B
# Tags: constructive algorithms, implementation
#
#
# Problem: Log Chopping
# Contest: 1672
# Index: A
# Tags: games, implementation, math
#
#
# Problem: String Building
# Contest: 1671
# Index: A
# Tags: implementation
#
#
# Problem: Very Suspicious
# Contest: 1670
# Index: D
# Tags: binary search, brute force, geometry, greedy, implementation, math
#
#
# Problem: Where is the Pizza?
# Contest: 1670
# Index: C
# Tags: data structures, dfs and similar, dsu, graphs, implementation, math
#
#
# Problem: Dorms War
# Contest: 1670
# Index: B
# Tags: brute force, implementation, strings
#
#
# Problem: Prof. Slim
# Contest: 1670
# Index: A
# Tags: greedy, implementation, sortings
#
#
# Problem: Fall Down
# Contest: 1669
# Index: G
# Tags: dfs and similar, implementation
#
#
# Problem: Colorful Stamp
# Contest: 1669
# Index: D
# Tags: implementation
#
#
# Problem: Odd/Even Increments
# Contest: 1669
# Index: C
# Tags: greedy, greedy, implementation, math
#
#
# Problem: Triple
# Contest: 1669
# Index: B
# Tags: implementation, sortings
#
#
# Problem: Division?
# Contest: 1669
# Index: A
# Tags: implementation
#
#
# Problem: Direction Change
# Contest: 1668
# Index: A
# Tags: implementation, math
#
#
# Problem: Yin Yang
# Contest: 1667
# Index: F
# Tags: implementation
#
#
# Problem: Fancy Stack
# Contest: 1666
# Index: F
# Tags: combinatorics, dp, implementation
#
#
# Problem: MinimizOR
# Contest: 1665
# Index: E
# Tags: bitmasks, brute force, data structures, divide and conquer, greedy, implementation, two pointers
#
#
# Problem: Are You Safe?
# Contest: 1663
# Index: E
# Tags: *special, implementation
#
#
# Problem: Pōja Verdon
# Contest: 1663
# Index: C
# Tags: *special, implementation, math
#
#
# Problem: Mike's Sequence
# Contest: 1663
# Index: B
# Tags: *special, divide and conquer, implementation, math
#
#
# Problem: Circular Maze
# Contest: 1662
# Index: O
# Tags: brute force, dfs and similar, graphs, implementation
#
#
# Problem: Ice Cream Shop
# Contest: 1662
# Index: I
# Tags: brute force, implementation, sortings
#
#
# Problem: Antennas
# Contest: 1662
# Index: F
# Tags: data structures, dfs and similar, graphs, graphs, implementation, implementation, shortest paths, shortest paths
#
#
# Problem: Evolution of Weasels
# Contest: 1662
# Index: D
# Tags: greedy, implementation, strings
#
#
# Problem: Organizing SWERC
# Contest: 1662
# Index: A
# Tags: brute force, implementation
#
#
# Problem: Promising String (hard version)
# Contest: 1660
# Index: F2
# Tags: data structures, implementation, math, strings
#
#
# Problem: Promising String (easy version)
# Contest: 1660
# Index: F1
# Tags: brute force, implementation, math, strings
#
#
# Problem: Matrix and Shifts
# Contest: 1660
# Index: E
# Tags: brute force, constructive algorithms, greedy, implementation
#
#
# Problem: Maximum Product Strikes Back
# Contest: 1660
# Index: D
# Tags: brute force, implementation, math, two pointers
#
#
# Problem: Reverse Sort Sum
# Contest: 1659
# Index: D
# Tags: constructive algorithms, data structures, greedy, implementation, math, two pointers
#
#
# Problem: Line Empire
# Contest: 1659
# Index: C
# Tags: binary search, brute force, dp, greedy, implementation, math
#
#
# Problem: Red Versus Blue
# Contest: 1659
# Index: A
# Tags: constructive algorithms, greedy, implementation, math
#
#
# Problem: Gojou and Matrix Game
# Contest: 1658
# Index: E
# Tags: data structures, dp, games, hashing, implementation, math, number theory, sortings
#
#
# Problem: Marin and Photoshoot
# Contest: 1658
# Index: A
# Tags: constructive algorithms, implementation, math
#
#
# Problem: Bracket Sequence Deletion
# Contest: 1657
# Index: C
# Tags: greedy, implementation
#
#
# Problem: Alice and the Cake
# Contest: 1654
# Index: C
# Tags: data structures, greedy, implementation, sortings
#
#
# Problem: Maximum Cake Tastiness
# Contest: 1654
# Index: A
# Tags: brute force, greedy, implementation, sortings
#
#
# Problem: Fault-tolerant Network
# Contest: 1651
# Index: C
# Tags: brute force, data structures, implementation
#
#
# Problem: Playoff
# Contest: 1651
# Index: A
# Tags: implementation
#
#
# Problem: Vitaly and Advanced Useless Algorithms
# Contest: 1650
# Index: F
# Tags: dp, greedy, implementation
#
#
# Problem: Rescheduling the Exam
# Contest: 1650
# Index: E
# Tags: binary search, data structures, greedy, implementation, math, sortings
#
#
# Problem: Twist the Permutation
# Contest: 1650
# Index: D
# Tags: brute force, constructive algorithms, implementation, math
#
#
# Problem: Weight of the System of Nested Segments
# Contest: 1650
# Index: C
# Tags: greedy, hashing, implementation, sortings
#
#
# Problem: Deletions of Two Adjacent Letters
# Contest: 1650
# Index: A
# Tags: implementation, strings
#
#
# Problem: Game of Ball Passing
# Contest: 1649
# Index: B
# Tags: greedy, implementation
#
#
# Problem: Game
# Contest: 1649
# Index: A
# Tags: implementation
#
#
# Problem: Air Reform
# Contest: 1648
# Index: E
# Tags: data structures, dfs and similar, divide and conquer, dsu, graphs, implementation, trees
#
#
# Problem: Serious Business
# Contest: 1648
# Index: D
# Tags: data structures, divide and conquer, dp, implementation, shortest paths
#
#
# Problem: Tyler and Strings
# Contest: 1648
# Index: C
# Tags: combinatorics, data structures, implementation
#
#
# Problem: Madoka and the Elegant Gift
# Contest: 1647
# Index: B
# Tags: brute force, constructive algorithms, graphs, implementation
#
#
# Problem: Madoka and Math Dad
# Contest: 1647
# Index: A
# Tags: implementation, math
#
#
# Problem: Playing Around the Table
# Contest: 1646
# Index: F
# Tags: constructive algorithms, greedy, implementation
#
#
# Problem: Weight the Tree
# Contest: 1646
# Index: D
# Tags: constructive algorithms, dfs and similar, dp, implementation, trees
#
#
# Problem: Expand the Path
# Contest: 1644
# Index: E
# Tags: brute force, combinatorics, data structures, implementation, math
#
#
# Problem: Cross Coloring
# Contest: 1644
# Index: D
# Tags: data structures, implementation, math
#
#
# Problem: Increase Subarray Sums
# Contest: 1644
# Index: C
# Tags: brute force, dp, greedy, implementation
#
#
# Problem: Anti-Fibonacci Permutation
# Contest: 1644
# Index: B
# Tags: brute force, constructive algorithms, implementation
#
#
# Problem: Doors and Keys
# Contest: 1644
# Index: A
# Tags: implementation
#
#
# Problem: Repetitions Decoding
# Contest: 1641
# Index: B
# Tags: constructive algorithms, implementation, sortings
#
#
# Problem: Colorful Operations
# Contest: 1638
# Index: E
# Tags: brute force, data structures, implementation
#
#
# Problem: Big Brush
# Contest: 1638
# Index: D
# Tags: constructive algorithms, data structures, greedy, implementation
#
#
# Problem: Best Pair
# Contest: 1637
# Index: E
# Tags: binary search, brute force, implementation
#
#
# Problem: Andrew and Stones
# Contest: 1637
# Index: C
# Tags: greedy, implementation
#
#
# Problem: Fibonacci Additions
# Contest: 1634
# Index: F
# Tags: brute force, data structures, hashing, implementation, math
#
#
# Problem: ABC
# Contest: 1632
# Index: A
# Tags: implementation
#
#
# Problem: Grid Xor
# Contest: 1628
# Index: C
# Tags: constructive algorithms, greedy, implementation, interactive, math
#
#
# Problem: Meximum Array
# Contest: 1628
# Index: A
# Tags: binary search, constructive algorithms, greedy, implementation, math, two pointers
#
#
# Problem: Not Splitting
# Contest: 1627
# Index: F
# Tags: geometry, graphs, greedy, implementation, shortest paths
#
#
# Problem: Not Escaping
# Contest: 1627
# Index: E
# Tags: data structures, dp, implementation, shortest paths, two pointers
#
#
# Problem: Not Shading
# Contest: 1627
# Index: A
# Tags: constructive algorithms, implementation
#
#
# Problem: Monsters And Spells
# Contest: 1626
# Index: C
# Tags: binary search, data structures, dp, greedy, implementation, math, two pointers
#
#
# Problem: Binary Spiders
# Contest: 1625
# Index: D
# Tags: bitmasks, data structures, implementation, math, sortings, trees
#
#
# Problem: Masha-forgetful
# Contest: 1624
# Index: E
# Tags: brute force, constructive algorithms, dp, hashing, implementation, strings
#
#
# Problem: Make AP
# Contest: 1624
# Index: B
# Tags: implementation, math
#
#
# Problem: Robot Cleaner Revisit
# Contest: 1623
# Index: D
# Tags: implementation, math, probabilities
#
#
# Problem: Game on Ranges
# Contest: 1623
# Index: B
# Tags: brute force, dfs and similar, implementation, sortings
#
#
# Problem: Robot Cleaner
# Contest: 1623
# Index: A
# Tags: brute force, implementation, math
#
#
# Problem: Strange Instructions
# Contest: 1621
# Index: F
# Tags: data structures, greedy, implementation
#
#
# Problem: New School
# Contest: 1621
# Index: E
# Tags: binary search, data structures, dp, greedy, implementation, sortings
#
#
# Problem: Integers Shop
# Contest: 1621
# Index: B
# Tags: data structures, greedy, implementation
#
#
# Problem: Replace the Numbers
# Contest: 1620
# Index: E
# Tags: constructive algorithms, data structures, dsu, implementation
#
#
# Problem: BA-String
# Contest: 1620
# Index: C
# Tags: brute force, dp, greedy, implementation, math
#
#
# Problem: Equal or Not Equal
# Contest: 1620
# Index: A
# Tags: constructive algorithms, dsu, implementation
#
#
# Problem: MEX and Increments
# Contest: 1619
# Index: E
# Tags: constructive algorithms, data structures, dp, greedy, implementation, math, sortings
#
#
# Problem: Wrong Addition
# Contest: 1619
# Index: C
# Tags: implementation
#
#
# Problem: Squares and Cubes
# Contest: 1619
# Index: B
# Tags: implementation, math
#
#
# Problem: Square String?
# Contest: 1619
# Index: A
# Tags: implementation, strings
#
#
# Problem: Reverse
# Contest: 1618
# Index: F
# Tags: bitmasks, constructive algorithms, dfs and similar, implementation, math, strings
#
#
# Problem: Missing Bigram
# Contest: 1618
# Index: B
# Tags: implementation
#
#
# Problem: Christmas Chocolates
# Contest: 1617
# Index: E
# Tags: dfs and similar, dp, games, graphs, implementation, math, number theory, shortest paths, trees
#
#
# Problem: Too Many Impostors (hard version)
# Contest: 1617
# Index: D2
# Tags: constructive algorithms, implementation, interactive, math
#
#
# Problem: Too Many Impostors (easy version)
# Contest: 1617
# Index: D1
# Tags: constructive algorithms, implementation, interactive
#
#
# Problem: Representative Edges
# Contest: 1616
# Index: C
# Tags: brute force, geometry, implementation, math
#
#
# Problem: Integer Diversity
# Contest: 1616
# Index: A
# Tags: implementation
#
#
# Problem: Absent Remainder
# Contest: 1613
# Index: B
# Tags: greedy, implementation, sortings
#
#
# Problem: Long Comparison
# Contest: 1613
# Index: A
# Tags: implementation, math
#
#
# Problem: AmShZ and G.O.A.T.
# Contest: 1610
# Index: E
# Tags: binary search, brute force, greedy, implementation, math
#
#
# Problem: Social Network
# Contest: 1609
# Index: D
# Tags: dsu, graphs, greedy, implementation, trees
#
#
# Problem: Complex Market Analysis
# Contest: 1609
# Index: C
# Tags: binary search, dp, implementation, number theory, schedules, two pointers
#
#
# Problem: William the Vigilant
# Contest: 1609
# Index: B
# Tags: implementation, strings
#
#
# Problem: Divide and Multiply
# Contest: 1609
# Index: A
# Tags: greedy, implementation, math, number theory
#
#
# Problem: MEX counting
# Contest: 1608
# Index: F
# Tags: combinatorics, dp, implementation
#
#
# Problem: The Cells on the Paper
# Contest: 1608
# Index: E
# Tags: binary search, implementation, sortings
#
#
# Problem: Robot on the Board 2
# Contest: 1607
# Index: F
# Tags: brute force, dfs and similar, graphs, implementation
#
#
# Problem: Robot on the Board 1
# Contest: 1607
# Index: E
# Tags: implementation
#
#
# Problem: Linear Keyboard
# Contest: 1607
# Index: A
# Tags: implementation, strings
#
#
# Problem: Red-Blue Matrix
# Contest: 1606
# Index: D
# Tags: brute force, constructive algorithms, implementation, sortings
#
#
# Problem: Update Files
# Contest: 1606
# Index: B
# Tags: greedy, implementation, math
#
#
# Problem: Array Equalizer
# Contest: 1605
# Index: E
# Tags: binary search, greedy, implementation, math, number theory, sortings, two pointers
#
#
# Problem: Treelabeling
# Contest: 1605
# Index: D
# Tags: bitmasks, constructive algorithms, dfs and similar, games, greedy, implementation, trees
#
#
# Problem: Dominant Character
# Contest: 1605
# Index: C
# Tags: brute force, greedy, implementation, strings
#
#
# Problem: October 18, 2017
# Contest: 1603
# Index: F
# Tags: combinatorics, dp, implementation, math
#
#
# Problem: Divine Array
# Contest: 1602
# Index: B
# Tags: constructive algorithms, implementation
#
#
# Problem: Two Subsequences
# Contest: 1602
# Index: A
# Tags: implementation
#
#
# Problem: Staircases
# Contest: 1598
# Index: E
# Tags: brute force, combinatorics, data structures, dfs and similar, dp, implementation, math
#
#
# Problem: Training Session
# Contest: 1598
# Index: D
# Tags: combinatorics, data structures, geometry, implementation, math
#
#
# Problem: Delete Two Elements
# Contest: 1598
# Index: C
# Tags: data structures, dp, implementation, math, two pointers
#
#
# Problem: Groups
# Contest: 1598
# Index: B
# Tags: brute force, implementation
#
#
# Problem: Computer Game
# Contest: 1598
# Index: A
# Tags: brute force, dfs and similar, dp, implementation
#
#
# Problem: Rubik's Cube Coloring (hard version)
# Contest: 1594
# Index: E2
# Tags: brute force, dp, implementation, math, trees
#
#
# Problem: Red-Black Number
# Contest: 1593
# Index: F
# Tags: dfs and similar, dp, implementation, math, meet-in-the-middle
#
#
# Problem: Gardener and Tree
# Contest: 1593
# Index: E
# Tags: brute force, data structures, dfs and similar, greedy, implementation, trees
#
#
# Problem: Hemose in ICPC ?
# Contest: 1592
# Index: D
# Tags: binary search, dfs and similar, implementation, interactive, math, number theory, trees
#
#
# Problem: Life of a Flower
# Contest: 1585
# Index: A
# Tags: implementation
#
#
# Problem: Train Maintenance
# Contest: 1580
# Index: C
# Tags: brute force, data structures, implementation
#
#
# Problem: Portal
# Contest: 1580
# Index: A
# Tags: brute force, data structures, dp, greedy, implementation
#
#
# Problem: Ticks
# Contest: 1579
# Index: C
# Tags: greedy, implementation
#
#
# Problem: Shifting Sort
# Contest: 1579
# Index: B
# Tags: implementation, sortings
#
#
# Problem: Kingdom of Islands
# Contest: 1578
# Index: K
# Tags: brute force, graphs, implementation
#
#
# Problem: Higher Order Functions
# Contest: 1578
# Index: H
# Tags: implementation, strings
#
#
# Problem: Easy Scheduling
# Contest: 1578
# Index: E
# Tags: implementation, math
#
#
# Problem: Knitting Batik
# Contest: 1575
# Index: K
# Tags: implementation, math
#
#
# Problem: Jeopardy of Dropped Balls
# Contest: 1575
# Index: J
# Tags: binary search, brute force, dsu, implementation
#
#
# Problem: Coloring
# Contest: 1574
# Index: E
# Tags: combinatorics, constructive algorithms, implementation, math
#
#
# Problem: The Strongest Build
# Contest: 1574
# Index: D
# Tags: binary search, brute force, data structures, dfs and similar, graphs, greedy, hashing, implementation
#
#
# Problem: Book
# Contest: 1572
# Index: A
# Tags: binary search, brute force, data structures, dp, graphs, implementation, sortings
#
#
# Problem: Sweepstake
# Contest: 1571
# Index: D
# Tags: *special, brute force, constructive algorithms, implementation, math
#
#
# Problem: Rhyme
# Contest: 1571
# Index: C
# Tags: *special, implementation
#
#
# Problem: Playoff Restoration
# Contest: 1569
# Index: E
# Tags: bitmasks, brute force, hashing, implementation, meet-in-the-middle
#
#
# Problem: Inconvenient Pairs
# Contest: 1569
# Index: D
# Tags: binary search, data structures, implementation, sortings, two pointers
#
#
# Problem: Balanced Substring
# Contest: 1569
# Index: A
# Tags: implementation
#
#
# Problem: One-Four Overload
# Contest: 1567
# Index: F
# Tags: 2-sat, constructive algorithms, dfs and similar, dsu, graphs, implementation
#
#
# Problem: Expression Evaluation Error
# Contest: 1567
# Index: D
# Tags: constructive algorithms, greedy, implementation, math
#
#
# Problem: Domino Disaster
# Contest: 1567
# Index: A
# Tags: implementation, strings
#
#
# Problem: Four Vertices
# Contest: 1566
# Index: G
# Tags: constructive algorithms, data structures, graphs, greedy, implementation, shortest paths
#
#
# Problem: Points Movement
# Contest: 1566
# Index: F
# Tags: data structures, dp, greedy, implementation, sortings
#
#
# Problem: Seating Arrangements (hard version)
# Contest: 1566
# Index: D2
# Tags: data structures, greedy, implementation, sortings, two pointers
#
#
# Problem: Scenes From a Memory
# Contest: 1562
# Index: B
# Tags: brute force, constructive algorithms, implementation, math, number theory
#
#
# Problem: Simply Strange Sort
# Contest: 1561
# Index: A
# Tags: brute force, implementation, sortings
#
#
# Problem: Polycarp and String Transformation
# Contest: 1560
# Index: E
# Tags: binary search, implementation, sortings, strings
#
#
# Problem: Infinity Table
# Contest: 1560
# Index: C
# Tags: implementation, math
#
#
# Problem: Dislike of Threes
# Contest: 1560
# Index: A
# Tags: implementation
#
#
# Problem: Compressed Bracket Sequence
# Contest: 1556
# Index: C
# Tags: brute force, implementation
#
#
# Problem: Take Your Places!
# Contest: 1556
# Index: B
# Tags: implementation
#
#
# Problem: Coin Rows
# Contest: 1555
# Index: C
# Tags: brute force, constructive algorithms, dp, implementation
#
#
# Problem: Mikasa
# Contest: 1554
# Index: C
# Tags: binary search, bitmasks, greedy, implementation
#
#
# Problem: Reverse String
# Contest: 1553
# Index: B
# Tags: brute force, dp, hashing, implementation, strings
#
#
# Problem: Domino (hard version)
# Contest: 1551
# Index: D2
# Tags: constructive algorithms, implementation, math
#
#
# Problem: Excellent Arrays
# Contest: 1550
# Index: D
# ...
# Index: E
# Tags: data structures, divide and conquer, implementation, trees
#
#
# Problem: Elevator
# Contest: 117
# Index: A
# Tags: implementation, math
#
#
# Problem: Little Pigs and Wolves
# Contest: 116
# Index: B
# Tags: greedy, implementation
#
#
# Problem: Tram
# Contest: 116
# Index: A
# Tags: implementation
#
#
# Problem: Sleeping
# Contest: 113
# Index: E
# Tags: combinatorics, implementation, math
#
#
# Problem: Grammar Lessons
# Contest: 113
# Index: A
# Tags: implementation, strings
#
#
# Problem: Petya and Square
# Contest: 112
# Index: B
# Tags: implementation, math
#
#
# Problem: Petya and Strings
# Contest: 112
# Index: A
# Tags: implementation, strings
#
#
# Problem: Nearly Lucky Number
# Contest: 110
# Index: A
# Tags: implementation
#
#
# Problem: Lucky Sum of Digits
# Contest: 109
# Index: A
# Tags: brute force, implementation
#
#
# Problem: Palindromic Times
# Contest: 108
# Index: A
# Tags: implementation, strings
#
#
# Problem: Treasure Island
# Contest: 106
# Index: D
# Tags: brute force, implementation
#
#
# Problem: Choosing Laptop
# Contest: 106
# Index: B
# Tags: brute force, implementation
#
#
# Problem: Card Game
# Contest: 106
# Index: A
# Tags: implementation
#
#
# Problem: Entertaining Geodetics
# Contest: 105
# Index: D
# Tags: brute force, dsu, implementation
#
#
# Problem: Item World
# Contest: 105
# Index: C
# Tags: brute force, implementation, sortings
#
#
# Problem: Transmigration
# Contest: 105
# Index: A
# Tags: implementation
#
#
# Problem: Blackjack
# Contest: 104
# Index: A
# Tags: implementation
#
#
# Problem: Testing Pants for Sadness
# Contest: 103
# Index: A
# Tags: greedy, implementation, math
#
#
# Problem: Sum of Digits
# Contest: 102
# Index: B
# Tags: implementation
#
#
# Problem: Vectors
# Contest: 101
# Index: C
# Tags: implementation, math
#
#
# Problem: Battleship
# Contest: 100
# Index: H
# Tags: *special, dfs and similar, implementation
#
#
# Problem: Name the album
# Contest: 100
# Index: G
# Tags: *special, data structures, implementation
#
#
# Problem: Polynom
# Contest: 100
# Index: F
# Tags: *special, implementation
#
#
# Problem: A+B
# Contest: 100
# Index: C
# Tags: *special, implementation
#
#
# Problem: Friendly Numbers
# Contest: 100
# Index: B
# Tags: *special, implementation
#
#
# Problem: Carpeting the Room
# Contest: 100
# Index: A
# Tags: *special, implementation
#
#
# Problem: Help Chef Gerasim
# Contest: 99
# Index: B
# Tags: implementation, sortings
#
#
# Problem: Help King
# Contest: 98
# Index: B
# Tags: implementation, probabilities, trees
#
#
# Problem: Help Victoria the Wise
# Contest: 98
# Index: A
# Tags: brute force, implementation
#
#
# Problem: Robot in Basement
# Contest: 97
# Index: D
# Tags: bitmasks, brute force, implementation
#
#
# Problem: Domino
# Contest: 97
# Index: A
# Tags: brute force, implementation
#
#
# Problem: Football
# Contest: 96
# Index: A
# Tags: implementation, strings
#
#
# Problem: Hockey
# Contest: 95
# Index: A
# Tags: implementation, strings
#
#
# Problem: Friends
# Contest: 94
# Index: B
# Tags: graphs, implementation, math
#
#
# Problem: Restoring Password
# Contest: 94
# Index: A
# Tags: implementation, strings
#
#
# Problem: Azembler
# Contest: 93
# Index: C
# Tags: brute force, implementation
#
#
# Problem: Frames
# Contest: 93
# Index: A
# Tags: implementation
#
#
# Problem: Chips
# Contest: 92
# Index: A
# Tags: implementation, math
#
#
# Problem: African Crossword
# Contest: 90
# Index: B
# Tags: implementation, strings
#
#
# Problem: Chip Play
# Contest: 89
# Index: C
# Tags: brute force, data structures, implementation
#
#
# Problem: Widget Library
# Contest: 89
# Index: B
# Tags: dp, expression parsing, graphs, implementation
#
#
# Problem: Keyboard
# Contest: 88
# Index: B
# Tags: implementation
#
#
# Problem: Chord
# Contest: 88
# Index: A
# Tags: brute force, implementation
#
#
# Problem: Beautiful Road
# Contest: 87
# Index: D
# Tags: dfs and similar, dp, dsu, graphs, implementation, sortings, trees
#
#
# Problem: Vasya and Types
# Contest: 87
# Index: B
# Tags: implementation, strings
#
#
# Problem: Trains
# Contest: 87
# Index: A
# Tags: implementation, math
#
#
# Problem: Powerful array
# Contest: 86
# Index: D
# Tags: data structures, implementation, math, two pointers
#
#
# Problem: Sum of Medians
# Contest: 85
# Index: D
# Tags: binary search, brute force, data structures, implementation
#
#
# Problem: Domino
# Contest: 85
# Index: A
# Tags: constructive algorithms, implementation
#
#
# Problem: Biathlon
# Contest: 84
# Index: C
# Tags: binary search, implementation
#
#
# Problem: Sets
# Contest: 82
# Index: B
# Tags: constructive algorithms, hashing, implementation
#
#
# Problem: Double Cola
# Contest: 82
# Index: A
# Tags: implementation, math
#
#
# Problem: Pairs
# Contest: 81
# Index: E
# Tags: dfs and similar, dp, dsu, graphs, implementation, trees
#
#
# Problem: Sequence Formatting
# Contest: 81
# Index: B
# Tags: implementation, strings
#
#
# Problem: Plug-in
# Contest: 81
# Index: A
# Tags: implementation
#
#
# Problem: Colorful Field
# Contest: 79
# Index: B
# Tags: implementation, sortings
#
#
# Problem: Easter Eggs
# Contest: 78
# Index: B
# Tags: constructive algorithms, implementation
#
#
# Problem: Haiku
# Contest: 78
# Index: A
# Tags: implementation, strings
#
#
# Problem: Domino Carpet
# Contest: 77
# Index: D
# Tags: dp, implementation
#
#
# Problem: Heroes
# Contest: 77
# Index: A
# Tags: brute force, implementation
#
#
# Problem: Points
# Contest: 76
# Index: E
# Tags: implementation, math
#
#
# Problem: Big Maximum Sum
# Contest: 75
# Index: D
# Tags: data structures, dp, greedy, implementation, math, trees
#
#
# Problem: Facetook Priority Wall
# Contest: 75
# Index: B
# Tags: expression parsing, implementation, strings
#
#
# Problem: Life Without Zeros
# Contest: 75
# Index: A
# Tags: implementation
#
#
# Problem: Room Leader
# Contest: 74
# Index: A
# Tags: implementation
#
#
# Problem: Goofy Numbers
# Contest: 72
# Index: I
# Tags: *special, implementation
#
#
# Problem: Reverse It!
# Contest: 72
# Index: H
# Tags: *special, implementation
#
#
# Problem: INI-file
# Contest: 72
# Index: B
# Tags: *special, implementation
#
#
# Problem: Solitaire
# Contest: 71
# Index: D
# Tags: brute force, implementation
#
#
# Problem: Progress Bar
# Contest: 71
# Index: B
# Tags: implementation, math
#
#
# Problem: Information Reform
# Contest: 70
# Index: E
# Tags: dp, implementation, trees
#
#
# Problem: Subsegments
# Contest: 69
# Index: E
# Tags: data structures, implementation
#
#
# Problem: Game
# Contest: 69
# Index: C
# Tags: implementation
#
#
# Problem: Bets
# Contest: 69
# Index: B
# Tags: greedy, implementation
#
#
# Problem: Young Physicist
# Contest: 69
# Index: A
# Tags: implementation, math
#
#
# Problem: Irrational problem
# Contest: 68
# Index: A
# Tags: implementation, number theory
#
#
# Problem: Partial Teacher
# Contest: 67
# Index: A
# Tags: dp, graphs, greedy, implementation
#
#
# Problem: Petya and File System
# Contest: 66
# Index: C
# Tags: data structures, implementation
#
#
# Problem: Petya and Countryside
# Contest: 66
# Index: B
# Tags: brute force, implementation
#
#
# Problem: Petya and Java
# Contest: 66
# Index: A
# Tags: implementation, strings
#
#
# Problem: Harry Potter and Moving Staircases
# Contest: 65
# Index: E
# Tags: dfs and similar, implementation
#
#
# Problem: Harry Potter and the History of Magic
# Contest: 65
# Index: B
# Tags: brute force, greedy, implementation
#
#
# Problem: Harry Potter and Three Spells
# Contest: 65
# Index: A
# Tags: implementation, math
#
#
# Problem: Table
# Contest: 64
# Index: C
# Tags: *special, greedy, implementation, math
#
#
# Problem: Factorial
# Contest: 64
# Index: A
# Tags: *special, implementation
#
#
# Problem: Sweets Game
# Contest: 63
# Index: E
# Tags: bitmasks, dfs and similar, dp, games, implementation
#
#
# Problem: Bulls and Cows
# Contest: 63
# Index: C
# Tags: brute force, implementation
#
#
# Problem: Settlers' Training
# Contest: 63
# Index: B
# Tags: implementation
#
#
# Problem: Sinking Ship
# Contest: 63
# Index: A
# Tags: implementation, sortings, strings
#
#
# Problem: Inquisition
# Contest: 62
# Index: C
# Tags: geometry, implementation, sortings
#
#
# Problem: Tyndex.Brome
# Contest: 62
# Index: B
# Tags: binary search, implementation
#
#
# Problem: Ultra-Fast Mathematician
# Contest: 61
# Index: A
# Tags: implementation
#
#
# Problem: Where Are My Flakes?
# Contest: 60
# Index: A
# Tags: implementation, two pointers
#
#
# Problem: Team Arrangement
# Contest: 59
# Index: D
# Tags: constructive algorithms, greedy, implementation
#
#
# Problem: Fortune Telling
# Contest: 59
# Index: B
# Tags: implementation, number theory
#
#
# Problem: Word
# Contest: 59
# Index: A
# Tags: implementation, strings
#
#
# Problem: Martian Architecture
# Contest: 57
# Index: B
# Tags: implementation
#
#
# Problem: Square Earth?
# Contest: 57
# Index: A
# Tags: dfs and similar, greedy, implementation
#
#
# Problem: Corporation Mail
# Contest: 56
# Index: C
# Tags: data structures, expression parsing, implementation
#
#
# Problem: Spoilt Permutation
# Contest: 56
# Index: B
# Tags: implementation
#
#
# Problem: Bar
# Contest: 56
# Index: A
# Tags: implementation
#
#
# Problem: Flea travel
# Contest: 55
# Index: A
# Tags: implementation, math
#
#
# Problem: Cutting Jigsaw Puzzle
# Contest: 54
# Index: B
# Tags: hashing, implementation
#
#
# Problem: Presents
# Contest: 54
# Index: A
# Tags: implementation
#
#
# Problem: Blog Photo
# Contest: 53
# Index: B
# Tags: binary search, implementation
#
#
# Problem: Autocomplete
# Contest: 53
# Index: A
# Tags: implementation
#
#
# Problem: 123-sequence
# Contest: 52
# Index: A
# Tags: implementation
#
#
# Problem: Geometrical problem
# Contest: 51
# Index: D
# Tags: implementation
#
#
# Problem: Cheaterius's Problem
# Contest: 51
# Index: A
# Tags: implementation
#
#
# Problem: Game
# Contest: 49
# Index: D
# Tags: brute force, dp, implementation
#
#
# Problem: Sleuth
# Contest: 49
# Index: A
# Tags: implementation
#
#
# Problem: Land Lot
# Contest: 48
# Index: B
# Tags: brute force, implementation
#
#
# Problem: Rock-paper-scissors
# Contest: 48
# Index: A
# Tags: implementation, schedules
#
#
# Problem: Crossword
# Contest: 47
# Index: C
# Tags: implementation
#
#
# Problem: Coins
# Contest: 47
# Index: B
# Tags: implementation
#
#
# Problem: Parking Lot
# Contest: 46
# Index: D
# Tags: data structures, implementation
#
#
# Problem: T-shirts from Sponsor
# Contest: 46
# Index: B
# Tags: implementation
#
#
# Problem: Ball Game
# Contest: 46
# Index: A
# Tags: brute force, implementation
#
#
# Problem: Codecraft III
# Contest: 45
# Index: A
# Tags: implementation
#
#
# Problem: Shooting Gallery
# Contest: 44
# Index: G
# Tags: data structures, implementation
#
#
# Problem: Holidays
# Contest: 44
# Index: C
# Tags: implementation
#
#
# Problem: Cola
# Contest: 44
# Index: B
# Tags: implementation
#
#
# Problem: Indian Summer
# Contest: 44
# Index: A
# Tags: implementation
#
#
# Problem: Race
# Contest: 43
# Index: E
# Tags: brute force, implementation, two pointers
#
#
# Problem: Journey
# Contest: 43
# Index: D
# Tags: brute force, constructive algorithms, implementation
#
#
# Problem: Letter
# Contest: 43
# Index: B
# Tags: implementation, strings
#
#
# Problem: Game of chess unfinished
# Contest: 42
# Index: B
# Tags: implementation
#
#
# Problem: Guilty --- to the kitchen!
# Contest: 42
# Index: A
# Tags: greedy, implementation
#
#
# Problem: Email address
# Contest: 41
# Index: C
# Tags: expression parsing, implementation
#
#
# Problem: Translation
# Contest: 41
# Index: A
# Tags: implementation, strings
#
#
# Problem: Berland Square
# Contest: 40
# Index: C
# Tags: implementation, math
#
#
# Problem: Find Color
# Contest: 40
# Index: A
# Tags: constructive algorithms, geometry, implementation, math
#
#
# Problem: Spelling Check
# Contest: 39
# Index: J
# Tags: hashing, implementation, strings
#
#
# Problem: Multiplication Table
# Contest: 39
# Index: H
# Tags: implementation
#
#
# Problem: Inverse Function
# Contest: 39
# Index: G
# Tags: implementation
#
#
# Problem: Pacifist frogs
# Contest: 39
# Index: F
# Tags: implementation
#
#
# Problem: Vasya the Architect
# Contest: 38
# Index: D
# Tags: implementation
#
#
# Problem: Chess
# Contest: 38
# Index: B
# Tags: brute force, implementation, math
#
#
# Problem: Army
# Contest: 38
# Index: A
# Tags: implementation
#
#
# Problem: Computer Game
# Contest: 37
# Index: B
# Tags: greedy, implementation
#
#
# Problem: Two Paths
# Contest: 36
# Index: E
# Tags: constructive algorithms, dsu, graphs, implementation
#
#
# Problem: Bowls
# Contest: 36
# Index: C
# Tags: geometry, implementation
#
#
# Problem: Fractal
# Contest: 36
# Index: B
# Tags: implementation
#
#
# Problem: Extra-terrestrial Intelligence
# Contest: 36
# Index: A
# Tags: implementation
#
#
# Problem: Warehouse
# Contest: 35
# Index: B
# Tags: implementation
#
#
# Problem: Shell Game
# Contest: 35
# Index: A
# Tags: implementation
#
#
# Problem: Collisions
# Contest: 34
# Index: E
# Tags: brute force, implementation, math
#
#
# Problem: Page Numbers
# Contest: 34
# Index: C
# Tags: expression parsing, implementation, sortings, strings
#
#
# Problem: Reconnaissance 2
# Contest: 34
# Index: A
# Tags: implementation
#
#
# Problem: What is for dinner?
# Contest: 33
# Index: A
# Tags: greedy, implementation
#
#
# Problem: Hide-and-Seek
# Contest: 32
# Index: E
# Tags: geometry, implementation
#
#
# Problem: Constellation
# Contest: 32
# Index: D
# Tags: implementation
#
#
# Problem: Borze
# Contest: 32
# Index: B
# Tags: expression parsing, implementation
#
#
# Problem: Chocolate
# Contest: 31
# Index: D
# Tags: dfs and similar, implementation
#
#
# Problem: Schedule
# Contest: 31
# Index: C
# Tags: implementation
#
#
# Problem: Sysadmin Bob
# Contest: 31
# Index: B
# Tags: greedy, implementation, strings
#
#
# Problem: Worms Evolution
# Contest: 31
# Index: A
# Tags: implementation
#
#
# Problem: Codeforces World Finals
# Contest: 30
# Index: B
# Tags: implementation
#
#
# Problem: Mail Stamps
# Contest: 29
# Index: C
# Tags: data structures, dfs and similar, graphs, implementation
#
#
# Problem: Traffic Lights
# Contest: 29
# Index: B
# Tags: implementation
#
#
# Problem: Bender Problem
# Contest: 28
# Index: A
# Tags: implementation
#
#
# Problem: Next Test
# Contest: 27
# Index: A
# Tags: implementation, sortings
#
#
# Problem: Parquet
# Contest: 26
# Index: C
# Tags: combinatorics, constructive algorithms, greedy, implementation
#
#
# Problem: Phone numbers
# Contest: 25
# Index: B
# Tags: implementation
#
#
# Problem: Sequence of points
# Contest: 24
# Index: C
# Tags: geometry, implementation, math
#
#
# Problem: F1 Champions
# Contest: 24
# Index: B
# Tags: implementation
#
#
# Problem: Intersection
# Contest: 21
# Index: B
# Tags: implementation, math
#
#
# Problem: Jabber ID
# Contest: 21
# Index: A
# Tags: implementation, strings
#
#
# Problem: BerOS file system
# Contest: 20
# Index: A
# Tags: implementation
#
#
# Problem: World Football Cup
# Contest: 19
# Index: A
# Tags: implementation
#
#
# Problem: Stripe
# Contest: 18
# Index: C
# Tags: data structures, implementation
#
#
# Problem: Logging
# Contest: 16
# Index: D
# Tags: implementation, strings
#
#
# Problem: Burglar and Matches
# Contest: 16
# Index: B
# Tags: greedy, implementation, sortings
#
#
# Problem: Flag
# Contest: 16
# Index: A
# Tags: implementation
#
#
# Problem: Map
# Contest: 15
# Index: D
# Tags: data structures, implementation, sortings
#
#
# Problem: Cottage Village
# Contest: 15
# Index: A
# Tags: implementation, sortings
#
#
# Problem: Four Segments
# Contest: 14
# Index: C
# Tags: brute force, constructive algorithms, geometry, implementation, math
#
#
# Problem: Young Photographer
# Contest: 14
# Index: B
# Tags: implementation
#
#
# Problem: Letter
# Contest: 14
# Index: A
# Tags: implementation
#
#
# Problem: Letter A
# Contest: 13
# Index: B
# Tags: geometry, implementation
#
#
# Problem: Numbers
# Contest: 13
# Index: A
# Tags: implementation, math
#
#
# Problem: Fruits
# Contest: 12
# Index: C
# Tags: greedy, implementation, sortings
#
#
# Problem: Correct Solution?
# Contest: 12
# Index: B
# Tags: implementation, sortings
#
#
# Problem: Super Agent
# Contest: 12
# Index: A
# Tags: implementation
#
#
# Problem: How Many Squares?
# Contest: 11
# Index: C
# Tags: implementation
#
#
# Problem: Increasing Sequence
# Contest: 11
# Index: A
# Tags: constructive algorithms, implementation, math
#
#
# Problem: Cinema Cashier
# Contest: 10
# Index: B
# Tags: dp, implementation
#
#
# Problem: Power Consumption Calculation
# Contest: 10
# Index: A
# Tags: implementation
#
#
# Problem: Hexadecimal's Numbers
# Contest: 9
# Index: C
# Tags: brute force, implementation, math
#
#
# Problem: Running Student
# Contest: 9
# Index: B
# Tags: brute force, geometry, implementation
#
#
# Problem: Obsession with Robots
# Contest: 8
# Index: B
# Tags: constructive algorithms, graphs, implementation
#
#
# Problem: Defining Macros
# Contest: 7
# Index: E
# Tags: dp, expression parsing, implementation
#
#
# Problem: Memory Manager
# Contest: 7
# Index: B
# Tags: implementation
#
#
# Problem: President's Office
# Contest: 6
# Index: B
# Tags: implementation
#
#
# Problem: Follow Traffic Rules
# Contest: 5
# Index: D
# Tags: implementation, math
#
#
# Problem: Center Alignment
# Contest: 5
# Index: B
# Tags: implementation, strings
#
#
# Problem: Chat Servers Outgoing Traffic
# Contest: 5
# Index: A
# Tags: implementation
#
#
# Problem: Registration System
# Contest: 4
# Index: C
# Tags: data structures, hashing, implementation
#
#
# Problem: Tic-tac-toe
# Contest: 3
# Index: C
# Tags: brute force, games, implementation
#
#
# Problem: Winner
# Contest: 2
# Index: A
# Tags: hashing, implementation
#
#
# Problem: Spreadsheet
# Contest: 1
# Index: B
# Tags: implementation, math
#
#
# Problems saved to codeforces_problems2.csv

# %%
import requests
import csv

def get_codeforces_problems(min_difficulty, max_difficulty, count=1000):
    base_url = "https://codeforces.com/api/problemset.problems"
    problems = []

    page = 1
    while len(problems) < count:
        params = {
            "tags": "implementation",
            "minRating": min_difficulty,
            "maxRating": max_difficulty,
            "page": page
        }

        response = requests.get(base_url, params=params)
        data = response.json()

        if "result" in data and "problems" in data["result"]:
            problems.extend(data["result"]["problems"])

        page += 1

    return problems

def save_problems_to_csv(problems, filename):
    with open(filename, 'w', newline='') as csv_file:
        fieldnames = ['Problem', 'Contest', 'Index', 'Tags']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        
        writer.writeheader()
        
        for problem in problems:
            writer.writerow({
                'Problem': problem['name'],
                'Contest': problem['contestId'],
                'Index': problem['index'],
                'Tags': ', '.join(problem.get('tags', []))
            })

if __name__ == "__main__":
    min_difficulty = 1300
    max_difficulty = 1500
    count = 3000  # You can adjust this to the total number of problems you want
    filename = "codeforces_problems3.csv"
    
    problems = get_codeforces_problems(min_difficulty, max_difficulty, count)
    
    if problems:
        for problem in problems:
            print(f"Problem: {problem['name']}")
            print(f"Contest: {problem['contestId']}")
            print(f"Index: {problem['index']}")
            print(f"Tags: {', '.join(problem.get('tags', []))}")
            print("\n")
        
        save_problems_to_csv(problems, filename)
        print(f"Problems saved to {filename}")
    else:
        print("Failed to retrieve all problems from Codeforces API.")

# %%
import requests
import csv

def get_codeforces_problem_info(contest_id, index):
    base_url = f"https://codeforces.com/api/problemset.problem"
    params = {
        "contestId": contest_id,
        "index": index,
    }
    response = requests.get(base_url, params=params)
    
    # Check if the response is valid JSON
    try:
        response_data = response.json()
    except ValueError as e:
        print(f"Error: Failed to decode JSON response - {e}")
        return {}

    return response_data.get("result", {})

def get_codeforces_problems(min_difficulty, max_difficulty):
    base_url = "https://codeforces.com/api/problemset.problems"
    params = {
        "tags": "implementation",
        "minRating": min_difficulty,
        "maxRating": max_difficulty,
    }
    response = requests.get(base_url, params=params)
    
    # Check if the response is valid JSON
    try:
        response_data = response.json()
    except ValueError as e:
        print(f"Error: Failed to decode JSON response - {e}")
        return []

    if "result" in response_data and "problems" in response_data["result"]:
        problems = response_data["result"]["problems"]
        return problems
    else:
        return []

def save_problems_to_csv(problems, filename):
    with open(filename, 'w', newline='') as csv_file:
        fieldnames = ['Problem', 'Contest', 'Index', 'Tags', 'Statement', 'Input', 'Output', 'Difficulty']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        writer.writeheader()
        for problem in problems:
            problem_info = get_codeforces_problem_info(problem['contestId'], problem['index'])
            writer.writerow({
                'Problem': problem['name'],
                'Contest': problem['contestId'],
                'Index': problem['index'],
                'Tags': ', '.join(problem.get('tags', [])),
            })

if __name__ == "__main__":
    min_difficulty = 1300
    max_difficulty = 1500
    filename = "codeforces_problems4.csv"
    problems = get_codeforces_problems(min_difficulty, max_difficulty)
    if problems:
        save_problems_to_csv(problems, filename)
        print(f"Problems saved to {filename}")
    else:
        print("Failed to retrieve problems from Codeforces API.")

# %%
import requests
import csv

def get_codeforces_problem_info(contest_id, index):
    base_url = f"https://codeforces.com/api/problemset.problem"
    params = {
        "contestId": contest_id,
        "index": index,
        "rating": "true",
        "submissions": "true",
        "accepted": "true",
        "wrongAnswer": "true",
        "timeLimitExceeded": "true",
        "memoryLimitExceeded": "true",
        "sampleTests": "true",
    }
    response = requests.get(base_url, params=params)
    
    try:
        response_data = response.json()
    except ValueError as e:
        
        return {}

    return response_data.get("result", {})

def get_codeforces_problems(min_difficulty, max_difficulty):
    base_url = "https://codeforces.com/api/problemset.problems"
    params = {
        "tags": "implementation",
        "minRating": min_difficulty,
        "maxRating": max_difficulty,
        "rating": "true",
        "submissions": "true",
        "accepted": "true",
        "wrongAnswer": "true",
        "timeLimitExceeded": "true",
        "memoryLimitExceeded": "true",
        "sampleTests": "true",
    }
    response = requests.get(base_url, params=params)
    
    try:
        response_data = response.json()
    except ValueError as e:
        
        return []

    if "result" in response_data and "problems" in response_data["result"]:
        problems = response_data["result"]["problems"]
        return problems
    else:
        return []

def save_problems_to_csv(problems, filename):
    with open(filename, 'w', newline='') as csv_file:
        fieldnames = ['Problem', 'Contest', 'Index', 'Tags', 'Rating', 'Submissions', 'Accepted', 'WrongAnswer', 'TimeLimitExceeded', 'MemoryLimitExceeded', 'SampleTests', 'Statement', 'Input', 'Output']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        writer.writeheader()
        for problem in problems:
            problem_info = get_codeforces_problem_info(problem['contestId'], problem['index'])
            writer.writerow({
                'Problem': problem['name'],
                'Contest': problem['contestId'],
                'Index': problem['index'],
                'Tags': ', '.join(problem.get('tags', [])),
                'Rating': problem_info.get('rating', None),
                'Submissions': problem_info.get('submissions', None),
                'Accepted': problem_info.get('accepted', None),
                'WrongAnswer': problem_info.get('wrongAnswer', None),
                'TimeLimitExceeded': problem_info.get('timeLimitExceeded', None),
                'MemoryLimitExceeded': problem_info.get('memoryLimitExceeded', None),
                'SampleTests': problem_info.get('sampleTests', None),
            })

if __name__ == "__main__":
    min_difficulty = 1300
    max_difficulty = 1500
    filename = "codeforces_problems5.csv"
    problems = get_codeforces_problems(min_difficulty, max_difficulty)
    if problems:
        save_problems_to_csv(problems, filename)
        print(f"Problems saved to {filename}")
# Out:
# Problems saved to codeforces_problems5.csv
