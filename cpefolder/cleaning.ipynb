# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('users.csv')

# %%
df.head()
# Out:
#    index     handle  contribution  last_online_time  registration_time  \
# 0      0  MiFaFaOvO           103        1579286035         1306208507
# 1      1    tourist           179        1579343739         1265987288
# 2      2     apiadu            56        1579363936         1472955181
# 3      3    mnbvmar           128        1579344393         1359543965
# 4      4       Benq           112        1579308396         1435099979
#
#                     rank               max_rank  rating  max_rating email  \
# 0  legendary grandmaster  legendary grandmaster    3520        3520   NaN
# 1  legendary grandmaster  legendary grandmaster    3430        3739   NaN
# 2  legendary grandmaster  legendary grandmaster    3351        3351   NaN
# 3  legendary grandmaster  legendary grandmaster    3332        3509   NaN
# 4  legendary grandmaster  legendary grandmaster    3290        3539   NaN
#
#    vk_id open_id first_name    last_name        country       city  \
# ...

# %%
columns_to_drop = ['contribution', 'last_online_time','registration_time','rank','max_rank','rating','email','vk_id','open_id','first_name','last_name','country','city','organization','friend_of_count','avatar','title_photo']
df.drop(columns_to_drop, axis=1, inplace=True)

# %%
df.head()
# Out:
#    index     handle  max_rating
# 0      0  MiFaFaOvO        3520
# 1      1    tourist        3739
# 2      2     apiadu        3351
# 3      3    mnbvmar        3509
# 4      4       Benq        3539

# %%
specified_value = 1400 
filtered_df = df[df['max_rating'] >= specified_value]

# %%
filtered_df.head()
# Out:
#    index     handle  max_rating
# 0      0  MiFaFaOvO        3520
# 1      1    tourist        3739
# 2      2     apiadu        3351
# 3      3    mnbvmar        3509
# 4      4       Benq        3539

# %%
filtered_df.shape[0]
# Out:
# 160542

# %%
df.to_csv('Filtered_above_1400_rating.csv', index=False)
