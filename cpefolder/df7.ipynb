# %%
import requests
from datetime import datetime
import pandas as pd

# %%
df=pd.read_csv('df15.csv') #change

# %%
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1400  #CHANGE
    target_upper = 1600 #CHANGE

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 30 <= days_taken <= 50: #CHANGE
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
# Out:
# yang3 did not cross the rating margin within the specified range.
# AbubiBoba did not cross the rating margin within the specified range.
# BlackIce666 did not cross the rating margin within the specified range.
# DarK_SouL17 did not cross the rating margin within the specified range.
# Gaurav..singh did not cross the rating margin within the specified range.
# JaishreeramCoder did not cross the rating margin within the specified range.
# Rcmple did not cross the rating margin within the specified range.
# Stortoise did not cross the rating margin within the specified range.
# UzuHa_NaruSuke did not cross the rating margin within the specified range.
# Vishnu767 did not cross the rating margin within the specified range.
# _Prince did not cross the rating margin within the specified range.
# alaa.A2 did not cross the rating margin within the specified range.
# Failed to fetch rating history for incra. Status code: 503
# nurlybek-yes-019-2025 did not cross the rating margin within the specified range.
# ollo did not cross the rating margin within the specified range.
# zuyuh0ng did not cross the rating margin within the specified range.
# 3013216027 did not cross the rating margin within the specified range.
# DestineDude did not cross the rating margin within the specified range.
# Dr_Glitch did not cross the rating margin within the specified range.
# Failed to fetch rating history for Eftekhar_Nahim. Status code: 503
# KienNguyen624 did not cross the rating margin within the specified range.
# Failed to fetch rating history for LeMinhDuc. Status code: 503
# M0N did not cross the rating margin within the specified range.
# Rainmaker2627 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Rawlat_vanak. Status code: 503
# Failed to fetch rating history for itachi_1807. Status code: 503
# mafailure_2 did not cross the rating margin within the specified range.
# Failed to fetch rating history for zsfxcb. Status code: 503
# -RAGNAR- did not cross the rating margin within the specified range.
# 1091857051 did not cross the rating margin within the specified range.
# 123sad did not cross the rating margin within the specified range.
# Failed to fetch rating history for JakubLap. Status code: 503
# LiFar did not cross the rating margin within the specified range.
# MODDI did not cross the rating margin within the specified range.
# Failed to fetch rating history for _Vadim_. Status code: 503
# __szh__ did not cross the rating margin within the specified range.
# altbxy did not cross the rating margin within the specified range.
# ggorelov did not cross the rating margin within the specified range.
# m1racleO_o did not cross the rating margin within the specified range.
# neg_infinity did not cross the rating margin within the specified range.
# Failed to fetch rating history for praps1614. Status code: 503
# trMatherz did not cross the rating margin within the specified range.
# 1271920576 did not cross the rating margin within the specified range.
# Ahmadbit did not cross the rating margin within the specified range.
# Failed to fetch rating history for Hamzeh_Miqdad. Status code: 503
# Failed to fetch rating history for Pekiban. Status code: 503
# ProudCarrotG did not cross the rating margin within the specified range.
# ahmadelhajj did not cross the rating margin within the specified range.
# ankan_0610 did not cross the rating margin within the specified range.
# Failed to fetch rating history for antonio.mondejar. Status code: 503
# bkdn23.LQDLover did not cross the rating margin within the specified range.
# daksh_02 did not cross the rating margin within the specified range.
# Failed to fetch rating history for dio_2. Status code: 503
# dmkwis did not cross the rating margin within the specified range.
# Failed to fetch rating history for himdyuti. Status code: 503
# Failed to fetch rating history for prabhatsingh21. Status code: 503
# zac2010 did not cross the rating margin within the specified range.
# 1_Devil_1 did not cross the rating margin within the specified range.
# Failed to fetch rating history for AR69420. Status code: 503
# AlTarek did not cross the rating margin within the specified range.
# Detach.. did not cross the rating margin within the specified range.
# IITian_here did not cross the rating margin within the specified range.
# Izeed did not cross the rating margin within the specified range.
# Muhammad.Daniyal did not cross the rating margin within the specified range.
# SolidAngel did not cross the rating margin within the specified range.
# WaterHashParsi did not cross the rating margin within the specified range.
# Failed to fetch rating history for abobkr. Status code: 503
# doanquocthinh2004 did not cross the rating margin within the specified range.
# fightMaster001 did not cross the rating margin within the specified range.
# Failed to fetch rating history for firizky. Status code: 503
# Failed to fetch rating history for michyjz. Status code: 503
# newestsolego did not cross the rating margin within the specified range.
# Failed to fetch rating history for srossd. Status code: 503
# 2625215223 did not cross the rating margin within the specified range.
# Classic_Adhom did not cross the rating margin within the specified range.
# DanRo23 did not cross the rating margin within the specified range.
# ErrorMaker. did not cross the rating margin within the specified range.
# SilviaXavier did not cross the rating margin within the specified range.
# Siunkyo did not cross the rating margin within the specified range.
# Failed to fetch rating history for Staid. Status code: 503
# Ved_Patel did not cross the rating margin within the specified range.
# eScaryNinja did not cross the rating margin within the specified range.
# Failed to fetch rating history for lycogno. Status code: 503
# Failed to fetch rating history for pt_dtu. Status code: 503
# stingspree_ did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ahmed-Naser. Status code: 503
# AngryKid did not cross the rating margin within the specified range.
# Failed to fetch rating history for Bhargav4037. Status code: 503
# Itadori_yuji_007 did not cross the rating margin within the specified range.
# L7Y13 did not cross the rating margin within the specified range.
# MahmoudBassem did not cross the rating margin within the specified range.
# Failed to fetch rating history for Only1ahmed. Status code: 503
# TheAcrux did not cross the rating margin within the specified range.
# Failed to fetch rating history for deepakjsagarwal. Status code: 503
# hertysd did not cross the rating margin within the specified range.
# lwsq did not cross the rating margin within the specified range.
# mingyun1343 did not cross the rating margin within the specified range.
# Failed to fetch rating history for naam_me_kya_rakha_ha. Status code: 503
# smchen did not cross the rating margin within the specified range.
# 2020liujinhan did not cross the rating margin within the specified range.
# Daoortor did not cross the rating margin within the specified range.
# Failed to fetch rating history for Hammoda. Status code: 503
# TheIridescentOne did not cross the rating margin within the specified range.
# Failed to fetch rating history for _Jerry. Status code: 503
# afeng111 did not cross the rating margin within the specified range.
# chenye3 did not cross the rating margin within the specified range.
# hungntils did not cross the rating margin within the specified range.
# kSagiri did not cross the rating margin within the specified range.
# Failed to fetch rating history for kgandhi22. Status code: 503
# mainex did not cross the rating margin within the specified range.
# Failed to fetch rating history for shivamxd. Status code: 503
# Ahmed_Ashraf_f did not cross the rating margin within the specified range.
# Failed to fetch rating history for Blitz8301. Status code: 503
# Jinesh1 did not cross the rating margin within the specified range.
# NONEEDDEBUG12 did not cross the rating margin within the specified range.
# TaylorFly did not cross the rating margin within the specified range.
# _s.r.i.j.a.l_ did not cross the rating margin within the specified range.
# keshavgoel_186 did not cross the rating margin within the specified range.
# lkm_codeforces did not cross the rating margin within the specified range.
# Failed to fetch rating history for lxylluvio. Status code: 503
# meKira did not cross the rating margin within the specified range.
# nosaboy did not cross the rating margin within the specified range.
# passion_fruit did not cross the rating margin within the specified range.
# stumblebum did not cross the rating margin within the specified range.
# wanxiangzx did not cross the rating margin within the specified range.
# Failed to fetch rating history for xu-_-ke. Status code: 503
# ARSHKHAN98 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Chaves. Status code: 503
# CodeGPT did not cross the rating margin within the specified range.
# Failed to fetch rating history for EndStarry. Status code: 503
# MethusIsBack did not cross the rating margin within the specified range.
# SirPh did not cross the rating margin within the specified range.
# Failed to fetch rating history for akash456. Status code: 503
# akwa_blue did not cross the rating margin within the specified range.
# anymzx did not cross the rating margin within the specified range.
# bennyk0406 did not cross the rating margin within the specified range.
# codiway did not cross the rating margin within the specified range.
# hungeazy did not cross the rating margin within the specified range.
# jarvis22 did not cross the rating margin within the specified range.
# Failed to fetch rating history for jvdss12. Status code: 503
# lyxtyl did not cross the rating margin within the specified range.
# Failed to fetch rating history for mukundm. Status code: 503
# panyuehui did not cross the rating margin within the specified range.
# pgergo03 did not cross the rating margin within the specified range.
# Failed to fetch rating history for shao_h_y. Status code: 503
# wazz did not cross the rating margin within the specified range.
# wsk1202 did not cross the rating margin within the specified range.
# Failed to fetch rating history for xcvv. Status code: 503
# Boss_Google did not cross the rating margin within the specified range.
# Doubleen233 did not cross the rating margin within the specified range.
# Failed to fetch rating history for KK_1729. Status code: 503
# King_is_here did not cross the rating margin within the specified range.
# Matveyko did not cross the rating margin within the specified range.
# Failed to fetch rating history for RHEXAOC. Status code: 503
# Rip_Pro did not cross the rating margin within the specified range.
# SOSCharlie did not cross the rating margin within the specified range.
# Failed to fetch rating history for Seer_2210. Status code: 503
# arahan_673 did not cross the rating margin within the specified range.
# c1imber did not cross the rating margin within the specified range.
# charlixcx did not cross the rating margin within the specified range.
# Failed to fetch rating history for henriqueramos.qs. Status code: 503
# kirillveshnyakov did not cross the rating margin within the specified range.
# Failed to fetch rating history for lanhuo. Status code: 503
# nandapavan26 did not cross the rating margin within the specified range.
# phoenix1289 did not cross the rating margin within the specified range.
# qinglu09 did not cross the rating margin within the specified range.
# volfgang did not cross the rating margin within the specified range.
# Failed to fetch rating history for windy_hill. Status code: 503
# DortyTheGreat did not cross the rating margin within the specified range.
# Hamloo did not cross the rating margin within the specified range.
# alvinhsu did not cross the rating margin within the specified range.
# Failed to fetch rating history for chechau. Status code: 503
# drNarzullayev did not cross the rating margin within the specified range.
# mH4S4N did not cross the rating margin within the specified range.
# namanxain did not cross the rating margin within the specified range.
# schrodinger_789 did not cross the rating margin within the specified range.
# 863aditya did not cross the rating margin within the specified range.
# AprLsity did not cross the rating margin within the specified range.
# Bloodstalk did not cross the rating margin within the specified range.
# DeVilmaNzz did not cross the rating margin within the specified range.
# DoTes did not cross the rating margin within the specified range.
# Lazy23 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Nightmaressss. Status code: 503
# RTRTTT did not cross the rating margin within the specified range.
# Sahilrk07 did not cross the rating margin within the specified range.
# Sley_K did not cross the rating margin within the specified range.
# abiramee did not cross the rating margin within the specified range.
# aryangupta1604 did not cross the rating margin within the specified range.
# Failed to fetch rating history for beethOWEN. Status code: 503
# lanbae did not cross the rating margin within the specified range.
# Failed to fetch rating history for magga. Status code: 503
# Failed to fetch rating history for mc_rodrix99. Status code: 503
# poxiao0 did not cross the rating margin within the specified range.
# Failed to fetch rating history for rc_leon. Status code: 503
# Failed to fetch rating history for rkaiki. Status code: 503
# Failed to fetch rating history for uleenneelu. Status code: 503
# 333DaysLater did not cross the rating margin within the specified range.
# AKYoung did not cross the rating margin within the specified range.
# BARAN_NABEISI did not cross the rating margin within the specified range.
# Failed to fetch rating history for ByeByePM8. Status code: 503
# Failed to fetch rating history for MarkoRaskovic. Status code: 503
# MostafaM.Galal did not cross the rating margin within the specified range.
# Failed to fetch rating history for PHarr_. Status code: 503
# Phuong0703 did not cross the rating margin within the specified range.
# Failed to fetch rating history for ShinnirKolaChori. Status code: 503
# Vishnu_Actual did not cross the rating margin within the specified range.
# anonymous_yuvi did not cross the rating margin within the specified range.
# Failed to fetch rating history for kaotualtd. Status code: 503
# pranitrai07 did not cross the rating margin within the specified range.
# Failed to fetch rating history for sunhero. Status code: 503
# theDistorter did not cross the rating margin within the specified range.
# wixx did not cross the rating margin within the specified range.
# Failed to fetch rating history for Andrei.E. Status code: 503
# Dijkstra_attack did not cross the rating margin within the specified range.
# Failed to fetch rating history for GojoSatoru. Status code: 503
# HarshalHolkar did not cross the rating margin within the specified range.
# HeReWeGoAgAiN123 did not cross the rating margin within the specified range.
# IIIIIlIIIl did not cross the rating margin within the specified range.
# Raowl did not cross the rating margin within the specified range.
# Sameer_sharma did not cross the rating margin within the specified range.
# Failed to fetch rating history for Sinlin. Status code: 503
# Sunward_z did not cross the rating margin within the specified range.
# Victor_Luis123 did not cross the rating margin within the specified range.
# Failed to fetch rating history for VincentK. Status code: 503
# YuTJ did not cross the rating margin within the specified range.
# _GG_123 did not cross the rating margin within the specified range.
# aniruddhmodi03 did not cross the rating margin within the specified range.
# detective...dots did not cross the rating margin within the specified range.
# morphinecode did not cross the rating margin within the specified range.
# retyrn did not cross the rating margin within the specified range.
# shaanjijoe2 did not cross the rating margin within the specified range.
# Failed to fetch rating history for silenceneo_xw. Status code: 503
# 2132141325 did not cross the rating margin within the specified range.
# AKM17 did not cross the rating margin within the specified range.
# ARUME did not cross the rating margin within the specified range.
# Failed to fetch rating history for AoiYuki8. Status code: 503
# CQUT-FWXDD did not cross the rating margin within the specified range.
# Litvin_Vlad did not cross the rating margin within the specified range.
# MURGI_adid did not cross the rating margin within the specified range.
# Palmerin did not cross the rating margin within the specified range.
# Failed to fetch rating history for f3f3f3f3. Status code: 503
# ladisgin did not cross the rating margin within the specified range.
# s.pris did not cross the rating margin within the specified range.
# Failed to fetch rating history for unforgettablepl. Status code: 503
# wyyzqx did not cross the rating margin within the specified range.
# xiaofangyi did not cross the rating margin within the specified range.
# 2020A7PS1195H_Rishi did not cross the rating margin within the specified range.
# Failed to fetch rating history for Jaishriram11. Status code: 503
# NaCl823400 did not cross the rating margin within the specified range.
# SaurabhKumar1611 did not cross the rating margin within the specified range.
# Sheber did not cross the rating margin within the specified range.
# Sp00kiel did not cross the rating margin within the specified range.
# alex0511 did not cross the rating margin within the specified range.
# aryang22 did not cross the rating margin within the specified range.
# bkdn23.dakduc did not cross the rating margin within the specified range.
# Failed to fetch rating history for bkdn23.leevox. Status code: 503
# dhairyamagnetar did not cross the rating margin within the specified range.
# dukhdard did not cross the rating margin within the specified range.
# innerboy did not cross the rating margin within the specified range.
# rajesh_127 did not cross the rating margin within the specified range.
# san18 did not cross the rating margin within the specified range.
# Failed to fetch rating history for sgm007. Status code: 503
# srinith did not cross the rating margin within the specified range.
# syysongyuyang did not cross the rating margin within the specified range.
# Aadarsh_negi did not cross the rating margin within the specified range.
# ApoorvShri did not cross the rating margin within the specified range.
# Basekill did not cross the rating margin within the specified range.
# Failed to fetch rating history for BortiK. Status code: 503
# Federico_Garcia_Lorca did not cross the rating margin within the specified range.
# GiyuTomioka did not cross the rating margin within the specified range.
# HHHashmap did not cross the rating margin within the specified range.
# Failed to fetch rating history for Lior. Status code: 503
# basalt_lava did not cross the rating margin within the specified range.
# Failed to fetch rating history for bholi. Status code: 503
# catandcode did not cross the rating margin within the specified range.
# code_destructor did not cross the rating margin within the specified range.
# hardcheese did not cross the rating margin within the specified range.
# hmmhnopro did not cross the rating margin within the specified range.
# hngara did not cross the rating margin within the specified range.
# lsr123456789 did not cross the rating margin within the specified range.
# mc1 did not cross the rating margin within the specified range.
# Failed to fetch rating history for pratheekrai2002. Status code: 503
# roycf123 did not cross the rating margin within the specified range.
# tuandequy did not cross the rating margin within the specified range.
# wjd_ did not cross the rating margin within the specified range.
# ABlyh did not cross the rating margin within the specified range.
# Abracadaber did not cross the rating margin within the specified range.
# Failed to fetch rating history for ArushN27. Status code: 503
# Carl_Hu did not cross the rating margin within the specified range.
# Failed to fetch rating history for CrispOuO. Status code: 503
# KaiYuan00 did not cross the rating margin within the specified range.
# LVDT_ did not cross the rating margin within the specified range.
# Nikttop did not cross the rating margin within the specified range.
# Rhyme3 did not cross the rating margin within the specified range.
# Failed to fetch rating history for TjeRAWAgent. Status code: 503
# Yash_92 did not cross the rating margin within the specified range.
# Failed to fetch rating history for __LAKSHAY__. Status code: 503
# __sam__ did not cross the rating margin within the specified range.
# mulyam13986 did not cross the rating margin within the specified range.
# Failed to fetch rating history for oviyan_gandhi. Status code: 503
# s.nazyrov did not cross the rating margin within the specified range.
# Failed to fetch rating history for wintersoldier2004. Status code: 503
# 2005zhw did not cross the rating margin within the specified range.
# Failed to fetch rating history for 514InParadise. Status code: 503
# Advaid did not cross the rating margin within the specified range.
# Failed to fetch rating history for CodeforcesADMlN. Status code: 503
# Failed to fetch rating history for NazarPablo. Status code: 503
# Failed to fetch rating history for Shifted777. Status code: 503
# chtholly3 did not cross the rating margin within the specified range.
# Failed to fetch rating history for d1amondzz. Status code: 503
# girlgg did not cross the rating margin within the specified range.
# jstzmxuan did not cross the rating margin within the specified range.
# mpanyavin did not cross the rating margin within the specified range.
# nevikw39 did not cross the rating margin within the specified range.
# Failed to fetch rating history for thanhdno. Status code: 503
# unknownAsGod did not cross the rating margin within the specified range.
# uttam20 did not cross the rating margin within the specified range.
# 440066 did not cross the rating margin within the specified range.
# Ahmed_Dyab did not cross the rating margin within the specified range.
# Ayupyon did not cross the rating margin within the specified range.
# Failed to fetch rating history for CodeyBanks. Status code: 503
# Curse969 did not cross the rating margin within the specified range.
# Failed to fetch rating history for LoganGD. Status code: 503
# MEGAMMS did not cross the rating margin within the specified range.
# Failed to fetch rating history for XHYMathematics. Status code: 503
# Failed to fetch rating history for agarwalaswastik. Status code: 503
# ajay_mnc did not cross the rating margin within the specified range.
# Failed to fetch rating history for harshal_02. Status code: 503
# hengliao did not cross the rating margin within the specified range.
# Failed to fetch rating history for keptany. Status code: 503
# Failed to fetch rating history for mehrad22. Status code: 503
# Failed to fetch rating history for perdoname_Dios. Status code: 503
# the_coder_8297 did not cross the rating margin within the specified range.
# Failed to fetch rating history for American_Eagle. Status code: 503
# Aviral_Gupta did not cross the rating margin within the specified range.
# Intellect001 did not cross the rating margin within the specified range.
# Failed to fetch rating history for JanekKwadrat. Status code: 503
# Norvezhskaya_8-klassnica did not cross the rating margin within the specified range.
# Tudor.Mihai did not cross the rating margin within the specified range.
# UNSALEK did not cross the rating margin within the specified range.
# VJWIHKG did not cross the rating margin within the specified range.
# Failed to fetch rating history for VMaksimoski008. Status code: 503
# denmonik did not cross the rating margin within the specified range.
# Failed to fetch rating history for puspendra_09. Status code: 503
# sush2k3 did not cross the rating margin within the specified range.
# .Eddy did not cross the rating margin within the specified range.
# Failed to fetch rating history for Cmndr_Salamander. Status code: 503
# Emet-Selch did not cross the rating margin within the specified range.
# Gamakatsu did not cross the rating margin within the specified range.
# HenriqueCP did not cross the rating margin within the specified range.
# Kirlos_Nabil did not cross the rating margin within the specified range.
# NenadDapic did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ronbogo. Status code: 503
# __AA did not cross the rating margin within the specified range.
# Failed to fetch rating history for creampuffshu. Status code: 503
# cyan0515 did not cross the rating margin within the specified range.
# jontybot did not cross the rating margin within the specified range.
# linwenqi did not cross the rating margin within the specified range.
# Failed to fetch rating history for prasoon107. Status code: 503
# rose_DKY did not cross the rating margin within the specified range.
# rzi did not cross the rating margin within the specified range.
# 2022Zhangfenglai did not cross the rating margin within the specified range.
# Abid_Ul_Islam did not cross the rating margin within the specified range.
# Failed to fetch rating history for Blue_M00n. Status code: 503
# Dream_zaa did not cross the rating margin within the specified range.
# Failed to fetch rating history for GamerSheel. Status code: 503
# JJThomson did not cross the rating margin within the specified range.
# JavaHere did not cross the rating margin within the specified range.
# Shubh_Kr07 did not cross the rating margin within the specified range.
# Failed to fetch rating history for czp2222. Status code: 503
# gsc0618 did not cross the rating margin within the specified range.
# hongjinjian did not cross the rating margin within the specified range.
#                Handle  Max Rating Result
# 0    uchihahahahahaha        1733     No
# 1               yang3        1540    N/A
# 2               ygznb        1661    Yes
# 3           AbubiBoba        1576    N/A
# 4          Ahmet_Emre        1677     No
# ..                ...         ...    ...
# 495      O2iginal2023        1662     No
# 496        Shubh_Kr07        1576    N/A
# 497           czp2222        1537    N/A
# 498           gsc0618        1516    N/A
# 499       hongjinjian        1522    N/A
#
# [500 rows x 3 columns]

# %%
df.head()
# Out:
#              Handle  Max Rating Result
# 0  uchihahahahahaha        1733     No
# 1             yang3        1540    N/A
# 2             ygznb        1661    Yes
# 3         AbubiBoba        1576    N/A
# 4        Ahmet_Emre        1677     No

# %%
df.to_csv('outdf15.csv', index=False) #change

# %%
#

# %%
file_names = ['outdf{}.csv'.format(i) for i in range(1, 15)] #change

dataframes = []

for file_name in file_names:
    df = pd.read_csv(file_name)
    dataframes.append(df)

merged_data = pd.concat(dataframes, ignore_index=True)

merged_data.to_csv('merged_output.csv', index=False)

print("Merged CSV file saved as 'merged_output.csv'")
# Out:
# Merged CSV file saved as 'merged_output.csv'
