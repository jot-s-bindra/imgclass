# %%
import requests
import json

def get_solved_problems(user_handle):
  """Gets the set of problems done by a Codeforces user.

  Args:
    user_handle: The handle of the user.

  Returns:
    A set of problem IDs.
  """

  # Make a request to the Codeforces API to get the user's solved list.
  response = requests.get(
      f"https://codeforces.com/api/user.status?handle={user_handle}")

  # Parse the JSON response.
  data = json.loads(response.content)

  # Get the list of solved problems.
  solved_problems = set()
  for submission in data["result"]:
    if submission["verdict"] == "OK":
      solved_problems.add(submission["problem"]["contestId"])
      solved_problems.add(submission["problem"]["index"])

  return solved_problems

# Example usage:

user_handle = "agrim07"
solved_problems = get_solved_problems(user_handle)

print(solved_problems)
print(f"Number of problems solved: {len(solved_problems)}")
# Out:
# {1537, 1538, 1, 4, 1541, 'P', 1324, 525, 528, 1553, 1560, 25, 'S', 103466, 47, 'A1', 1102, 'A', 'T', 1632, 610, 1649, 628, 118, 1667, 1669, 1673, 1165, 1680, 'K', 'I', 1692, 158, 'R', 1700, 'F', 1702, 1703, 'J', 1705, 1706, 1701, 1712, 1714, 1715, 1719, 1721, 698, 1722, 189, 1729, 1731, 1732, 1733, 1738, 1739, 1740, 1741, 1742, 1744, 1748, 1749, 1750, 'N', 1753, 1758, 1759, 1760, 1762, 1763, 1252, 1765, 1766, 1768, 'L', 1770, 1772, 1771, 1774, 1775, 1776, 'G2', 1778, 1779, 1780, 1783, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1804, 1805, 268, 1807, 1808, 1809, 1810, 1811, 782, 1814, 'E2', 1816, 1818, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 'A2', 1828, 1829, 1830, 1831, 'D2', 1833, 1834, 1835, 1832, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 103736, 1849, 1851, 1850, 1853, 'D', 1856, 'B', 1858, 1859, 1860, 1857, 1862, 1855, 1864, 104257, 1866, 1867, 1869, 1872, 1873, 'H', 1875, 1878, 1879, 1881, 1882, 1883, 1884, 'E', 1886, 1888, 'M', 'E1', 102267, 'Q', 'D1', 1420, 'C', 'G1', 'C2', 1473, 1475, 1476, 'G', 104400, 100819, 1497, 1512, 103401, 104426, 1516, 492, 1520, 1521, 1526, 'C1'}
# Number of problems solved: 201

# %%
import requests

# Replace with the user's Codeforces handle
handle = "agrim07"

# Step 1: Get User Info
user_info_url = f"https://codeforces.com/api/user.info?handles={handle}"
response = requests.get(user_info_url)
user_info = response.json()["result"][0]
user_rating = user_info["rating"]

# Step 2: Fetch Submissions
user_submissions_url = f"https://codeforces.com/api/user.status?handle={handle}"
response = requests.get(user_submissions_url)
submissions = response.json()["result"]

# Step 3 and 4: Filter and Retrieve Questions
desired_rating_range = range(1200, 1401)  # Inclusive range
questions = []

for submission in submissions:
    if "rating" in submission and submission["rating"] in desired_rating_range:
        question = {
            "contest_id": submission["contestId"],
            "problem_index": submission["problem"]["index"],
            "problem_name": submission["problem"]["name"],
        }
        questions.append(question)

# Step 5: Optional Deduplication
unique_questions = []
seen = set()

for question in questions:
    question_id = (question["contest_id"], question["problem_index"])
    if question_id not in seen:
        unique_questions.append(question)
        seen.add(question_id)

# Print or process the unique questions
for question in unique_questions:
    print(f"Contest ID: {question['contest_id']}, Problem Index: {question['problem_index']}, Problem Name: {question['problem_name']}")
# Debugging output
print("User Rating:", user_rating)

for submission in submissions:
    print("Submission:", submission)

for question in questions:
    print("Question:", question)
# Out:
# User Rating: 1637
# Submission: {'id': 229330352, 'contestId': 1883, 'creationTimeSeconds': 1697999454, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1883, 'index': 'E', 'name': 'Look Back', 'type': 'PROGRAMMING', 'points': 2500.0, 'tags': ['bitmasks', 'greedy']}, 'author': {'contestId': 1883, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1697972700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 14, 'timeConsumedMillis': 46, 'memoryConsumedBytes': 1228800}
# Submission: {'id': 229327542, 'contestId': 1883, 'creationTimeSeconds': 1697997980, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1883, 'index': 'E', 'name': 'Look Back', 'type': 'PROGRAMMING', 'points': 2500.0, 'tags': ['bitmasks', 'greedy']}, 'author': {'contestId': 1883, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1697972700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 3, 'timeConsumedMillis': 46, 'memoryConsumedBytes': 0}
# Submission: {'id': 229327073, 'contestId': 1883, 'creationTimeSeconds': 1697997756, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1883, 'index': 'E', 'name': 'Look Back', 'type': 'PROGRAMMING', 'points': 2500.0, 'tags': ['bitmasks', 'greedy']}, 'author': {'contestId': 1883, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1697972700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'TIME_LIMIT_EXCEEDED', 'testset': 'TESTS', 'passedTestCount': 3, 'timeConsumedMillis': 1000, 'memoryConsumedBytes': 0}
# Submission: {'id': 229264166, 'contestId': 1888, 'creationTimeSeconds': 1697977634, 'relativeTimeSeconds': 4934, 'problem': {'contestId': 1888, 'index': 'D2', 'name': 'Dances (Hard Version)', 'type': 'PROGRAMMING', 'points': 1250.0, 'tags': ['binary search', 'brute force', 'greedy', 'math']}, 'author': {'contestId': 1888, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 56, 'startTimeSeconds': 1697972700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 15, 'timeConsumedMillis': 78, 'memoryConsumedBytes': 6451200}
# Submission: {'id': 229245842, 'contestId': 1888, 'creationTimeSeconds': 1697975922, 'relativeTimeSeconds': 3222, 'problem': {'contestId': 1888, 'index': 'D1', 'name': 'Dances (Easy version)', 'type': 'PROGRAMMING', 'points': 750.0, 'tags': ['binary search', 'greedy']}, 'author': {'contestId': 1888, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 56, 'startTimeSeconds': 1697972700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 15, 'timeConsumedMillis': 93, 'memoryConsumedBytes': 6451200}
# Submission: {'id': 229241303, 'contestId': 1888, 'creationTimeSeconds': 1697975516, 'relativeTimeSeconds': 2816, 'problem': {'contestId': 1888, 'index': 'C', 'name': 'You Are So Beautiful', 'type': 'PROGRAMMING', 'points': 1000.0, 'tags': ['data structures']}, 'author': {'contestId': 1888, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 56, 'startTimeSeconds': 1697972700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 18, 'timeConsumedMillis': 202, 'memoryConsumedBytes': 6758400}
# Submission: {'id': 229232644, 'contestId': 1888, 'creationTimeSeconds': 1697974775, 'relativeTimeSeconds': 2075, 'problem': {'contestId': 1888, 'index': 'B', 'name': 'Raspberries', 'type': 'PROGRAMMING', 'points': 500.0, 'tags': ['math', 'number theory']}, 'author': {'contestId': 1888, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 56, 'startTimeSeconds': 1697972700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 5, 'timeConsumedMillis': 46, 'memoryConsumedBytes': 819200}
# Submission: {'id': 229226813, 'contestId': 1888, 'creationTimeSeconds': 1697974328, 'relativeTimeSeconds': 1628, 'problem': {'contestId': 1888, 'index': 'B', 'name': 'Raspberries', 'type': 'PROGRAMMING', 'points': 500.0, 'tags': ['math', 'number theory']}, 'author': {'contestId': 1888, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 56, 'startTimeSeconds': 1697972700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 3, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 229225607, 'contestId': 1888, 'creationTimeSeconds': 1697974238, 'relativeTimeSeconds': 1538, 'problem': {'contestId': 1888, 'index': 'B', 'name': 'Raspberries', 'type': 'PROGRAMMING', 'points': 500.0, 'tags': ['math', 'number theory']}, 'author': {'contestId': 1888, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 56, 'startTimeSeconds': 1697972700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 0, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 229217220, 'contestId': 1888, 'creationTimeSeconds': 1697973667, 'relativeTimeSeconds': 967, 'problem': {'contestId': 1888, 'index': 'B', 'name': 'Raspberries', 'type': 'PROGRAMMING', 'points': 500.0, 'tags': ['math', 'number theory']}, 'author': {'contestId': 1888, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 56, 'startTimeSeconds': 1697972700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 0, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 229210314, 'contestId': 1888, 'creationTimeSeconds': 1697973261, 'relativeTimeSeconds': 561, 'problem': {'contestId': 1888, 'index': 'A', 'name': 'Chemistry', 'type': 'PROGRAMMING', 'points': 250.0, 'tags': ['strings']}, 'author': {'contestId': 1888, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 56, 'startTimeSeconds': 1697972700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 5, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 307200}
# Submission: {'id': 229207985, 'contestId': 1888, 'creationTimeSeconds': 1697973118, 'relativeTimeSeconds': 418, 'problem': {'contestId': 1888, 'index': 'A', 'name': 'Chemistry', 'type': 'PROGRAMMING', 'points': 250.0, 'tags': ['strings']}, 'author': {'contestId': 1888, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 56, 'startTimeSeconds': 1697972700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 1, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 229162551, 'contestId': 1884, 'creationTimeSeconds': 1697960237, 'relativeTimeSeconds': 1937, 'problem': {'contestId': 1884, 'index': 'B', 'name': 'Haunted House', 'type': 'PROGRAMMING', 'points': 1000.0, 'tags': ['binary search', 'greedy', 'math', 'two pointers']}, 'author': {'contestId': 1884, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 111, 'startTimeSeconds': 1697958300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 11, 'timeConsumedMillis': 31, 'memoryConsumedBytes': 3276800}
# Submission: {'id': 229159932, 'contestId': 1884, 'creationTimeSeconds': 1697959846, 'relativeTimeSeconds': 1546, 'problem': {'contestId': 1884, 'index': 'B', 'name': 'Haunted House', 'type': 'PROGRAMMING', 'points': 1000.0, 'tags': ['binary search', 'greedy', 'math', 'two pointers']}, 'author': {'contestId': 1884, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 111, 'startTimeSeconds': 1697958300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 1, 'timeConsumedMillis': 31, 'memoryConsumedBytes': 0}
# Submission: {'id': 229147166, 'contestId': 1884, 'creationTimeSeconds': 1697958427, 'relativeTimeSeconds': 127, 'problem': {'contestId': 1884, 'index': 'A', 'name': 'Simple Design', 'type': 'PROGRAMMING', 'points': 500.0, 'tags': ['brute force', 'greedy', 'math']}, 'author': {'contestId': 1884, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 111, 'startTimeSeconds': 1697958300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 4, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 228474524, 'contestId': 1700, 'creationTimeSeconds': 1697492663, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1700, 'index': 'C', 'name': 'Helping the Nature', 'type': 'PROGRAMMING', 'points': 1500.0, 'rating': 1700, 'tags': ['constructive algorithms', 'data structures', 'greedy']}, 'author': {'contestId': 1700, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1655629500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 27, 'timeConsumedMillis': 46, 'memoryConsumedBytes': 1638400}
# Submission: {'id': 228469409, 'contestId': 1881, 'creationTimeSeconds': 1697487325, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1881, 'index': 'G', 'name': 'Anya and the Mysterious String', 'type': 'PROGRAMMING', 'tags': ['binary search', 'data structures']}, 'author': {'contestId': 1881, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1697121300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 11, 'timeConsumedMillis': 311, 'memoryConsumedBytes': 9011200}
# Submission: {'id': 227896597, 'contestId': 1881, 'creationTimeSeconds': 1697126563, 'relativeTimeSeconds': 5263, 'problem': {'contestId': 1881, 'index': 'C', 'name': 'Perfect Square', 'type': 'PROGRAMMING', 'tags': ['brute force', 'implementation']}, 'author': {'contestId': 1881, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1697121300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 7, 'timeConsumedMillis': 1418, 'memoryConsumedBytes': 129638400}
# Submission: {'id': 227884231, 'contestId': 1881, 'creationTimeSeconds': 1697125402, 'relativeTimeSeconds': 4102, 'problem': {'contestId': 1881, 'index': 'E', 'name': 'Block Sequence', 'type': 'PROGRAMMING', 'tags': ['dp']}, 'author': {'contestId': 1881, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1697121300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 16, 'timeConsumedMillis': 31, 'memoryConsumedBytes': 3174400}
# Submission: {'id': 227873626, 'contestId': 1881, 'creationTimeSeconds': 1697124522, 'relativeTimeSeconds': 3222, 'problem': {'contestId': 1881, 'index': 'D', 'name': 'Divide and Equalize', 'type': 'PROGRAMMING', 'tags': ['math', 'number theory']}, 'author': {'contestId': 1881, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1697121300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 34, 'timeConsumedMillis': 46, 'memoryConsumedBytes': 8908800}
# Submission: {'id': 227852251, 'contestId': 1881, 'creationTimeSeconds': 1697123019, 'relativeTimeSeconds': 1719, 'problem': {'contestId': 1881, 'index': 'B', 'name': 'Three Threadlets', 'type': 'PROGRAMMING', 'tags': ['math']}, 'author': {'contestId': 1881, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1697121300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 22, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 227842298, 'contestId': 1881, 'creationTimeSeconds': 1697122410, 'relativeTimeSeconds': 1110, 'problem': {'contestId': 1881, 'index': 'A', 'name': "Don't Try to Count", 'type': 'PROGRAMMING', 'tags': ['brute force', 'strings']}, 'author': {'contestId': 1881, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1697121300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 58, 'timeConsumedMillis': 78, 'memoryConsumedBytes': 0}
# Submission: {'id': 227837225, 'contestId': 1881, 'creationTimeSeconds': 1697122100, 'relativeTimeSeconds': 800, 'problem': {'contestId': 1881, 'index': 'A', 'name': "Don't Try to Count", 'type': 'PROGRAMMING', 'tags': ['brute force', 'strings']}, 'author': {'contestId': 1881, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1697121300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 1, 'timeConsumedMillis': 31, 'memoryConsumedBytes': 0}
# Submission: {'id': 227833781, 'contestId': 1881, 'creationTimeSeconds': 1697121881, 'relativeTimeSeconds': 581, 'problem': {'contestId': 1881, 'index': 'A', 'name': "Don't Try to Count", 'type': 'PROGRAMMING', 'tags': ['brute force', 'strings']}, 'author': {'contestId': 1881, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1697121300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 1, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 227740779, 'contestId': 1673, 'creationTimeSeconds': 1697066453, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1673, 'index': 'C', 'name': 'Palindrome Basis', 'type': 'PROGRAMMING', 'points': 1500.0, 'rating': 1500, 'tags': ['brute force', 'dp', 'math', 'number theory']}, 'author': {'contestId': 1673, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1651329300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 10, 'timeConsumedMillis': 436, 'memoryConsumedBytes': 168038400}
# Submission: {'id': 227740661, 'contestId': 1673, 'creationTimeSeconds': 1697066217, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1673, 'index': 'C', 'name': 'Palindrome Basis', 'type': 'PROGRAMMING', 'points': 1500.0, 'rating': 1500, 'tags': ['brute force', 'dp', 'math', 'number theory']}, 'author': {'contestId': 1673, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1651329300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'TIME_LIMIT_EXCEEDED', 'testset': 'TESTS', 'passedTestCount': 1, 'timeConsumedMillis': 2000, 'memoryConsumedBytes': 102400}
# Submission: {'id': 227738013, 'contestId': 628, 'creationTimeSeconds': 1697061233, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 628, 'index': 'B', 'name': 'New Skateboard', 'type': 'PROGRAMMING', 'rating': 1300, 'tags': ['dp']}, 'author': {'contestId': 628, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1455894000}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 22, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 3481600}
# Submission: {'id': 227737679, 'contestId': 628, 'creationTimeSeconds': 1697060734, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 628, 'index': 'B', 'name': 'New Skateboard', 'type': 'PROGRAMMING', 'rating': 1300, 'tags': ['dp']}, 'author': {'contestId': 628, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1455894000}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 22, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 1024000}
# Submission: {'id': 227737301, 'contestId': 189, 'creationTimeSeconds': 1697060251, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 189, 'index': 'A', 'name': 'Cut Ribbon', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 1300, 'tags': ['brute force', 'dp']}, 'author': {'contestId': 189, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1336663800}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 58, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 227736896, 'contestId': 698, 'creationTimeSeconds': 1697059681, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 698, 'index': 'A', 'name': 'Vacations', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 1400, 'tags': ['dp']}, 'author': {'contestId': 698, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1468933500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 88, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 227456910, 'contestId': 1715, 'creationTimeSeconds': 1696884954, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1715, 'index': 'C', 'name': 'Monoblock', 'type': 'PROGRAMMING', 'points': 1750.0, 'rating': 1700, 'tags': ['combinatorics', 'data structures', 'implementation', 'math']}, 'author': {'contestId': 1715, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1661006100}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 35, 'timeConsumedMillis': 77, 'memoryConsumedBytes': 819200}
# Submission: {'id': 227402249, 'contestId': 1886, 'creationTimeSeconds': 1696867191, 'relativeTimeSeconds': 5091, 'problem': {'contestId': 1886, 'index': 'C', 'name': 'Decreasing String', 'type': 'PROGRAMMING', 'tags': ['implementation', 'strings']}, 'author': {'contestId': 1886, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1696862100}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 1, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 227393453, 'contestId': 1886, 'creationTimeSeconds': 1696866354, 'relativeTimeSeconds': 4254, 'problem': {'contestId': 1886, 'index': 'C', 'name': 'Decreasing String', 'type': 'PROGRAMMING', 'tags': ['implementation', 'strings']}, 'author': {'contestId': 1886, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1696862100}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 1, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 227377698, 'contestId': 1886, 'creationTimeSeconds': 1696864957, 'relativeTimeSeconds': 2857, 'problem': {'contestId': 1886, 'index': 'C', 'name': 'Decreasing String', 'type': 'PROGRAMMING', 'tags': ['implementation', 'strings']}, 'author': {'contestId': 1886, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1696862100}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 1, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 227373437, 'contestId': 1886, 'creationTimeSeconds': 1696864602, 'relativeTimeSeconds': 2502, 'problem': {'contestId': 1886, 'index': 'C', 'name': 'Decreasing String', 'type': 'PROGRAMMING', 'tags': ['implementation', 'strings']}, 'author': {'contestId': 1886, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1696862100}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 1, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 227358901, 'contestId': 1886, 'creationTimeSeconds': 1696863478, 'relativeTimeSeconds': 1378, 'problem': {'contestId': 1886, 'index': 'B', 'name': 'Fear of the Dark', 'type': 'PROGRAMMING', 'tags': ['binary search', 'geometry', 'math']}, 'author': {'contestId': 1886, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1696862100}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 11, 'timeConsumedMillis': 31, 'memoryConsumedBytes': 0}
# Submission: {'id': 227354665, 'contestId': 1886, 'creationTimeSeconds': 1696863179, 'relativeTimeSeconds': 1078, 'problem': {'contestId': 1886, 'index': 'B', 'name': 'Fear of the Dark', 'type': 'PROGRAMMING', 'tags': ['binary search', 'geometry', 'math']}, 'author': {'contestId': 1886, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1696862100}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 0, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 227341331, 'contestId': 1886, 'creationTimeSeconds': 1696862323, 'relativeTimeSeconds': 223, 'problem': {'contestId': 1886, 'index': 'A', 'name': 'Sum of Three', 'type': 'PROGRAMMING', 'tags': ['brute force', 'constructive algorithms', 'math']}, 'author': {'contestId': 1886, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1696862100}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 10, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 227340413, 'contestId': 1872, 'creationTimeSeconds': 1696862035, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1872, 'index': 'E', 'name': 'Data Structures Fan', 'type': 'PROGRAMMING', 'rating': 1500, 'tags': ['binary search', 'bitmasks', 'data structures', 'dp']}, 'author': {'contestId': 1872, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1694097300}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 28, 'timeConsumedMillis': 62, 'memoryConsumedBytes': 2048000}
# Submission: {'id': 226075596, 'contestId': 1875, 'creationTimeSeconds': 1696101913, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1875, 'index': 'D', 'name': 'Jellyfish and Mex', 'type': 'PROGRAMMING', 'points': 1250.0, 'tags': ['dp']}, 'author': {'contestId': 1875, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1696084500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 20, 'timeConsumedMillis': 249, 'memoryConsumedBytes': 201420800}
# Submission: {'id': 226068360, 'contestId': 1875, 'creationTimeSeconds': 1696098623, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1875, 'index': 'D', 'name': 'Jellyfish and Mex', 'type': 'PROGRAMMING', 'points': 1250.0, 'tags': ['dp']}, 'author': {'contestId': 1875, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1696084500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 1, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 226049087, 'contestId': 1875, 'creationTimeSeconds': 1696093222, 'relativeTimeSeconds': 8722, 'problem': {'contestId': 1875, 'index': 'D', 'name': 'Jellyfish and Mex', 'type': 'PROGRAMMING', 'points': 1250.0, 'tags': ['dp']}, 'author': {'contestId': 1875, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 343, 'startTimeSeconds': 1696084500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 1, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 226039595, 'contestId': 1875, 'creationTimeSeconds': 1696091896, 'relativeTimeSeconds': 7396, 'problem': {'contestId': 1875, 'index': 'D', 'name': 'Jellyfish and Mex', 'type': 'PROGRAMMING', 'points': 1250.0, 'tags': ['dp']}, 'author': {'contestId': 1875, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 343, 'startTimeSeconds': 1696084500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 1, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 226020151, 'contestId': 1875, 'creationTimeSeconds': 1696090609, 'relativeTimeSeconds': 6109, 'problem': {'contestId': 1875, 'index': 'C', 'name': 'Jellyfish and Green Apple', 'type': 'PROGRAMMING', 'points': 1000.0, 'tags': ['bitmasks', 'greedy', 'math', 'number theory']}, 'author': {'contestId': 1875, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 343, 'startTimeSeconds': 1696084500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 20, 'timeConsumedMillis': 30, 'memoryConsumedBytes': 0}
# Submission: {'id': 226006913, 'contestId': 1875, 'creationTimeSeconds': 1696090153, 'relativeTimeSeconds': 5653, 'problem': {'contestId': 1875, 'index': 'C', 'name': 'Jellyfish and Green Apple', 'type': 'PROGRAMMING', 'points': 1000.0, 'tags': ['bitmasks', 'greedy', 'math', 'number theory']}, 'author': {'contestId': 1875, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 343, 'startTimeSeconds': 1696084500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 1, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 226006281, 'contestId': 1875, 'creationTimeSeconds': 1696090088, 'relativeTimeSeconds': 5588, 'problem': {'contestId': 1875, 'index': 'C', 'name': 'Jellyfish and Green Apple', 'type': 'PROGRAMMING', 'points': 1000.0, 'tags': ['bitmasks', 'greedy', 'math', 'number theory']}, 'author': {'contestId': 1875, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 343, 'startTimeSeconds': 1696084500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 1, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 225948592, 'contestId': 1875, 'creationTimeSeconds': 1696085807, 'relativeTimeSeconds': 1307, 'problem': {'contestId': 1875, 'index': 'B', 'name': 'Jellyfish and Game', 'type': 'PROGRAMMING', 'points': 1000.0, 'tags': ['brute force', 'greedy', 'implementation']}, 'author': {'contestId': 1875, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 343, 'startTimeSeconds': 1696084500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 10, 'timeConsumedMillis': 140, 'memoryConsumedBytes': 0}
# Submission: {'id': 225921705, 'contestId': 1875, 'creationTimeSeconds': 1696084685, 'relativeTimeSeconds': 185, 'problem': {'contestId': 1875, 'index': 'A', 'name': 'Jellyfish and Undertale', 'type': 'PROGRAMMING', 'points': 500.0, 'tags': ['brute force', 'greedy']}, 'author': {'contestId': 1875, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 343, 'startTimeSeconds': 1696084500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 10, 'timeConsumedMillis': 46, 'memoryConsumedBytes': 0}
# Submission: {'id': 225656694, 'contestId': 1879, 'creationTimeSeconds': 1695907609, 'relativeTimeSeconds': 1549, 'problem': {'contestId': 1879, 'index': 'C', 'name': 'Make it Alternating', 'type': 'PROGRAMMING', 'rating': 1300, 'tags': ['combinatorics', 'dp', 'greedy']}, 'author': {'contestId': 1879, 'members': [{'handle': 'agrim07'}], 'participantType': 'VIRTUAL', 'ghost': False, 'startTimeSeconds': 1695906060}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 1, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 819200}
# Submission: {'id': 225654798, 'contestId': 1879, 'creationTimeSeconds': 1695906726, 'relativeTimeSeconds': 666, 'problem': {'contestId': 1879, 'index': 'B', 'name': 'Chips on the Board', 'type': 'PROGRAMMING', 'rating': 900, 'tags': ['constructive algorithms', 'greedy']}, 'author': {'contestId': 1879, 'members': [{'handle': 'agrim07'}], 'participantType': 'VIRTUAL', 'ghost': False, 'startTimeSeconds': 1695906060}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 10, 'timeConsumedMillis': 124, 'memoryConsumedBytes': 4812800}
# Submission: {'id': 225654206, 'contestId': 1879, 'creationTimeSeconds': 1695906465, 'relativeTimeSeconds': 405, 'problem': {'contestId': 1879, 'index': 'A', 'name': 'Rigged!', 'type': 'PROGRAMMING', 'rating': 800, 'tags': ['greedy']}, 'author': {'contestId': 1879, 'members': [{'handle': 'agrim07'}], 'participantType': 'VIRTUAL', 'ghost': False, 'startTimeSeconds': 1695906060}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 7, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 225544619, 'contestId': 1878, 'creationTimeSeconds': 1695831905, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1878, 'index': 'F', 'name': 'Vasilije Loves Number Theory', 'type': 'PROGRAMMING', 'tags': ['brute force', 'math', 'number theory']}, 'author': {'contestId': 1878, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1695738900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 22, 'timeConsumedMillis': 46, 'memoryConsumedBytes': 8192000}
# Submission: {'id': 225424505, 'contestId': 1878, 'creationTimeSeconds': 1695754406, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1878, 'index': 'E', 'name': 'Iva & Pav', 'type': 'PROGRAMMING', 'tags': ['binary search', 'bitmasks', 'data structures', 'greedy']}, 'author': {'contestId': 1878, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1695738900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 20, 'timeConsumedMillis': 358, 'memoryConsumedBytes': 69120000}
# Submission: {'id': 225362715, 'contestId': 1878, 'creationTimeSeconds': 1695743129, 'relativeTimeSeconds': 4229, 'problem': {'contestId': 1878, 'index': 'D', 'name': 'Reverse Madness', 'type': 'PROGRAMMING', 'tags': ['data structures', 'greedy']}, 'author': {'contestId': 1878, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695738900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 15, 'timeConsumedMillis': 124, 'memoryConsumedBytes': 4300800}
# Submission: {'id': 225333554, 'contestId': 1878, 'creationTimeSeconds': 1695741227, 'relativeTimeSeconds': 2327, 'problem': {'contestId': 1878, 'index': 'B', 'name': 'Aleksa and Stack', 'type': 'PROGRAMMING', 'tags': ['constructive algorithms', 'math']}, 'author': {'contestId': 1878, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695738900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 6, 'timeConsumedMillis': 30, 'memoryConsumedBytes': 1228800}
# Submission: {'id': 225327754, 'contestId': 1878, 'creationTimeSeconds': 1695740945, 'relativeTimeSeconds': 2045, 'problem': {'contestId': 1878, 'index': 'C', 'name': 'Vasilije in Cacak', 'type': 'PROGRAMMING', 'tags': ['math']}, 'author': {'contestId': 1878, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695738900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 41, 'timeConsumedMillis': 30, 'memoryConsumedBytes': 1331200}
# Submission: {'id': 225290032, 'contestId': 1878, 'creationTimeSeconds': 1695739446, 'relativeTimeSeconds': 546, 'problem': {'contestId': 1878, 'index': 'B', 'name': 'Aleksa and Stack', 'type': 'PROGRAMMING', 'tags': ['constructive algorithms', 'math']}, 'author': {'contestId': 1878, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695738900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 0, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 225285910, 'contestId': 1878, 'creationTimeSeconds': 1695739299, 'relativeTimeSeconds': 399, 'problem': {'contestId': 1878, 'index': 'A', 'name': 'How Much Does Daytona Cost?', 'type': 'PROGRAMMING', 'tags': ['greedy']}, 'author': {'contestId': 1878, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695738900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 14, 'timeConsumedMillis': 31, 'memoryConsumedBytes': 1228800}
# Submission: {'id': 225140454, 'contestId': 1882, 'creationTimeSeconds': 1695657544, 'relativeTimeSeconds': 5044, 'problem': {'contestId': 1882, 'index': 'C', 'name': 'Card Game', 'type': 'PROGRAMMING', 'points': 1500.0, 'tags': ['brute force', 'greedy']}, 'author': {'contestId': 1882, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 121, 'startTimeSeconds': 1695652500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 26, 'timeConsumedMillis': 109, 'memoryConsumedBytes': 13414400}
# Submission: {'id': 225139970, 'contestId': 1882, 'creationTimeSeconds': 1695657470, 'relativeTimeSeconds': 4970, 'problem': {'contestId': 1882, 'index': 'C', 'name': 'Card Game', 'type': 'PROGRAMMING', 'points': 1500.0, 'tags': ['brute force', 'greedy']}, 'author': {'contestId': 1882, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 121, 'startTimeSeconds': 1695652500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'TIME_LIMIT_EXCEEDED', 'testset': 'PRETESTS', 'passedTestCount': 3, 'timeConsumedMillis': 2000, 'memoryConsumedBytes': 716800}
# Submission: {'id': 225127261, 'contestId': 1882, 'creationTimeSeconds': 1695655665, 'relativeTimeSeconds': 3165, 'problem': {'contestId': 1882, 'index': 'C', 'name': 'Card Game', 'type': 'PROGRAMMING', 'points': 1500.0, 'tags': ['brute force', 'greedy']}, 'author': {'contestId': 1882, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 121, 'startTimeSeconds': 1695652500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 1, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 225111576, 'contestId': 1882, 'creationTimeSeconds': 1695653780, 'relativeTimeSeconds': 1280, 'problem': {'contestId': 1882, 'index': 'B', 'name': 'Sets and Union', 'type': 'PROGRAMMING', 'points': 1000.0, 'tags': ['bitmasks', 'brute force', 'constructive algorithms', 'greedy']}, 'author': {'contestId': 1882, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 121, 'startTimeSeconds': 1695652500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 12, 'timeConsumedMillis': 46, 'memoryConsumedBytes': 409600}
# Submission: {'id': 225096370, 'contestId': 1882, 'creationTimeSeconds': 1695652702, 'relativeTimeSeconds': 202, 'problem': {'contestId': 1882, 'index': 'A', 'name': 'Increasing Sequence', 'type': 'PROGRAMMING', 'points': 500.0, 'tags': ['greedy']}, 'author': {'contestId': 1882, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 121, 'startTimeSeconds': 1695652500}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 8, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 224496005, 'contestId': 1873, 'creationTimeSeconds': 1695315378, 'relativeTimeSeconds': 8478, 'problem': {'contestId': 1873, 'index': 'H', 'name': 'Mad City', 'type': 'PROGRAMMING', 'rating': 1700, 'tags': ['dfs and similar', 'dsu', 'games', 'graphs', 'shortest paths', 'trees']}, 'author': {'contestId': 1873, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695306900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 13, 'timeConsumedMillis': 249, 'memoryConsumedBytes': 33689600}
# Submission: {'id': 224492076, 'contestId': 1873, 'creationTimeSeconds': 1695315077, 'relativeTimeSeconds': 8177, 'problem': {'contestId': 1873, 'index': 'H', 'name': 'Mad City', 'type': 'PROGRAMMING', 'rating': 1700, 'tags': ['dfs and similar', 'dsu', 'games', 'graphs', 'shortest paths', 'trees']}, 'author': {'contestId': 1873, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695306900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'TIME_LIMIT_EXCEEDED', 'testset': 'TESTS', 'passedTestCount': 4, 'timeConsumedMillis': 4000, 'memoryConsumedBytes': 4505600}
# Submission: {'id': 224455794, 'contestId': 1873, 'creationTimeSeconds': 1695312593, 'relativeTimeSeconds': 5693, 'problem': {'contestId': 1873, 'index': 'E', 'name': 'Building an Aquarium', 'type': 'PROGRAMMING', 'rating': 1100, 'tags': ['binary search', 'sortings']}, 'author': {'contestId': 1873, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695306900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 28, 'timeConsumedMillis': 62, 'memoryConsumedBytes': 1638400}
# Submission: {'id': 224431420, 'contestId': 1873, 'creationTimeSeconds': 1695311209, 'relativeTimeSeconds': 4309, 'problem': {'contestId': 1873, 'index': 'G', 'name': 'ABBC or BACB', 'type': 'PROGRAMMING', 'rating': 1500, 'tags': ['constructive algorithms', 'greedy']}, 'author': {'contestId': 1873, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695306900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 10, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 4505600}
# Submission: {'id': 224412312, 'contestId': 1873, 'creationTimeSeconds': 1695310259, 'relativeTimeSeconds': 3359, 'problem': {'contestId': 1873, 'index': 'F', 'name': 'Money Trees', 'type': 'PROGRAMMING', 'rating': 1300, 'tags': ['binary search', 'greedy', 'math', 'two pointers']}, 'author': {'contestId': 1873, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695306900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 21, 'timeConsumedMillis': 62, 'memoryConsumedBytes': 4812800}
# Submission: {'id': 224383635, 'contestId': 1873, 'creationTimeSeconds': 1695309064, 'relativeTimeSeconds': 2164, 'problem': {'contestId': 1873, 'index': 'E', 'name': 'Building an Aquarium', 'type': 'PROGRAMMING', 'rating': 1100, 'tags': ['binary search', 'sortings']}, 'author': {'contestId': 1873, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695306900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 3, 'timeConsumedMillis': 31, 'memoryConsumedBytes': 0}
# Submission: {'id': 224378222, 'contestId': 1873, 'creationTimeSeconds': 1695308868, 'relativeTimeSeconds': 1968, 'problem': {'contestId': 1873, 'index': 'E', 'name': 'Building an Aquarium', 'type': 'PROGRAMMING', 'rating': 1100, 'tags': ['binary search', 'sortings']}, 'author': {'contestId': 1873, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695306900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 2, 'timeConsumedMillis': 31, 'memoryConsumedBytes': 0}
# Submission: {'id': 224375876, 'contestId': 1873, 'creationTimeSeconds': 1695308787, 'relativeTimeSeconds': 1887, 'problem': {'contestId': 1873, 'index': 'E', 'name': 'Building an Aquarium', 'type': 'PROGRAMMING', 'rating': 1100, 'tags': ['binary search', 'sortings']}, 'author': {'contestId': 1873, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695306900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 2, 'timeConsumedMillis': 31, 'memoryConsumedBytes': 0}
# Submission: {'id': 224369349, 'contestId': 1873, 'creationTimeSeconds': 1695308567, 'relativeTimeSeconds': 1666, 'problem': {'contestId': 1873, 'index': 'D', 'name': '1D Eraser', 'type': 'PROGRAMMING', 'rating': 800, 'tags': ['greedy', 'implementation', 'two pointers']}, 'author': {'contestId': 1873, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695306900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 9, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 512000}
# Submission: {'id': 224363999, 'contestId': 1873, 'creationTimeSeconds': 1695308387, 'relativeTimeSeconds': 1487, 'problem': {'contestId': 1873, 'index': 'C', 'name': 'Target Practice', 'type': 'PROGRAMMING', 'rating': 800, 'tags': ['implementation', 'math']}, 'author': {'contestId': 1873, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695306900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 3, 'timeConsumedMillis': 30, 'memoryConsumedBytes': 0}
# Submission: {'id': 224356502, 'contestId': 1873, 'creationTimeSeconds': 1695308140, 'relativeTimeSeconds': 1240, 'problem': {'contestId': 1873, 'index': 'B', 'name': 'Good Kid', 'type': 'PROGRAMMING', 'rating': 800, 'tags': ['brute force', 'greedy', 'math']}, 'author': {'contestId': 1873, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695306900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 5, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 224352715, 'contestId': 1873, 'creationTimeSeconds': 1695308011, 'relativeTimeSeconds': 1111, 'problem': {'contestId': 1873, 'index': 'A', 'name': 'Short Sort', 'type': 'PROGRAMMING', 'rating': 800, 'tags': ['brute force', 'implementation']}, 'author': {'contestId': 1873, 'members': [{'handle': 'agrim07'}], 'participantType': 'OUT_OF_COMPETITION', 'ghost': False, 'startTimeSeconds': 1695306900}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 5, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 223379019, 'contestId': 1867, 'creationTimeSeconds': 1694707457, 'relativeTimeSeconds': 2057, 'problem': {'contestId': 1867, 'index': 'C', 'name': 'Salyg1n and the MEX Game', 'type': 'PROGRAMMING', 'points': 1250.0, 'rating': 1300, 'tags': ['constructive algorithms', 'data structures', 'games', 'greedy', 'interactive']}, 'author': {'contestId': 1867, 'members': [{'handle': 'agrim07'}], 'participantType': 'VIRTUAL', 'ghost': False, 'startTimeSeconds': 1694705400}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 23, 'timeConsumedMillis': 950, 'memoryConsumedBytes': 819200}
# Submission: {'id': 223378702, 'contestId': 1867, 'creationTimeSeconds': 1694707328, 'relativeTimeSeconds': 1928, 'problem': {'contestId': 1867, 'index': 'C', 'name': 'Salyg1n and the MEX Game', 'type': 'PROGRAMMING', 'points': 1250.0, 'rating': 1300, 'tags': ['constructive algorithms', 'data structures', 'games', 'greedy', 'interactive']}, 'author': {'contestId': 1867, 'members': [{'handle': 'agrim07'}], 'participantType': 'VIRTUAL', 'ghost': False, 'startTimeSeconds': 1694705400}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 0, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 223376751, 'contestId': 1867, 'creationTimeSeconds': 1694706538, 'relativeTimeSeconds': 1138, 'problem': {'contestId': 1867, 'index': 'B', 'name': 'XOR Palindromes', 'type': 'PROGRAMMING', 'points': 1000.0, 'rating': 1100, 'tags': ['bitmasks', 'constructive algorithms', 'strings']}, 'author': {'contestId': 1867, 'members': [{'handle': 'agrim07'}], 'participantType': 'VIRTUAL', 'ghost': False, 'startTimeSeconds': 1694705400}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 11, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 409600}
# Submission: {'id': 223374729, 'contestId': 1867, 'creationTimeSeconds': 1694705758, 'relativeTimeSeconds': 358, 'problem': {'contestId': 1867, 'index': 'A', 'name': 'green_gold_dog, array and permutation', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 800, 'tags': ['constructive algorithms', 'sortings']}, 'author': {'contestId': 1867, 'members': [{'handle': 'agrim07'}], 'participantType': 'VIRTUAL', 'ghost': False, 'startTimeSeconds': 1694705400}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 11, 'timeConsumedMillis': 62, 'memoryConsumedBytes': 4505600}
# Submission: {'id': 223374618, 'contestId': 1867, 'creationTimeSeconds': 1694705716, 'relativeTimeSeconds': 316, 'problem': {'contestId': 1867, 'index': 'A', 'name': 'green_gold_dog, array and permutation', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 800, 'tags': ['constructive algorithms', 'sortings']}, 'author': {'contestId': 1867, 'members': [{'handle': 'agrim07'}], 'participantType': 'VIRTUAL', 'ghost': False, 'startTimeSeconds': 1694705400}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 1, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 222823634, 'contestId': 1869, 'creationTimeSeconds': 1694374044, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1869, 'index': 'D1', 'name': 'Candy Party (Easy Version)', 'type': 'PROGRAMMING', 'points': 1250.0, 'rating': 1700, 'tags': ['bitmasks', 'constructive algorithms', 'graphs', 'implementation', 'math']}, 'author': {'contestId': 1869, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1694354700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 2, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 222783311, 'contestId': 1869, 'creationTimeSeconds': 1694361001, 'relativeTimeSeconds': 6301, 'problem': {'contestId': 1869, 'index': 'D1', 'name': 'Candy Party (Easy Version)', 'type': 'PROGRAMMING', 'points': 1250.0, 'rating': 1700, 'tags': ['bitmasks', 'constructive algorithms', 'graphs', 'implementation', 'math']}, 'author': {'contestId': 1869, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 13, 'startTimeSeconds': 1694354700}, 'programmingLanguage': 'GNU C++20 (64)', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 5, 'timeConsumedMillis': 31, 'memoryConsumedBytes': 1638400}
# ...
# Submission: {'id': 187323561, 'contestId': 1770, 'creationTimeSeconds': 1672414912, 'relativeTimeSeconds': 4012, 'problem': {'contestId': 1770, 'index': 'A', 'name': 'Koxia and Whiteboards', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 1000, 'tags': ['brute force', 'greedy']}, 'author': {'contestId': 1770, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 386, 'startTimeSeconds': 1672410900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 1, 'timeConsumedMillis': 78, 'memoryConsumedBytes': 0}
# Submission: {'id': 187306603, 'contestId': 1770, 'creationTimeSeconds': 1672413677, 'relativeTimeSeconds': 2777, 'problem': {'contestId': 1770, 'index': 'A', 'name': 'Koxia and Whiteboards', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 1000, 'tags': ['brute force', 'greedy']}, 'author': {'contestId': 1770, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 386, 'startTimeSeconds': 1672410900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 1, 'timeConsumedMillis': 62, 'memoryConsumedBytes': 0}
# Submission: {'id': 187297035, 'contestId': 1770, 'creationTimeSeconds': 1672413080, 'relativeTimeSeconds': 2180, 'problem': {'contestId': 1770, 'index': 'A', 'name': 'Koxia and Whiteboards', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 1000, 'tags': ['brute force', 'greedy']}, 'author': {'contestId': 1770, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 386, 'startTimeSeconds': 1672410900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'WRONG_ANSWER', 'testset': 'PRETESTS', 'passedTestCount': 1, 'timeConsumedMillis': 77, 'memoryConsumedBytes': 0}
# Submission: {'id': 186936324, 'contestId': 1731, 'creationTimeSeconds': 1672157172, 'relativeTimeSeconds': 5472, 'problem': {'contestId': 1731, 'index': 'B', 'name': 'Kill Demodogs', 'type': 'PROGRAMMING', 'points': 1000.0, 'rating': 1100, 'tags': ['greedy', 'math']}, 'author': {'contestId': 1731, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 205, 'startTimeSeconds': 1672151700}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 15, 'timeConsumedMillis': 62, 'memoryConsumedBytes': 0}
# Submission: {'id': 186935205, 'contestId': 1731, 'creationTimeSeconds': 1672157031, 'relativeTimeSeconds': 5331, 'problem': {'contestId': 1731, 'index': 'B', 'name': 'Kill Demodogs', 'type': 'PROGRAMMING', 'points': 1000.0, 'rating': 1100, 'tags': ['greedy', 'math']}, 'author': {'contestId': 1731, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 205, 'startTimeSeconds': 1672151700}, 'programmingLanguage': 'GNU C++14', 'verdict': 'COMPILATION_ERROR', 'testset': 'PRETESTS', 'passedTestCount': 0, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 186906849, 'contestId': 1731, 'creationTimeSeconds': 1672153595, 'relativeTimeSeconds': 1895, 'problem': {'contestId': 1731, 'index': 'A', 'name': 'Joey Takes Money', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 800, 'tags': ['greedy', 'math']}, 'author': {'contestId': 1731, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 205, 'startTimeSeconds': 1672151700}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 10, 'timeConsumedMillis': 156, 'memoryConsumedBytes': 0}
# Submission: {'id': 186115726, 'contestId': 1772, 'creationTimeSeconds': 1671547661, 'relativeTimeSeconds': 6401, 'problem': {'contestId': 1772, 'index': 'C', 'name': 'Different Differences', 'type': 'PROGRAMMING', 'rating': 1000, 'tags': ['constructive algorithms', 'greedy', 'math']}, 'author': {'contestId': 1772, 'members': [{'handle': 'agrim07'}], 'participantType': 'VIRTUAL', 'ghost': False, 'startTimeSeconds': 1671541260}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 5, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 186108634, 'contestId': 1772, 'creationTimeSeconds': 1671543869, 'relativeTimeSeconds': 2609, 'problem': {'contestId': 1772, 'index': 'B', 'name': 'Matrix Rotation', 'type': 'PROGRAMMING', 'rating': 800, 'tags': ['brute force', 'implementation']}, 'author': {'contestId': 1772, 'members': [{'handle': 'agrim07'}], 'participantType': 'VIRTUAL', 'ghost': False, 'startTimeSeconds': 1671541260}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 8, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 186104738, 'contestId': 1772, 'creationTimeSeconds': 1671541478, 'relativeTimeSeconds': 218, 'problem': {'contestId': 1772, 'index': 'A', 'name': 'A+B?', 'type': 'PROGRAMMING', 'rating': 800, 'tags': ['implementation']}, 'author': {'contestId': 1772, 'members': [{'handle': 'agrim07'}], 'participantType': 'VIRTUAL', 'ghost': False, 'startTimeSeconds': 1671541260}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 29, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 185755979, 'contestId': 1774, 'creationTimeSeconds': 1671346057, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1774, 'index': 'A', 'name': 'Add Plus Minus Sign', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 800, 'tags': ['constructive algorithms', 'math']}, 'author': {'contestId': 1774, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1671287700}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 6, 'timeConsumedMillis': 46, 'memoryConsumedBytes': 0}
# Submission: {'id': 185689548, 'contestId': 1774, 'creationTimeSeconds': 1671293312, 'relativeTimeSeconds': 5612, 'problem': {'contestId': 1774, 'index': 'A', 'name': 'Add Plus Minus Sign', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 800, 'tags': ['constructive algorithms', 'math']}, 'author': {'contestId': 1774, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'room': 47, 'startTimeSeconds': 1671287700}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 6, 'timeConsumedMillis': 46, 'memoryConsumedBytes': 0}
# Submission: {'id': 185554170, 'contestId': 1771, 'creationTimeSeconds': 1671217548, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1771, 'index': 'B', 'name': 'Hossam and Friends', 'type': 'PROGRAMMING', 'points': 1000.0, 'rating': 1400, 'tags': ['binary search', 'constructive algorithms', 'dp', 'two pointers']}, 'author': {'contestId': 1771, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1670772900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'TIME_LIMIT_EXCEEDED', 'testset': 'TESTS', 'passedTestCount': 3, 'timeConsumedMillis': 2000, 'memoryConsumedBytes': 1228800}
# Submission: {'id': 185443138, 'contestId': 1771, 'creationTimeSeconds': 1671187024, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1771, 'index': 'A', 'name': 'Hossam and Combinatorics', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 900, 'tags': ['combinatorics', 'math', 'sortings']}, 'author': {'contestId': 1771, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1670772900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 28, 'timeConsumedMillis': 124, 'memoryConsumedBytes': 409600}
# Submission: {'id': 185442113, 'contestId': 1771, 'creationTimeSeconds': 1671186282, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1771, 'index': 'A', 'name': 'Hossam and Combinatorics', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 900, 'tags': ['combinatorics', 'math', 'sortings']}, 'author': {'contestId': 1771, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1670772900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 2, 'timeConsumedMillis': 109, 'memoryConsumedBytes': 409600}
# Submission: {'id': 185441770, 'contestId': 1771, 'creationTimeSeconds': 1671186051, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1771, 'index': 'A', 'name': 'Hossam and Combinatorics', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 900, 'tags': ['combinatorics', 'math', 'sortings']}, 'author': {'contestId': 1771, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1670772900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 2, 'timeConsumedMillis': 109, 'memoryConsumedBytes': 409600}
# Submission: {'id': 185441332, 'contestId': 1771, 'creationTimeSeconds': 1671185750, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1771, 'index': 'A', 'name': 'Hossam and Combinatorics', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 900, 'tags': ['combinatorics', 'math', 'sortings']}, 'author': {'contestId': 1771, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1670772900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 0, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 185379324, 'contestId': 1762, 'creationTimeSeconds': 1671128163, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1762, 'index': 'A', 'name': 'Divide and Conquer', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 800, 'tags': ['greedy', 'math', 'number theory']}, 'author': {'contestId': 1762, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1671114900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 4, 'timeConsumedMillis': 61, 'memoryConsumedBytes': 0}
# Submission: {'id': 185378025, 'contestId': 1762, 'creationTimeSeconds': 1671127590, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1762, 'index': 'B', 'name': 'Make Array Good', 'type': 'PROGRAMMING', 'points': 1000.0, 'rating': 1100, 'tags': ['constructive algorithms', 'implementation', 'number theory', 'sortings']}, 'author': {'contestId': 1762, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1671114900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 9, 'timeConsumedMillis': 483, 'memoryConsumedBytes': 409600}
# Submission: {'id': 185377481, 'contestId': 1762, 'creationTimeSeconds': 1671127359, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1762, 'index': 'B', 'name': 'Make Array Good', 'type': 'PROGRAMMING', 'points': 1000.0, 'rating': 1100, 'tags': ['constructive algorithms', 'implementation', 'number theory', 'sortings']}, 'author': {'contestId': 1762, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1671114900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 0, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 185377360, 'contestId': 1762, 'creationTimeSeconds': 1671127298, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1762, 'index': 'B', 'name': 'Make Array Good', 'type': 'PROGRAMMING', 'points': 1000.0, 'rating': 1100, 'tags': ['constructive algorithms', 'implementation', 'number theory', 'sortings']}, 'author': {'contestId': 1762, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1671114900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'COMPILATION_ERROR', 'testset': 'TESTS', 'passedTestCount': 0, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 185377243, 'contestId': 1762, 'creationTimeSeconds': 1671127244, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1762, 'index': 'A', 'name': 'Divide and Conquer', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 800, 'tags': ['greedy', 'math', 'number theory']}, 'author': {'contestId': 1762, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1671114900}, 'programmingLanguage': 'GNU C++14', 'verdict': 'WRONG_ANSWER', 'testset': 'TESTS', 'passedTestCount': 0, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}
# Submission: {'id': 185053491, 'contestId': 1766, 'creationTimeSeconds': 1670923155, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1766, 'index': 'C', 'name': 'Hamiltonian Wall', 'type': 'PROGRAMMING', 'rating': 1300, 'tags': ['dp', 'implementation']}, 'author': {'contestId': 1766, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1670855700}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 14, 'timeConsumedMillis': 109, 'memoryConsumedBytes': 716800}
# Submission: {'id': 184956310, 'contestId': 1766, 'creationTimeSeconds': 1670860244, 'relativeTimeSeconds': 4544, 'problem': {'contestId': 1766, 'index': 'B', 'name': 'Notepad#', 'type': 'PROGRAMMING', 'rating': 1000, 'tags': ['implementation']}, 'author': {'contestId': 1766, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1670855700}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 9, 'timeConsumedMillis': 2215, 'memoryConsumedBytes': 512000}
# Submission: {'id': 184943867, 'contestId': 1766, 'creationTimeSeconds': 1670858840, 'relativeTimeSeconds': 3140, 'problem': {'contestId': 1766, 'index': 'A', 'name': 'Extremely Round', 'type': 'PROGRAMMING', 'rating': 800, 'tags': ['brute force', 'implementation']}, 'author': {'contestId': 1766, 'members': [{'handle': 'agrim07'}], 'participantType': 'CONTESTANT', 'ghost': False, 'startTimeSeconds': 1670855700}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 20, 'timeConsumedMillis': 77, 'memoryConsumedBytes': 40038400}
# Submission: {'id': 180158541, 'contestId': 1102, 'creationTimeSeconds': 1667972941, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 1102, 'index': 'A', 'name': 'Integer Sequence Dividing', 'type': 'PROGRAMMING', 'rating': 800, 'tags': ['math']}, 'author': {'contestId': 1102, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1547044500}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 54, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 180069819, 'contestId': 610, 'creationTimeSeconds': 1667904249, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 610, 'index': 'A', 'name': 'Pasha and Stick', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 1000, 'tags': ['combinatorics', 'math']}, 'author': {'contestId': 610, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1451215200}, 'programmingLanguage': 'GNU C++14', 'verdict': 'OK', 'testset': 'TESTS', 'passedTestCount': 76, 'timeConsumedMillis': 15, 'memoryConsumedBytes': 0}
# Submission: {'id': 180069611, 'contestId': 610, 'creationTimeSeconds': 1667904117, 'relativeTimeSeconds': 2147483647, 'problem': {'contestId': 610, 'index': 'A', 'name': 'Pasha and Stick', 'type': 'PROGRAMMING', 'points': 500.0, 'rating': 1000, 'tags': ['combinatorics', 'math']}, 'author': {'contestId': 610, 'members': [{'handle': 'agrim07'}], 'participantType': 'PRACTICE', 'ghost': False, 'startTimeSeconds': 1451215200}, 'programmingLanguage': 'GNU C11', 'verdict': 'COMPILATION_ERROR', 'testset': 'TESTS', 'passedTestCount': 0, 'timeConsumedMillis': 0, 'memoryConsumedBytes': 0}

# %%
import requests

# Replace with the user's Codeforces handle
handle = "agrim07"

# Step 1: Get User Info
user_info_url = f"https://codeforces.com/api/user.info?handles={handle}"
response = requests.get(user_info_url)
user_info = response.json()["result"][0]
user_rating = user_info["rating"]

# Step 2: Fetch Submissions
user_submissions_url = f"https://codeforces.com/api/user.status?handle={handle}"
response = requests.get(user_submissions_url)
submissions = response.json()["result"]

# Step 3: Filter and Retrieve Questions
desired_rating_range = range(1200, 1401)  # Inclusive range
questions = []

for submission in submissions:
    if "rating" in submission and submission["rating"] in desired_rating_range:
        question = {
            "contest_id": submission["contestId"],
            "problem_index": submission["problem"]["index"],
            "problem_name": submission["problem"]["name"],
            "problem_id": submission["problem"]["contestId"] + submission["problem"]["index"]
        }
        questions.append(question)

# Step 4: Optional Deduplication
unique_questions = []
seen = set()

for question in questions:
    question_id = (question["contest_id"], question["problem_index"])
    if question_id not in seen:
        unique_questions.append(question)
        seen.add(question_id)

# Print or process the unique questions
for question in unique_questions:
    print(f"Contest ID: {question['contest_id']}, Problem Index: {question['problem_index']}, Problem Name: {question['problem_name']}, Problem ID: {question['problem_id']}")

# Debugging output
print("User Rating:", user_rating)
# Out:
# User Rating: 1637

# %%
pip install concurrent.futures
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement concurrent.futures (from versions: none)
# ERROR: No matching distribution found for concurrent.futures
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json

def get_solved_problems_in_rating_range(user_handle, min_rating, max_rating):
    """Gets the set of problems done by a Codeforces user within a specific rating range.

    Args:
        user_handle: The handle of the user.
        min_rating: The minimum rating (inclusive) for the desired range.
        max_rating: The maximum rating (inclusive) for the desired range.

    Returns:
        A set of problem IDs.
    """

    # Make a request to the Codeforces API to get the user's solved list.
    response = requests.get(
        f"https://codeforces.com/api/user.status?handle={user_handle}")

    # Parse the JSON response.
    data = json.loads(response.content)

    # Get the list of solved problems within the specified rating range.
    solved_problems = set()

    for submission in data["result"]:
        if submission["verdict"] == "OK" and "problem" in submission:
            problem = submission["problem"]
            if "rating" in problem:
                rating = problem["rating"]
                if min_rating <= rating <= max_rating:
                    solved_problems.add((problem["contestId"], problem["index"]))

    return solved_problems



user_handle = "agrim07"
min_rating = 1200
max_rating = 1400
solved_problems = get_solved_problems_in_rating_range(user_handle, min_rating, max_rating)

print(solved_problems)
# Out:
# {(1844, 'D'), (1790, 'E'), (1853, 'B'), (1832, 'C'), (1857, 'D'), (1846, 'D'), (1768, 'C'), (1692, 'F'), (1872, 'D'), (1766, 'C'), (1821, 'C'), (1807, 'E'), (1805, 'C'), (1860, 'C'), (1729, 'D'), (1744, 'D'), (1714, 'E'), (1838, 'C'), (492, 'B'), (1808, 'B'), (628, 'B'), (1851, 'D'), (1705, 'C'), (1860, 'B'), (1749, 'C'), (1839, 'C'), (1762, 'C'), (1873, 'F'), (1788, 'C'), (1420, 'C1'), (1866, 'B'), (1869, 'C'), (1845, 'C'), (1826, 'A'), (1794, 'C'), (1855, 'C1'), (1843, 'D'), (1846, 'E1'), (1830, 'A'), (1790, 'D'), (1758, 'C'), (1859, 'C'), (1862, 'D'), (1822, 'D'), (1792, 'B'), (1541, 'B'), (698, 'A'), (1800, 'D'), (1867, 'C'), (1537, 'C'), (1837, 'D'), (1848, 'B'), (1750, 'C'), (1816, 'C'), (1800, 'E1'), (1850, 'F'), (1775, 'B'), (1667, 'A'), (1820, 'C'), (1799, 'B'), (1857, 'C'), (1846, 'C'), (4, 'C'), (1748, 'B'), (1420, 'B'), (1793, 'C'), (1763, 'B'), (1829, 'F'), (1833, 'D'), (1834, 'C'), (1810, 'C'), (189, 'A'), (1778, 'B'), (1847, 'C'), (1823, 'C'), (1824, 'A'), (1706, 'C'), (1476, 'B'), (1520, 'D'), (1719, 'C'), (1774, 'C'), (1864, 'C'), (1669, 'H'), (47, 'B'), (1733, 'D1'), (1772, 'D'), (1759, 'D'), (1721, 'C'), (25, 'A'), (1826, 'C'), (1776, 'H'), (1840, 'D'), (1692, 'G'), (1512, 'D'), (1521, 'B')}

# %%
import requests
import json

def get_solved_problems_in_rating_range(user_handle, min_rating, max_rating):
    """Gets the set of problems done by a Codeforces user within a specific rating range.

    Args:
        user_handle: The handle of the user.
        min_rating: The minimum rating (inclusive) for the desired range.
        max_rating: The maximum rating (inclusive) for the desired range.

    Returns:
        A tuple containing a set of problem IDs and the count of problems.
    """

    response = requests.get(
        f"https://codeforces.com/api/user.status?handle={user_handle}")

    data = json.loads(response.content)

    solved_problems = set()

    for submission in data["result"]:
        if submission["verdict"] == "OK" and "problem" in submission:
            problem = submission["problem"]
            if "rating" in problem:
                rating = problem["rating"]
                if min_rating <= rating <= max_rating:
                    solved_problems.add((problem["contestId"], problem["index"]))

    return solved_problems, len(solved_problems)


user_handle = "agrim07"
min_rating = 1300
max_rating = 1500
result = get_solved_problems_in_rating_range(user_handle, min_rating, max_rating)

solved_problems, problem_count = result

print("Solved problems within the rating range:")
for problem in solved_problems:
    print(problem)

print(f"Number of problems solved in the rating range: {problem_count}")
# Out:
# Solved problems within the rating range:
# (1844, 'D')
# (1790, 'E')
# (1853, 'B')
# (1832, 'C')
# (1857, 'D')
# (1846, 'D')
# (1768, 'C')
# (1692, 'F')
# (1872, 'D')
# (1766, 'C')
# (1821, 'C')
# (1807, 'E')
# (1805, 'C')
# (1860, 'C')
# (1729, 'D')
# (1744, 'D')
# (1714, 'E')
# (1838, 'C')
# (492, 'B')
# (1808, 'B')
# (628, 'B')
# (1851, 'D')
# (1705, 'C')
# (1860, 'B')
# (1749, 'C')
# (1839, 'C')
# (1762, 'C')
# (1873, 'F')
# (1788, 'C')
# (1420, 'C1')
# (1866, 'B')
# (1869, 'C')
# (1845, 'C')
# (1826, 'A')
# (1794, 'C')
# (1855, 'C1')
# (1843, 'D')
# (1846, 'E1')
# (1830, 'A')
# (1790, 'D')
# (1758, 'C')
# (1859, 'C')
# (1862, 'D')
# (1822, 'D')
# (1792, 'B')
# (1541, 'B')
# (698, 'A')
# (1800, 'D')
# (1867, 'C')
# (1537, 'C')
# (1837, 'D')
# (1848, 'B')
# (1750, 'C')
# (1816, 'C')
# (1800, 'E1')
# (1850, 'F')
# (1775, 'B')
# (1667, 'A')
# (1820, 'C')
# (1799, 'B')
# (1857, 'C')
# (1846, 'C')
# (4, 'C')
# (1748, 'B')
# (1420, 'B')
# (1793, 'C')
# (1763, 'B')
# (1829, 'F')
# (1833, 'D')
# (1834, 'C')
# (1810, 'C')
# (189, 'A')
# (1778, 'B')
# (1847, 'C')
# (1823, 'C')
# (1824, 'A')
# (1706, 'C')
# (1476, 'B')
# (1520, 'D')
# (1719, 'C')
# (1774, 'C')
# (1864, 'C')
# (1669, 'H')
# (47, 'B')
# (1733, 'D1')
# (1772, 'D')
# (1759, 'D')
# (1721, 'C')
# (25, 'A')
# (1826, 'C')
# (1776, 'H')
# (1840, 'D')
# (1692, 'G')
# (1512, 'D')
# (1521, 'B')
# Number of problems solved in the rating range: 95

# %%
import requests
import json

def get_solved_problems_in_rating_range(user_handle, min_rating, max_rating):
    """Gets the set of problems done by a Codeforces user when their rating was within a specific range.

    Args:
        user_handle: The handle of the user.
        min_rating: The minimum rating (inclusive) for the desired range.
        max_rating: The maximum rating (inclusive) for the desired range.

    Returns:
        A tuple containing a set of problem IDs and the count of problems.
    """

    # Fetch user's information
    user_info_response = requests.get(f"https://codeforces.com/api/user.info?handles={user_handle}")
    user_info = json.loads(user_info_response.content)
    
    user_rating = user_info["result"][0]["rating"]

    # Fetch the user's submissions
    response = requests.get(f"https://codeforces.com/api/user.status?handle={user_handle}")
    data = json.loads(response.content)

    solved_problems = set()

    for submission in data["result"]:
        if submission["verdict"] == "OK" and "problem" in submission:
            problem = submission["problem"]
            if "rating" in problem:
                rating = problem["rating"]
                submission_time = submission["creationTimeSeconds"]
                if min_rating <= rating <= max_rating and user_rating >= min_rating and user_rating <= max_rating:
                    solved_problems.add((problem["contestId"], problem["index"], submission_time))

    return solved_problems, len(solved_problems)

user_handle = "agrim07"
min_rating = 1200
max_rating = 1400
result = get_solved_problems_in_rating_range(user_handle, min_rating, max_rating)

solved_problems, problem_count = result

print("Solved problems within the rating range:")
for problem in solved_problems:
    print(problem)

print(f"Number of problems solved in the rating range: {problem_count}")
# Out:
# Solved problems within the rating range:
# Number of problems solved in the rating range: 0

# %%
import requests
import json

def get_solved_problems_in_rating_range(user_handle, min_rating, max_rating):
    user_info_response = requests.get(f"https://codeforces.com/api/user.info?handles={user_handle}")
    user_info = json.loads(user_info_response.content)
    user_rating = user_info["result"][0]["rating"]

    response = requests.get(f"https://codeforces.com/api/user.status?handle={user_handle}")
    data = json.loads(response.content)

    print("User's actual rating:", user_rating)
    print("Solved problems within the rating range:")

    for submission in data["result"]:
        if submission["verdict"] == "OK" and "problem" in submission:
            problem = submission["problem"]
            if "rating" in problem:
                rating = problem["rating"]
                submission_time = submission["creationTimeSeconds"]
                print(f"Problem Rating: {rating}, User Rating: {user_rating}, Submission Time: {submission_time}")
                if min_rating <= rating <= max_rating and user_rating >= min_rating and user_rating <= max_rating:
                    print(f"Contest ID: {problem['contestId']}, Problem Index: {problem['index']}")

user_handle = "agrim07"
min_rating = 1200
max_rating = 1400
get_solved_problems_in_rating_range(user_handle, min_rating, max_rating)
# Out:
# User's actual rating: 1637
# Solved problems within the rating range:
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1697492663
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1697066453
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1697061233
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1697060734
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1697060251
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1697059681
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1696884954
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1696862035
# Problem Rating: 900, User Rating: 1637, Submission Time: 1695906726
# Problem Rating: 800, User Rating: 1637, Submission Time: 1695906465
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1695315378
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1695312593
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1695311209
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1695310259
# Problem Rating: 800, User Rating: 1637, Submission Time: 1695308567
# Problem Rating: 800, User Rating: 1637, Submission Time: 1695308387
# Problem Rating: 800, User Rating: 1637, Submission Time: 1695308140
# Problem Rating: 800, User Rating: 1637, Submission Time: 1695308011
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1694707457
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1694706538
# Problem Rating: 800, User Rating: 1637, Submission Time: 1694705758
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1694359421
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1694356031
# Problem Rating: 900, User Rating: 1637, Submission Time: 1694355183
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1694284859
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1694283486
# Problem Rating: 800, User Rating: 1637, Submission Time: 1694283121
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1694098895
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1694098503
# Problem Rating: 900, User Rating: 1637, Submission Time: 1694097872
# Problem Rating: 800, User Rating: 1637, Submission Time: 1694097518
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1693744087
# Problem Rating: 800, User Rating: 1637, Submission Time: 1693742831
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1693650461
# Problem Rating: 1800, User Rating: 1637, Submission Time: 1692918817
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1692894179
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1692893215
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1692889035
# Problem Rating: 800, User Rating: 1637, Submission Time: 1692888368
# Problem Rating: 800, User Rating: 1637, Submission Time: 1692887963
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1692700193
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1692286002
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1692284615
# Problem Rating: 900, User Rating: 1637, Submission Time: 1692283451
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1692114470
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1692113772
# Problem Rating: 800, User Rating: 1637, Submission Time: 1692110229
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1691855344
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1691851784
# Problem Rating: 800, User Rating: 1637, Submission Time: 1691851159
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1691738887
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1691737011
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1691687840
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1691686053
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1691612732
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1691606625
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1691424791
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1691423078
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1691421883
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1691421202
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1691420713
# Problem Rating: 800, User Rating: 1637, Submission Time: 1691419028
# Problem Rating: 900, User Rating: 1637, Submission Time: 1691247122
# Problem Rating: 800, User Rating: 1637, Submission Time: 1691246515
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1691081022
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1691079988
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1690989982
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1690831681
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1690742742
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1690647976
# Problem Rating: 900, User Rating: 1637, Submission Time: 1690642470
# Problem Rating: 800, User Rating: 1637, Submission Time: 1690641690
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1690471127
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1690469181
# Problem Rating: 800, User Rating: 1637, Submission Time: 1690468653
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1690391674
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1690310190
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1690310086
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1690303583
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1690300852
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1690298237
# Problem Rating: 800, User Rating: 1637, Submission Time: 1690296931
# Problem Rating: 800, User Rating: 1637, Submission Time: 1690296563
# Problem Rating: 800, User Rating: 1637, Submission Time: 1690135961
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1690135176
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1690124838
# Problem Rating: 800, User Rating: 1637, Submission Time: 1690123170
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1689955870
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1689953132
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1689952475
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1689951817
# Problem Rating: 900, User Rating: 1637, Submission Time: 1689950877
# Problem Rating: 800, User Rating: 1637, Submission Time: 1689950548
# Problem Rating: 800, User Rating: 1637, Submission Time: 1689950373
# Problem Rating: 800, User Rating: 1637, Submission Time: 1689950223
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1689849241
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1689698122
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1689627723
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1689520275
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1689491873
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1689491243
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1689347230
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1689269910
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1689104205
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1689096406
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1689087508
# Problem Rating: 800, User Rating: 1637, Submission Time: 1689086259
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1689021747
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1688934325
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1688846105
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1688830776
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1688825223
# Problem Rating: 1800, User Rating: 1637, Submission Time: 1688747901
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1688744831
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1688742995
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1688742224
# Problem Rating: 800, User Rating: 1637, Submission Time: 1688740664
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1688659947
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1688655615
# Problem Rating: 800, User Rating: 1637, Submission Time: 1688654408
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1688596487
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1688518678
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1688517205
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1688228909
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1688143535
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1688129323
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1688124982
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1688052825
# Problem Rating: 900, User Rating: 1637, Submission Time: 1688051284
# Problem Rating: 800, User Rating: 1637, Submission Time: 1688050138
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1687896488
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1687889092
# Problem Rating: 800, User Rating: 1637, Submission Time: 1687888737
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1687274244
# Problem Rating: 800, User Rating: 1637, Submission Time: 1687272866
# Problem Rating: 800, User Rating: 1637, Submission Time: 1687272310
# Problem Rating: 800, User Rating: 1637, Submission Time: 1687271881
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1687009070
# Problem Rating: 800, User Rating: 1637, Submission Time: 1687007880
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1686332767
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1686331820
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1686173261
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1686170935
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1686167838
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1686146235
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1686145896
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1686073230
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1685975194
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1685970560
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1685913035
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1685893352
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1685891706
# Problem Rating: 800, User Rating: 1637, Submission Time: 1685890697
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1685879367
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1685874994
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1685816868
# Problem Rating: 1900, User Rating: 1637, Submission Time: 1685793538
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1685789327
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1685788960
# Problem Rating: 800, User Rating: 1637, Submission Time: 1685788816
# Problem Rating: 800, User Rating: 1637, Submission Time: 1685788722
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1685730881
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1685729491
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1685285381
# Problem Rating: 800, User Rating: 1637, Submission Time: 1685284753
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1685280292
# Problem Rating: 900, User Rating: 1637, Submission Time: 1685276941
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1685276941
# Problem Rating: 800, User Rating: 1637, Submission Time: 1685275793
# Problem Rating: 800, User Rating: 1637, Submission Time: 1685275401
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1685215968
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1685198008
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1685127970
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1685124213
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1685118967
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1685029761
# Problem Rating: 900, User Rating: 1637, Submission Time: 1685028298
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1685027639
# Problem Rating: 800, User Rating: 1637, Submission Time: 1685025589
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1684865200
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1684863457
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1684776823
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1684766930
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1684750560
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1684616705
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1684510891
# Problem Rating: 800, User Rating: 1637, Submission Time: 1684508240
# Problem Rating: 900, User Rating: 1637, Submission Time: 1684507611
# Problem Rating: 800, User Rating: 1637, Submission Time: 1684507103
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1684434309
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1684355501
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1684306837
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1684173351
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1684080365
# Problem Rating: 900, User Rating: 1637, Submission Time: 1684075385
# Problem Rating: 800, User Rating: 1637, Submission Time: 1684075108
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1684005697
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1683999139
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1683977139
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1683904226
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1683903513
# Problem Rating: 800, User Rating: 1637, Submission Time: 1683902264
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1683831888
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1683782156
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1683739236
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1683672058
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1683670854
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1683663939
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1683549655
# Problem Rating: 800, User Rating: 1637, Submission Time: 1683547806
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1683367912
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1683299613
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1683298390
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1683298050
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1683225306
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1683223459
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1682969382
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1682965443
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1682943273
# Problem Rating: 900, User Rating: 1637, Submission Time: 1682939911
# Problem Rating: 800, User Rating: 1637, Submission Time: 1682939363
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1682936436
# Problem Rating: 800, User Rating: 1637, Submission Time: 1682628701
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1682627852
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1682626772
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1682624216
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1682610504
# Problem Rating: 900, User Rating: 1637, Submission Time: 1682608196
# Problem Rating: 800, User Rating: 1637, Submission Time: 1682606572
# Problem Rating: 800, User Rating: 1637, Submission Time: 1682446754
# Problem Rating: 900, User Rating: 1637, Submission Time: 1682355423
# Problem Rating: 900, User Rating: 1637, Submission Time: 1682354422
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1681561894
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1681561131
# Problem Rating: 800, User Rating: 1637, Submission Time: 1681560831
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1681471712
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1681396823
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1681395835
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1681393133
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1681071481
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1681062370
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1681054047
# Problem Rating: 800, User Rating: 1637, Submission Time: 1681053041
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1680967834
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1680964165
# Problem Rating: 800, User Rating: 1637, Submission Time: 1680963242
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1680952700
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1680950544
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1680947202
# Problem Rating: 800, User Rating: 1637, Submission Time: 1680946455
# Problem Rating: 800, User Rating: 1637, Submission Time: 1680944894
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1680877408
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1680808548
# Problem Rating: 800, User Rating: 1637, Submission Time: 1680805201
# Problem Rating: 800, User Rating: 1637, Submission Time: 1680802603
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1680707209
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1680705828
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1680705803
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1680610874
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1680608662
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1680556685
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1680554777
# Problem Rating: 800, User Rating: 1637, Submission Time: 1680553483
# Problem Rating: 800, User Rating: 1637, Submission Time: 1680553324
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1680552986
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1680548929
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1680515338
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1680434007
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1680430043
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1680418483
# Problem Rating: 800, User Rating: 1637, Submission Time: 1680349261
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1680210396
# Problem Rating: 800, User Rating: 1637, Submission Time: 1680207205
# Problem Rating: 800, User Rating: 1637, Submission Time: 1680206600
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1680196873
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1680082699
# Problem Rating: 900, User Rating: 1637, Submission Time: 1680081304
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1680001785
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1679956053
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1679924099
# Problem Rating: 900, User Rating: 1637, Submission Time: 1679853609
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1679842764
# Problem Rating: 800, User Rating: 1637, Submission Time: 1679841862
# Problem Rating: 1700, User Rating: 1637, Submission Time: 1679828761
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1679586433
# Problem Rating: 800, User Rating: 1637, Submission Time: 1679583129
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1679520871
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1679519722
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1679519378
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1679518828
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1679517229
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1679515669
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1679512244
# Problem Rating: 800, User Rating: 1637, Submission Time: 1679288948
# Problem Rating: 800, User Rating: 1637, Submission Time: 1679287945
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1679241806
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1679241551
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1679240800
# Problem Rating: 900, User Rating: 1637, Submission Time: 1679238727
# Problem Rating: 800, User Rating: 1637, Submission Time: 1679238412
# Problem Rating: 800, User Rating: 1637, Submission Time: 1679238053
# Problem Rating: 800, User Rating: 1637, Submission Time: 1679237871
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1678971658
# Problem Rating: 800, User Rating: 1637, Submission Time: 1678969670
# Problem Rating: 800, User Rating: 1637, Submission Time: 1678961203
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1678947697
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1678820310
# Problem Rating: 800, User Rating: 1637, Submission Time: 1678814343
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1678788171
# Problem Rating: 800, User Rating: 1637, Submission Time: 1678717665
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1678136139
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1678131353
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1678130696
# Problem Rating: 800, User Rating: 1637, Submission Time: 1678128900
# Problem Rating: 800, User Rating: 1637, Submission Time: 1678128714
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1677957625
# Problem Rating: 900, User Rating: 1637, Submission Time: 1677953724
# Problem Rating: 800, User Rating: 1637, Submission Time: 1677952123
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1677778673
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1677771584
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1677771555
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1677768851
# Problem Rating: 800, User Rating: 1637, Submission Time: 1677768253
# Problem Rating: 800, User Rating: 1637, Submission Time: 1677335908
# Problem Rating: 800, User Rating: 1637, Submission Time: 1677335583
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1677220689
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1677217621
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1677216488
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1677215637
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1677214489
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1677213961
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1676234531
# Problem Rating: 800, User Rating: 1637, Submission Time: 1676232170
# Problem Rating: 800, User Rating: 1637, Submission Time: 1676230338
# Problem Rating: 1500, User Rating: 1637, Submission Time: 1675841527
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1675439670
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1675439196
# Problem Rating: 800, User Rating: 1637, Submission Time: 1675437170
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1675436908
# Problem Rating: 800, User Rating: 1637, Submission Time: 1675435448
# Problem Rating: 800, User Rating: 1637, Submission Time: 1675435159
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1675418352
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1675413236
# Problem Rating: 800, User Rating: 1637, Submission Time: 1674906662
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1674904613
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1674903929
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1674898216
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1674891885
# Problem Rating: 1200, User Rating: 1637, Submission Time: 1674888471
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1674840302
# Problem Rating: 800, User Rating: 1637, Submission Time: 1674837259
# Problem Rating: 800, User Rating: 1637, Submission Time: 1674836805
# Problem Rating: 800, User Rating: 1637, Submission Time: 1674386507
# Problem Rating: 800, User Rating: 1637, Submission Time: 1674383524
# Problem Rating: 1600, User Rating: 1637, Submission Time: 1673713037
# Problem Rating: 900, User Rating: 1637, Submission Time: 1673543488
# Problem Rating: 800, User Rating: 1637, Submission Time: 1673534774
# Problem Rating: 1400, User Rating: 1637, Submission Time: 1673508040
# Problem Rating: 900, User Rating: 1637, Submission Time: 1673351415
# Problem Rating: 800, User Rating: 1637, Submission Time: 1673351364
# Problem Rating: 800, User Rating: 1637, Submission Time: 1673338096
# Problem Rating: 900, User Rating: 1637, Submission Time: 1673337520
# Problem Rating: 800, User Rating: 1637, Submission Time: 1673194683
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1672492813
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1672157172
# Problem Rating: 800, User Rating: 1637, Submission Time: 1672153595
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1671547661
# Problem Rating: 800, User Rating: 1637, Submission Time: 1671543869
# Problem Rating: 800, User Rating: 1637, Submission Time: 1671541478
# Problem Rating: 800, User Rating: 1637, Submission Time: 1671346057
# Problem Rating: 800, User Rating: 1637, Submission Time: 1671293312
# Problem Rating: 900, User Rating: 1637, Submission Time: 1671187024
# Problem Rating: 800, User Rating: 1637, Submission Time: 1671128163
# Problem Rating: 1100, User Rating: 1637, Submission Time: 1671127590
# Problem Rating: 1300, User Rating: 1637, Submission Time: 1670923155
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1670860244
# Problem Rating: 800, User Rating: 1637, Submission Time: 1670858840
# Problem Rating: 800, User Rating: 1637, Submission Time: 1667972941
# Problem Rating: 1000, User Rating: 1637, Submission Time: 1667904249
